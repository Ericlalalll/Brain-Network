# %%
import scipy.io
import numpy as np
import networkx as nx
import os
import json
import time   #预估运行时间(可删除)
from scipy.stats import ttest_ind, ttest_rel

# %%
# 储存文件路径
folder_path = '/Users/shenxiaoyu/Desktop/FC'

file_paths = [
    'shamfc_s1.mat', 'shamfc_s2.mat', 'shamfc_s3.mat',
    'tacs6fc_s1.mat', 'tacs6fc_s2.mat', 'tacs6fc_s3.mat',
    'tacs10fc_s1.mat', 'tacs10fc_s2.mat', 'tacs10fc_s3.mat',
    'tdcsfc_s1.mat', 'tdcsfc_s2.mat', 'tdcsfc_s3.mat'
]


# preprocessing brain data
def data_preprocessing(matrix, fc_threshold=0.25, zfc_threshold=1.5):
    # matrix = np.where(np.isinf(matrix), np.nan, matrix)  # Replace infinite values with NaN
    
    # Apply threshold to create a binary adjacency matrix
    threshold = zfc_threshold if 'zfc' in file_path.lower() else fc_threshold
    binary_weighted_matrix = np.where(np.abs(matrix) >= threshold, matrix, 0)
    
    # Remove self-loops
    np.fill_diagonal(binary_weighted_matrix, 0)
    
    return binary_weighted_matrix


# Function to save metrics
def save_metrics(metrics, filename='metrics.json'):
    with open(filename, 'w') as f:
        json.dump(metrics, f)

# Function to load metrics
def load_metrics(filename='metrics.json'):
    if os.path.exists(filename):
        with open(filename, 'r') as f:
            return json.load(f)
    return {}

def clear_specific_property_from_metrics(property_name, filename='metrics.json'):
    if os.path.exists(filename):
        with open(filename, 'r') as f:
            metrics = json.load(f)
        for graph_id in metrics:
            if property_name in metrics[graph_id]:
                del metrics[graph_id][property_name]
        with open(filename, 'w') as f:
            json.dump(metrics, f)
    else:
        print("Metrics file not found.")

# Clear specific property before recomputing
#clear_specific_property_from_metrics('rich_club_coefficient')

#clear_specific_property_from_metrics('participation_coefficient')
# Function to delete the metrics file
def delete_metrics_file(filename='metrics.json'):
    if os.path.exists(filename):
        os.remove(filename)

# Delete the metrics file before recomputing
#delete_metrics_file()

# 创建一个dict来存储每种条件下的graph
graphs = {
    'sham': {'s1': [], 's2': [], 's3': []},
    'tacs6': {'s1': [], 's2': [], 's3': []},
    'tacs10': {'s1': [], 's2': [], 's3': []},
    'tdcs': {'s1': [], 's2': [], 's3': []}
}

# 读取文件里的matrix和提取ZFC
for file_name in file_paths:
    file_path = os.path.join(folder_path, file_name)
    mat = scipy.io.loadmat(file_path)
    key = [k for k in mat.keys() if not k.startswith('__')][0]  # 提取主要数据的key
    matrix = mat[key]
    
    # condition是刺激类型, time_point对应刺激前中后
    base_name = file_name.replace('.mat', '')
    parts = base_name.split('_')
    if len(parts) == 2:
        condition_time, time_point = parts
        if 'zfc' in condition_time:
            condition = condition_time.replace('zfc', '')
            matrix_type = 'zfc'
        else:
            condition = condition_time.replace('fc', '')
            matrix_type = 'fc'
    else:
        condition, matrix_type, time_point = parts

    
    if matrix_type == 'fc':
        # 将其转换为graph
        for i in range(matrix.shape[0]):
            adj_matrix_binary = data_preprocessing(matrix[i])
            G = nx.from_numpy_matrix(adj_matrix_binary)
            graphs[condition][time_point].append(G)

# %%
# WhitakerLab. (n.d.). Scona: Structural Covariance Networks. Retrieved [date], from https://whitakerlab.github.io/scona/_modules/scona/graph_measures.html
def participation_coefficient(G, module_partition):
    """ Calculate the participation coefficient for each node in the graph. """
    pc_dict = {}

    for m in module_partition.keys():
        M = set(module_partition[m])
        for v in M:
            degree = float(nx.degree(G=G, nbunch=v))
            if degree == 0:
                pc_dict[v] = 0
                continue

            wm_degree = float(sum([1 for u in M if (u, v) in G.edges()]))
            pc_dict[v] = 1 - ((float(wm_degree) / float(degree))**2)

    return pc_dict

# %%
# 定义所需要计算的graph property
def compute_graph_metrics(G, existing_metrics=None):
    
    metrics = existing_metrics if existing_metrics else {}
    
    if 'degree_centrality' not in metrics:
        metrics['degree_centrality'] = np.mean(list(nx.degree_centrality(G).values()))
        
    if 'betweenness_centrality' not in metrics:
        metrics['betweenness_centrality'] = np.mean(list(nx.betweenness_centrality(G, weight='weight').values()))
        
    if 'eigenvector_centrality' not in metrics:
        metrics['eigenvector_centrality'] = np.mean(list(nx.eigenvector_centrality(G, max_iter=10000, weight='weight').values()))
        
    if 'clustering_coefficient' not in metrics:
        metrics['clustering_coefficient'] = nx.average_clustering(G, weight='weight')
        
    if 'modularity' not in metrics:
        communities = list(nx.community.greedy_modularity_communities(G, weight='weight'))
        metrics['modularity'] = nx.algorithms.community.quality.modularity(G, communities, weight='weight')
        
    if 'rich_club_coefficient' not in metrics:
        try:
            rich_club = nx.rich_club_coefficient(G)
            avg_rich_club_coefficient = np.mean([v for v in rich_club.values() if v is not None])
        except ZeroDivisionError:
            avg_rich_club_coefficient = None
        metrics['rich_club_coefficient'] = avg_rich_club_coefficient
        
    if 'participation_coefficient' not in metrics:
        communities = list(nx.community.greedy_modularity_communities(G, weight='weight'))
        module_partition = {i: list(c) for i, c in enumerate(communities)}
        pc = participation_coefficient(G, module_partition)
        metrics['participation_coefficient'] = np.mean(list(pc.values()))
                                                           
    if 'connected_components' not in metrics:
        metrics['connected_components'] = nx.number_connected_components(G)
                                                           
    if 'minimum_spanning_tree' not in metrics:
        metrics['minimum_spanning_tree'] = nx.minimum_spanning_tree(G, weight='weight', ignore_nan=True).size(weight='weight') if nx.is_connected(G) else None
                                                           
    if 'cut_vertices' not in metrics:
        metrics['cut_vertices'] = len(list(nx.articulation_points(G)))
                                                           
    if 'biconnected_components' not in metrics:
        metrics['biconnected_components'] = len(list(nx.biconnected_components(G)))
        
    return metrics


# Store the computed metrics
metrics = load_metrics()

# 预估运行时间(可删除)
metrics_start_time = time.time()
total_graphs = sum(len(graphs[condition][time_point]) for condition in graphs for time_point in graphs[condition])
processed_graphs = 0

# Compute metrics for all graphs
for condition in graphs:
    for time_point in graphs[condition]:
        for idx, G in enumerate(graphs[condition][time_point]):
            graph_id = f"{condition}_{time_point}_{idx}"
            if graph_id not in metrics:
                metrics[graph_id] = compute_graph_metrics(G, metrics.get(graph_id, {}))
                
                
                # 预估运行时间(可删除)
                processed_graphs += 1
                elapsed_time = time.time() - metrics_start_time
                estimated_total_time = (elapsed_time / processed_graphs) * total_graphs
                remaining_time = estimated_total_time - elapsed_time
                print(f"Processed {processed_graphs}/{total_graphs} graphs. Estimated remaining time: {remaining_time:.2f} seconds.")

# Save the computed metrics
save_metrics(metrics)
# Out:
# Processed 1/252 graphs. Estimated remaining time: 23484.22 seconds.
# Processed 2/252 graphs. Estimated remaining time: 19511.91 seconds.
# Processed 3/252 graphs. Estimated remaining time: 21474.59 seconds.
# Processed 4/252 graphs. Estimated remaining time: 26420.60 seconds.
# Processed 5/252 graphs. Estimated remaining time: 27535.22 seconds.
# Processed 6/252 graphs. Estimated remaining time: 26954.16 seconds.
# Processed 7/252 graphs. Estimated remaining time: 28640.11 seconds.
# Processed 8/252 graphs. Estimated remaining time: 27188.38 seconds.
# Processed 9/252 graphs. Estimated remaining time: 26402.31 seconds.
# Processed 10/252 graphs. Estimated remaining time: 25599.09 seconds.
# Processed 11/252 graphs. Estimated remaining time: 25529.85 seconds.
# Processed 12/252 graphs. Estimated remaining time: 25115.81 seconds.
# Processed 13/252 graphs. Estimated remaining time: 26731.25 seconds.
# Processed 14/252 graphs. Estimated remaining time: 26216.24 seconds.
# Processed 15/252 graphs. Estimated remaining time: 25855.69 seconds.
# Processed 16/252 graphs. Estimated remaining time: 26426.00 seconds.
# Processed 17/252 graphs. Estimated remaining time: 26566.02 seconds.
# Processed 18/252 graphs. Estimated remaining time: 26502.62 seconds.
# Processed 19/252 graphs. Estimated remaining time: 26280.40 seconds.
# Processed 20/252 graphs. Estimated remaining time: 25490.53 seconds.
# Processed 21/252 graphs. Estimated remaining time: 25602.98 seconds.
# Processed 22/252 graphs. Estimated remaining time: 25424.66 seconds.
# Processed 23/252 graphs. Estimated remaining time: 24966.65 seconds.
# Processed 24/252 graphs. Estimated remaining time: 24709.54 seconds.
# Processed 25/252 graphs. Estimated remaining time: 25133.85 seconds.
# Processed 26/252 graphs. Estimated remaining time: 24769.37 seconds.
# Processed 27/252 graphs. Estimated remaining time: 24667.96 seconds.
# Processed 28/252 graphs. Estimated remaining time: 24397.85 seconds.
# Processed 29/252 graphs. Estimated remaining time: 24208.22 seconds.
# Processed 30/252 graphs. Estimated remaining time: 23895.79 seconds.
# Processed 31/252 graphs. Estimated remaining time: 23806.82 seconds.
# Processed 32/252 graphs. Estimated remaining time: 23694.30 seconds.
# Processed 33/252 graphs. Estimated remaining time: 23682.30 seconds.
# Processed 34/252 graphs. Estimated remaining time: 23368.89 seconds.
# Processed 35/252 graphs. Estimated remaining time: 23325.61 seconds.
# Processed 36/252 graphs. Estimated remaining time: 23524.68 seconds.
# Processed 37/252 graphs. Estimated remaining time: 23565.03 seconds.
# Processed 38/252 graphs. Estimated remaining time: 23457.65 seconds.
# Processed 39/252 graphs. Estimated remaining time: 23366.11 seconds.
# Processed 40/252 graphs. Estimated remaining time: 22988.68 seconds.
# Processed 41/252 graphs. Estimated remaining time: 22719.16 seconds.
# Processed 42/252 graphs. Estimated remaining time: 22662.82 seconds.
# Processed 43/252 graphs. Estimated remaining time: 22596.23 seconds.
# Processed 44/252 graphs. Estimated remaining time: 22557.14 seconds.
# Processed 45/252 graphs. Estimated remaining time: 22390.24 seconds.
# Processed 46/252 graphs. Estimated remaining time: 22106.85 seconds.
# Processed 47/252 graphs. Estimated remaining time: 21809.39 seconds.
# Processed 48/252 graphs. Estimated remaining time: 21717.20 seconds.
# Processed 49/252 graphs. Estimated remaining time: 21652.70 seconds.
# Processed 50/252 graphs. Estimated remaining time: 21442.96 seconds.
# Processed 51/252 graphs. Estimated remaining time: 21201.02 seconds.
# Processed 52/252 graphs. Estimated remaining time: 21081.08 seconds.
# Processed 53/252 graphs. Estimated remaining time: 21275.47 seconds.
# Processed 54/252 graphs. Estimated remaining time: 21028.79 seconds.
# Processed 55/252 graphs. Estimated remaining time: 20924.58 seconds.
# Processed 56/252 graphs. Estimated remaining time: 21045.28 seconds.
# Processed 57/252 graphs. Estimated remaining time: 21262.07 seconds.
# Processed 58/252 graphs. Estimated remaining time: 21044.81 seconds.
# Processed 59/252 graphs. Estimated remaining time: 20929.54 seconds.
# Processed 60/252 graphs. Estimated remaining time: 20775.69 seconds.
# Processed 61/252 graphs. Estimated remaining time: 20759.70 seconds.
# Processed 62/252 graphs. Estimated remaining time: 20549.30 seconds.
# Processed 63/252 graphs. Estimated remaining time: 20465.94 seconds.
# Processed 64/252 graphs. Estimated remaining time: 20313.49 seconds.
# Processed 65/252 graphs. Estimated remaining time: 20347.84 seconds.
# Processed 66/252 graphs. Estimated remaining time: 20545.41 seconds.
# Processed 67/252 graphs. Estimated remaining time: 20420.62 seconds.
# Processed 68/252 graphs. Estimated remaining time: 20244.79 seconds.
# Processed 69/252 graphs. Estimated remaining time: 20206.02 seconds.
# Processed 70/252 graphs. Estimated remaining time: 20339.32 seconds.
# Processed 71/252 graphs. Estimated remaining time: 20303.13 seconds.
# Processed 72/252 graphs. Estimated remaining time: 20249.58 seconds.
# Processed 73/252 graphs. Estimated remaining time: 20264.66 seconds.
# Processed 74/252 graphs. Estimated remaining time: 20232.77 seconds.
# Processed 75/252 graphs. Estimated remaining time: 20123.51 seconds.
# Processed 76/252 graphs. Estimated remaining time: 20205.03 seconds.
# Processed 77/252 graphs. Estimated remaining time: 20028.74 seconds.
# Processed 78/252 graphs. Estimated remaining time: 19876.55 seconds.
# Processed 79/252 graphs. Estimated remaining time: 19668.10 seconds.
# Processed 80/252 graphs. Estimated remaining time: 19605.04 seconds.
# Processed 81/252 graphs. Estimated remaining time: 19391.78 seconds.
# Processed 82/252 graphs. Estimated remaining time: 19208.68 seconds.
# Processed 83/252 graphs. Estimated remaining time: 19078.86 seconds.
# Processed 84/252 graphs. Estimated remaining time: 19001.99 seconds.
# Processed 85/252 graphs. Estimated remaining time: 18927.34 seconds.
# Processed 86/252 graphs. Estimated remaining time: 18921.44 seconds.
# Processed 87/252 graphs. Estimated remaining time: 18862.59 seconds.
# Processed 88/252 graphs. Estimated remaining time: 18847.76 seconds.
# Processed 89/252 graphs. Estimated remaining time: 18811.37 seconds.
# Processed 90/252 graphs. Estimated remaining time: 18677.63 seconds.
# Processed 91/252 graphs. Estimated remaining time: 18570.35 seconds.
# Processed 92/252 graphs. Estimated remaining time: 18622.96 seconds.
# Processed 93/252 graphs. Estimated remaining time: 18518.09 seconds.
# Processed 94/252 graphs. Estimated remaining time: 18395.89 seconds.
# Processed 95/252 graphs. Estimated remaining time: 18321.93 seconds.
# Processed 96/252 graphs. Estimated remaining time: 18242.70 seconds.
# Processed 97/252 graphs. Estimated remaining time: 18129.29 seconds.
# Processed 98/252 graphs. Estimated remaining time: 18316.55 seconds.
# Processed 99/252 graphs. Estimated remaining time: 18157.77 seconds.
# Processed 100/252 graphs. Estimated remaining time: 18027.73 seconds.
# Processed 101/252 graphs. Estimated remaining time: 17858.17 seconds.
# Processed 102/252 graphs. Estimated remaining time: 17697.19 seconds.
# Processed 103/252 graphs. Estimated remaining time: 17489.27 seconds.
# Processed 104/252 graphs. Estimated remaining time: 17348.28 seconds.
# Processed 105/252 graphs. Estimated remaining time: 17237.98 seconds.
# Processed 106/252 graphs. Estimated remaining time: 17076.66 seconds.
# Processed 107/252 graphs. Estimated remaining time: 16918.11 seconds.
# Processed 108/252 graphs. Estimated remaining time: 16767.27 seconds.
# Processed 109/252 graphs. Estimated remaining time: 16695.91 seconds.
# Processed 110/252 graphs. Estimated remaining time: 16580.74 seconds.
# Processed 111/252 graphs. Estimated remaining time: 16423.10 seconds.
# Processed 112/252 graphs. Estimated remaining time: 16249.22 seconds.
# Processed 113/252 graphs. Estimated remaining time: 16177.07 seconds.
# Processed 114/252 graphs. Estimated remaining time: 16183.39 seconds.
# Processed 115/252 graphs. Estimated remaining time: 16125.43 seconds.
# Processed 116/252 graphs. Estimated remaining time: 16164.52 seconds.
# Processed 117/252 graphs. Estimated remaining time: 15993.90 seconds.
# Processed 118/252 graphs. Estimated remaining time: 15845.29 seconds.
# Processed 119/252 graphs. Estimated remaining time: 15691.74 seconds.
# Processed 120/252 graphs. Estimated remaining time: 15586.29 seconds.
# Processed 121/252 graphs. Estimated remaining time: 15471.65 seconds.
# Processed 122/252 graphs. Estimated remaining time: 15306.49 seconds.
# Processed 123/252 graphs. Estimated remaining time: 15138.92 seconds.
# Processed 124/252 graphs. Estimated remaining time: 14993.95 seconds.
# Processed 125/252 graphs. Estimated remaining time: 14826.65 seconds.
# Processed 126/252 graphs. Estimated remaining time: 14701.48 seconds.
# Processed 127/252 graphs. Estimated remaining time: 14568.89 seconds.
# Processed 128/252 graphs. Estimated remaining time: 14454.35 seconds.
# Processed 129/252 graphs. Estimated remaining time: 14294.51 seconds.
# Processed 130/252 graphs. Estimated remaining time: 14146.63 seconds.
# Processed 131/252 graphs. Estimated remaining time: 13995.94 seconds.
# Processed 132/252 graphs. Estimated remaining time: 13888.68 seconds.
# Processed 133/252 graphs. Estimated remaining time: 13790.74 seconds.
# Processed 134/252 graphs. Estimated remaining time: 13643.43 seconds.
# Processed 135/252 graphs. Estimated remaining time: 13483.67 seconds.
# Processed 136/252 graphs. Estimated remaining time: 13371.04 seconds.
# Processed 137/252 graphs. Estimated remaining time: 13255.02 seconds.
# Processed 138/252 graphs. Estimated remaining time: 13095.80 seconds.
# Processed 139/252 graphs. Estimated remaining time: 12959.44 seconds.
# Processed 140/252 graphs. Estimated remaining time: 12831.40 seconds.
# Processed 141/252 graphs. Estimated remaining time: 12695.44 seconds.
# Processed 142/252 graphs. Estimated remaining time: 12574.74 seconds.
# Processed 143/252 graphs. Estimated remaining time: 12439.40 seconds.
# Processed 144/252 graphs. Estimated remaining time: 12299.63 seconds.
# Processed 145/252 graphs. Estimated remaining time: 12167.51 seconds.
# Processed 146/252 graphs. Estimated remaining time: 12019.00 seconds.
# Processed 147/252 graphs. Estimated remaining time: 11887.41 seconds.
# Processed 148/252 graphs. Estimated remaining time: 11812.48 seconds.
# Processed 149/252 graphs. Estimated remaining time: 11672.46 seconds.
# Processed 150/252 graphs. Estimated remaining time: 11537.28 seconds.
# Processed 151/252 graphs. Estimated remaining time: 11405.58 seconds.
# Processed 152/252 graphs. Estimated remaining time: 11308.77 seconds.
# Processed 153/252 graphs. Estimated remaining time: 11208.52 seconds.
# Processed 154/252 graphs. Estimated remaining time: 11192.09 seconds.
# Processed 155/252 graphs. Estimated remaining time: 11058.45 seconds.
# Processed 156/252 graphs. Estimated remaining time: 10912.87 seconds.
# Processed 157/252 graphs. Estimated remaining time: 10801.11 seconds.
# Processed 158/252 graphs. Estimated remaining time: 10688.69 seconds.
# Processed 159/252 graphs. Estimated remaining time: 10586.27 seconds.
# Processed 160/252 graphs. Estimated remaining time: 10450.75 seconds.
# Processed 161/252 graphs. Estimated remaining time: 10317.01 seconds.
# Processed 162/252 graphs. Estimated remaining time: 10183.95 seconds.
# Processed 163/252 graphs. Estimated remaining time: 10051.81 seconds.
# Processed 164/252 graphs. Estimated remaining time: 9912.60 seconds.
# Processed 165/252 graphs. Estimated remaining time: 9834.84 seconds.
# Processed 166/252 graphs. Estimated remaining time: 9712.53 seconds.
# Processed 167/252 graphs. Estimated remaining time: 9596.89 seconds.
# Processed 168/252 graphs. Estimated remaining time: 9459.15 seconds.
# Processed 169/252 graphs. Estimated remaining time: 9336.36 seconds.
# Processed 170/252 graphs. Estimated remaining time: 9259.04 seconds.
# Processed 171/252 graphs. Estimated remaining time: 9132.79 seconds.
# Processed 172/252 graphs. Estimated remaining time: 9007.37 seconds.
# Processed 173/252 graphs. Estimated remaining time: 8876.46 seconds.
# Processed 174/252 graphs. Estimated remaining time: 8754.93 seconds.
# Processed 175/252 graphs. Estimated remaining time: 8631.96 seconds.
# Processed 176/252 graphs. Estimated remaining time: 8518.04 seconds.
# Processed 177/252 graphs. Estimated remaining time: 8395.62 seconds.
# Processed 178/252 graphs. Estimated remaining time: 8278.70 seconds.
# Processed 179/252 graphs. Estimated remaining time: 8150.29 seconds.
# Processed 180/252 graphs. Estimated remaining time: 8052.95 seconds.
# Processed 181/252 graphs. Estimated remaining time: 7967.46 seconds.
# Processed 182/252 graphs. Estimated remaining time: 7845.10 seconds.
# Processed 183/252 graphs. Estimated remaining time: 7734.71 seconds.
# Processed 184/252 graphs. Estimated remaining time: 7613.45 seconds.
# Processed 185/252 graphs. Estimated remaining time: 7498.01 seconds.
# Processed 186/252 graphs. Estimated remaining time: 7375.48 seconds.
# Processed 187/252 graphs. Estimated remaining time: 7262.97 seconds.
# Processed 188/252 graphs. Estimated remaining time: 7143.65 seconds.
# Processed 189/252 graphs. Estimated remaining time: 7022.06 seconds.
# Processed 190/252 graphs. Estimated remaining time: 6903.56 seconds.
# Processed 191/252 graphs. Estimated remaining time: 6838.27 seconds.
# Processed 192/252 graphs. Estimated remaining time: 6735.15 seconds.
# Processed 193/252 graphs. Estimated remaining time: 6630.27 seconds.
# Processed 194/252 graphs. Estimated remaining time: 6512.21 seconds.
# Processed 195/252 graphs. Estimated remaining time: 6389.49 seconds.
# Processed 196/252 graphs. Estimated remaining time: 6282.02 seconds.
# Processed 197/252 graphs. Estimated remaining time: 6160.23 seconds.
# Processed 198/252 graphs. Estimated remaining time: 6043.66 seconds.
# Processed 199/252 graphs. Estimated remaining time: 5920.80 seconds.
# Processed 200/252 graphs. Estimated remaining time: 5801.13 seconds.
# Processed 201/252 graphs. Estimated remaining time: 5684.04 seconds.
# Processed 202/252 graphs. Estimated remaining time: 5561.57 seconds.
# Processed 203/252 graphs. Estimated remaining time: 5452.54 seconds.
# Processed 204/252 graphs. Estimated remaining time: 5333.28 seconds.
# Processed 205/252 graphs. Estimated remaining time: 5243.26 seconds.
# Processed 206/252 graphs. Estimated remaining time: 5127.54 seconds.
# Processed 207/252 graphs. Estimated remaining time: 5013.86 seconds.
# Processed 208/252 graphs. Estimated remaining time: 4893.58 seconds.
# Processed 209/252 graphs. Estimated remaining time: 4780.85 seconds.
# Processed 210/252 graphs. Estimated remaining time: 4661.40 seconds.
# Processed 211/252 graphs. Estimated remaining time: 4559.54 seconds.
# Processed 212/252 graphs. Estimated remaining time: 4449.49 seconds.
# Processed 213/252 graphs. Estimated remaining time: 4332.23 seconds.
# Processed 214/252 graphs. Estimated remaining time: 4218.56 seconds.
# Processed 215/252 graphs. Estimated remaining time: 4103.85 seconds.
# Processed 216/252 graphs. Estimated remaining time: 3986.10 seconds.
# Processed 217/252 graphs. Estimated remaining time: 3872.77 seconds.
# Processed 218/252 graphs. Estimated remaining time: 3758.31 seconds.
# Processed 219/252 graphs. Estimated remaining time: 3645.68 seconds.
# Processed 220/252 graphs. Estimated remaining time: 3528.99 seconds.
# Processed 221/252 graphs. Estimated remaining time: 3414.89 seconds.
# Processed 222/252 graphs. Estimated remaining time: 3298.32 seconds.
# Processed 223/252 graphs. Estimated remaining time: 3190.73 seconds.
# Processed 224/252 graphs. Estimated remaining time: 3081.73 seconds.
# Processed 225/252 graphs. Estimated remaining time: 2979.19 seconds.
# Processed 226/252 graphs. Estimated remaining time: 2868.99 seconds.
# Processed 227/252 graphs. Estimated remaining time: 2758.07 seconds.
# Processed 228/252 graphs. Estimated remaining time: 2643.17 seconds.
# Processed 229/252 graphs. Estimated remaining time: 2539.28 seconds.
# Processed 230/252 graphs. Estimated remaining time: 2424.55 seconds.
# Processed 231/252 graphs. Estimated remaining time: 2314.69 seconds.
# Processed 232/252 graphs. Estimated remaining time: 2206.35 seconds.
# Processed 233/252 graphs. Estimated remaining time: 2093.71 seconds.
# Processed 234/252 graphs. Estimated remaining time: 1982.57 seconds.
# Processed 235/252 graphs. Estimated remaining time: 1871.45 seconds.
# Processed 236/252 graphs. Estimated remaining time: 1761.99 seconds.
# Processed 237/252 graphs. Estimated remaining time: 1649.70 seconds.
# Processed 238/252 graphs. Estimated remaining time: 1539.06 seconds.
# Processed 239/252 graphs. Estimated remaining time: 1431.88 seconds.
# Processed 240/252 graphs. Estimated remaining time: 1322.21 seconds.
# Processed 241/252 graphs. Estimated remaining time: 1211.01 seconds.
# Processed 242/252 graphs. Estimated remaining time: 1099.23 seconds.
# Processed 243/252 graphs. Estimated remaining time: 988.75 seconds.
# Processed 244/252 graphs. Estimated remaining time: 878.79 seconds.
# Processed 245/252 graphs. Estimated remaining time: 774.28 seconds.
# Processed 246/252 graphs. Estimated remaining time: 664.13 seconds.
# Processed 247/252 graphs. Estimated remaining time: 552.78 seconds.
# Processed 248/252 graphs. Estimated remaining time: 441.52 seconds.
# Processed 249/252 graphs. Estimated remaining time: 331.24 seconds.
# Processed 250/252 graphs. Estimated remaining time: 220.58 seconds.
# Processed 251/252 graphs. Estimated remaining time: 110.16 seconds.
# Processed 252/252 graphs. Estimated remaining time: 0.00 seconds.

# %%
def compare_analysis(metrics, condition1, time_point1, condition2, time_point2, graph_property, paired=False):
    data1 = [metrics[f"{condition1}_{time_point1}_{i}"][graph_property] for i in range(20) if f"{condition1}_{time_point1}_{i}" in metrics and metrics[f"{condition1}_{time_point1}_{i}"].get(graph_property) is not None]
    data2 = [metrics[f"{condition2}_{time_point2}_{i}"][graph_property] for i in range(20) if f"{condition2}_{time_point2}_{i}" in metrics and metrics[f"{condition2}_{time_point2}_{i}"].get(graph_property) is not None]
    
    # Filter out None values
    data1 = [x for x in data1 if x is not None]
    data2 = [x for x in data2 if x is not None]
    
    if len(data1) > 0 and len(data2) > 0:
        if paired:
            t_stat, p_value = ttest_rel(data1, data2)
        else:
            t_stat, p_value = ttest_ind(data1, data2)
    else:
        t_stat, p_value = None, None
    return t_stat, p_value

# %%
# 1. 验证四组s1相似性 
print("S_1:")
for condition in ['tacs6', 'tacs10', 'tdcs']:
    for graph_property in ['degree_centrality', 'betweenness_centrality', 'eigenvector_centrality', 'clustering_coefficient', 'modularity', 'rich_club_coefficient', 'participation_coefficient', 'connected_components', 'minimum_spanning_tree', 'cut_vertices', 'biconnected_components']:
        t_stat, p_value = compare_analysis(metrics, 'sham', 's1', condition, 's1', graph_property)
        print(f"Sham S1 vs {condition} S1 - {graph_property}: T-statistic: {t_stat}, P-value: {p_value}")
# Out:
# S_1:
# Sham S1 vs tacs6 S1 - degree_centrality: T-statistic: -1.5093914488405373, P-value: 0.13946957597942822
# Sham S1 vs tacs6 S1 - betweenness_centrality: T-statistic: 0.22471075495464393, P-value: 0.8234082785058865
# Sham S1 vs tacs6 S1 - eigenvector_centrality: T-statistic: 0.8397667178031474, P-value: 0.4062917327193206
# Sham S1 vs tacs6 S1 - clustering_coefficient: T-statistic: -1.0833712718497148, P-value: 0.2854701233521141
# Sham S1 vs tacs6 S1 - modularity: T-statistic: -0.7096086447337933, P-value: 0.48227863008254335
# Sham S1 vs tacs6 S1 - rich_club_coefficient: T-statistic: 0.9331025670299374, P-value: 0.35715986262930444
# Sham S1 vs tacs6 S1 - participation_coefficient: T-statistic: 0.6982074213809646, P-value: 0.4892983907240316
# Sham S1 vs tacs6 S1 - connected_components: T-statistic: nan, P-value: nan
# Sham S1 vs tacs6 S1 - minimum_spanning_tree: T-statistic: 0.6586697677944189, P-value: 0.5140792995657061
# Sham S1 vs tacs6 S1 - cut_vertices: T-statistic: nan, P-value: nan
# Sham S1 vs tacs6 S1 - biconnected_components: T-statistic: nan, P-value: nan
# Sham S1 vs tacs10 S1 - degree_centrality: T-statistic: -0.03870039230992923, P-value: 0.9693318690330817
# Sham S1 vs tacs10 S1 - betweenness_centrality: T-statistic: -0.2976534976818976, P-value: 0.7675889285489562
# Sham S1 vs tacs10 S1 - eigenvector_centrality: T-statistic: 1.4976750134577963, P-value: 0.14247907816039837
# Sham S1 vs tacs10 S1 - clustering_coefficient: T-statistic: -0.16655335854008063, P-value: 0.868604584484994
# Sham S1 vs tacs10 S1 - modularity: T-statistic: -1.4466259861967976, P-value: 0.15620069150614127
# Sham S1 vs tacs10 S1 - rich_club_coefficient: T-statistic: 1.2257420214034487, P-value: 0.2289716958012158
# Sham S1 vs tacs10 S1 - participation_coefficient: T-statistic: 0.4656407355056218, P-value: 0.6441305545188919
# Sham S1 vs tacs10 S1 - connected_components: T-statistic: -1.0000000000000009, P-value: 0.3236360838644077
# Sham S1 vs tacs10 S1 - minimum_spanning_tree: T-statistic: 0.1839794952169533, P-value: 0.8550341587764791
# Sham S1 vs tacs10 S1 - cut_vertices: T-statistic: nan, P-value: nan
# Sham S1 vs tacs10 S1 - biconnected_components: T-statistic: nan, P-value: nan
# Sham S1 vs tdcs S1 - degree_centrality: T-statistic: -0.7021113556678289, P-value: 0.48688830594007904
# Sham S1 vs tdcs S1 - betweenness_centrality: T-statistic: -0.19440242006372085, P-value: 0.8468963817276525
# Sham S1 vs tdcs S1 - eigenvector_centrality: T-statistic: 1.4197828104495789, P-value: 0.1638232447826433
# Sham S1 vs tdcs S1 - clustering_coefficient: T-statistic: -0.5900592938471682, P-value: 0.5586436227804056
# Sham S1 vs tdcs S1 - modularity: T-statistic: -0.7739843727752855, P-value: 0.44372893192314355
# Sham S1 vs tdcs S1 - rich_club_coefficient: T-statistic: 0.19639634650426374, P-value: 0.8455818149938527
# Sham S1 vs tdcs S1 - participation_coefficient: T-statistic: 1.5391166027657948, P-value: 0.13206236650783307
# Sham S1 vs tdcs S1 - connected_components: T-statistic: nan, P-value: nan
# Sham S1 vs tdcs S1 - minimum_spanning_tree: T-statistic: 0.9488484375739924, P-value: 0.3486934171111252
# Sham S1 vs tdcs S1 - cut_vertices: T-statistic: nan, P-value: nan
# Sham S1 vs tdcs S1 - biconnected_components: T-statistic: nan, P-value: nan
# /var/folders/5h/x_p7ky7d4ts4dz4c7g75h28c0000gn/T/ipykernel_28369/2622518207.py:13: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   t_stat, p_value = ttest_ind(data1, data2)

# %%
# 2. 验证真实刺激的s2与sham组的对比
print("S_2:")
for condition in ['tacs6', 'tacs10', 'tdcs']:
    for graph_property in ['degree_centrality', 'betweenness_centrality', 'eigenvector_centrality', 'clustering_coefficient', 'modularity', 'rich_club_coefficient', 'participation_coefficient', 'connected_components', 'minimum_spanning_tree', 'cut_vertices', 'biconnected_components']:
        # 比较 s2
        t_stat, p_value = compare_analysis(metrics, 'sham', 's2', condition, 's2', graph_property)
        print(f"{condition} S2 vs Sham S2 - {graph_property}: T-statistic: {t_stat}, P-value: {p_value}")
# Out:
# S_2:
# tacs6 S2 vs Sham S2 - degree_centrality: T-statistic: -2.6382605378964046, P-value: 0.012011968889903942
# tacs6 S2 vs Sham S2 - betweenness_centrality: T-statistic: 0.31749173095480593, P-value: 0.7526085454704214
# tacs6 S2 vs Sham S2 - eigenvector_centrality: T-statistic: 0.6328273635329393, P-value: 0.5306363945912491
# tacs6 S2 vs Sham S2 - clustering_coefficient: T-statistic: -1.9785244428330868, P-value: 0.05515173795657097
# tacs6 S2 vs Sham S2 - modularity: T-statistic: -0.9993856749497396, P-value: 0.32392960210277655
# tacs6 S2 vs Sham S2 - rich_club_coefficient: T-statistic: 3.45346011921483, P-value: 0.001579081873659373
# tacs6 S2 vs Sham S2 - participation_coefficient: T-statistic: -0.7014588017762626, P-value: 0.48729069381871837
# tacs6 S2 vs Sham S2 - connected_components: T-statistic: nan, P-value: nan
# tacs6 S2 vs Sham S2 - minimum_spanning_tree: T-statistic: 1.5070476544388796, P-value: 0.1400675018244828
# tacs6 S2 vs Sham S2 - cut_vertices: T-statistic: nan, P-value: nan
# tacs6 S2 vs Sham S2 - biconnected_components: T-statistic: nan, P-value: nan
# tacs10 S2 vs Sham S2 - degree_centrality: T-statistic: -0.9464184667434027, P-value: 0.34991488085672073
# tacs10 S2 vs Sham S2 - betweenness_centrality: T-statistic: -0.23055384517572125, P-value: 0.8188981891266782
# tacs10 S2 vs Sham S2 - eigenvector_centrality: T-statistic: 1.0721143060600404, P-value: 0.29043058476548245
# tacs10 S2 vs Sham S2 - clustering_coefficient: T-statistic: -0.8815108075547781, P-value: 0.3835833545064601
# tacs10 S2 vs Sham S2 - modularity: T-statistic: -1.5663692488207372, P-value: 0.12555288518987567
# tacs10 S2 vs Sham S2 - rich_club_coefficient: T-statistic: 0.5072895517120966, P-value: 0.6155417401348056
# tacs10 S2 vs Sham S2 - participation_coefficient: T-statistic: -0.601749987473848, P-value: 0.5509141352875242
# tacs10 S2 vs Sham S2 - connected_components: T-statistic: nan, P-value: nan
# tacs10 S2 vs Sham S2 - minimum_spanning_tree: T-statistic: 1.5259087458038587, P-value: 0.13531358210300845
# tacs10 S2 vs Sham S2 - cut_vertices: T-statistic: nan, P-value: nan
# tacs10 S2 vs Sham S2 - biconnected_components: T-statistic: nan, P-value: nan
# tdcs S2 vs Sham S2 - degree_centrality: T-statistic: -0.8072578086697698, P-value: 0.4245422158204465
# tdcs S2 vs Sham S2 - betweenness_centrality: T-statistic: -0.8279098747981032, P-value: 0.41289105692336714
# tdcs S2 vs Sham S2 - eigenvector_centrality: T-statistic: 1.8606030563581843, P-value: 0.07055180899553964
# tdcs S2 vs Sham S2 - clustering_coefficient: T-statistic: -0.4606819483615466, P-value: 0.6476525177337689
# tdcs S2 vs Sham S2 - modularity: T-statistic: -2.0192332785924623, P-value: 0.05055790007050696
# tdcs S2 vs Sham S2 - rich_club_coefficient: T-statistic: 1.6592842556331593, P-value: 0.1062564141863157
# tdcs S2 vs Sham S2 - participation_coefficient: T-statistic: -0.3508960984120325, P-value: 0.7276042662967164
# tdcs S2 vs Sham S2 - connected_components: T-statistic: nan, P-value: nan
# tdcs S2 vs Sham S2 - minimum_spanning_tree: T-statistic: 1.9699843252515223, P-value: 0.0561601221635266
# tdcs S2 vs Sham S2 - cut_vertices: T-statistic: nan, P-value: nan
# tdcs S2 vs Sham S2 - biconnected_components: T-statistic: nan, P-value: nan
# /var/folders/5h/x_p7ky7d4ts4dz4c7g75h28c0000gn/T/ipykernel_28369/2622518207.py:13: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   t_stat, p_value = ttest_ind(data1, data2)

# %%
# 2. 验证真实刺激的s3与sham组的对比
print("S_3:")
for condition in ['tacs6', 'tacs10', 'tdcs']:
    for graph_property in ['degree_centrality', 'betweenness_centrality', 'eigenvector_centrality', 'clustering_coefficient', 'modularity', 'rich_club_coefficient', 'participation_coefficient', 'connected_components', 'minimum_spanning_tree', 'cut_vertices', 'biconnected_components']:        
        # 比较 s3
        t_stat, p_value = compare_analysis(metrics, 'sham', 's3', condition, 's3', graph_property)
        print(f"{condition} S3 vs Sham S3 - {graph_property}: T-statistic: {t_stat}, P-value: {p_value}")
# Out:
# S_3:
# tacs6 S3 vs Sham S3 - degree_centrality: T-statistic: -2.0602506440232715, P-value: 0.04626999476671034
# tacs6 S3 vs Sham S3 - betweenness_centrality: T-statistic: -0.3997628469032947, P-value: 0.6915694611710117
# tacs6 S3 vs Sham S3 - eigenvector_centrality: T-statistic: -0.3996234782827134, P-value: 0.6916712545764965
# tacs6 S3 vs Sham S3 - clustering_coefficient: T-statistic: -1.380811372635762, P-value: 0.1754047158218267
# tacs6 S3 vs Sham S3 - modularity: T-statistic: -0.1726794677853347, P-value: 0.863819848159049
# tacs6 S3 vs Sham S3 - rich_club_coefficient: T-statistic: 1.4256044064355118, P-value: 0.16397488260041568
# tacs6 S3 vs Sham S3 - participation_coefficient: T-statistic: -0.36116290794165196, P-value: 0.7199779511696873
# tacs6 S3 vs Sham S3 - connected_components: T-statistic: nan, P-value: nan
# tacs6 S3 vs Sham S3 - minimum_spanning_tree: T-statistic: 2.2783036140342814, P-value: 0.02841773320474008
# tacs6 S3 vs Sham S3 - cut_vertices: T-statistic: nan, P-value: nan
# tacs6 S3 vs Sham S3 - biconnected_components: T-statistic: nan, P-value: nan
# tacs10 S3 vs Sham S3 - degree_centrality: T-statistic: -1.1626591315098858, P-value: 0.2522176345237417
# tacs10 S3 vs Sham S3 - betweenness_centrality: T-statistic: -0.4260679192039501, P-value: 0.6724621525785721
# tacs10 S3 vs Sham S3 - eigenvector_centrality: T-statistic: 0.8195045006920748, P-value: 0.4176091203293718
# tacs10 S3 vs Sham S3 - clustering_coefficient: T-statistic: -0.6093160411580772, P-value: 0.5459410378094887
# tacs10 S3 vs Sham S3 - modularity: T-statistic: -1.6267767303196805, P-value: 0.11204983598763599
# tacs10 S3 vs Sham S3 - rich_club_coefficient: T-statistic: 1.3973308036249585, P-value: 0.17192823279015115
# tacs10 S3 vs Sham S3 - participation_coefficient: T-statistic: -0.8944398972610802, P-value: 0.37671705875844175
# tacs10 S3 vs Sham S3 - connected_components: T-statistic: nan, P-value: nan
# tacs10 S3 vs Sham S3 - minimum_spanning_tree: T-statistic: 0.980188158103966, P-value: 0.33319283821205026
# tacs10 S3 vs Sham S3 - cut_vertices: T-statistic: nan, P-value: nan
# tacs10 S3 vs Sham S3 - biconnected_components: T-statistic: nan, P-value: nan
# tdcs S3 vs Sham S3 - degree_centrality: T-statistic: -1.5671920467785438, P-value: 0.1253604696814206
# tdcs S3 vs Sham S3 - betweenness_centrality: T-statistic: -1.5810999455902706, P-value: 0.12214405518750124
# tdcs S3 vs Sham S3 - eigenvector_centrality: T-statistic: 1.3026337446291156, P-value: 0.20053930385353594
# tdcs S3 vs Sham S3 - clustering_coefficient: T-statistic: -0.6629158780618433, P-value: 0.511385798044313
# tdcs S3 vs Sham S3 - modularity: T-statistic: -1.4969880221095997, P-value: 0.14265713673579178
# tdcs S3 vs Sham S3 - rich_club_coefficient: T-statistic: 1.8150745998589848, P-value: 0.07952233635015997
# tdcs S3 vs Sham S3 - participation_coefficient: T-statistic: -0.6137799325335473, P-value: 0.5430178559626284
# tdcs S3 vs Sham S3 - connected_components: T-statistic: nan, P-value: nan
# tdcs S3 vs Sham S3 - minimum_spanning_tree: T-statistic: 3.6259014941782586, P-value: 0.00084181547976624
# tdcs S3 vs Sham S3 - cut_vertices: T-statistic: nan, P-value: nan
# tdcs S3 vs Sham S3 - biconnected_components: T-statistic: nan, P-value: nan
# /var/folders/5h/x_p7ky7d4ts4dz4c7g75h28c0000gn/T/ipykernel_28369/2622518207.py:13: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   t_stat, p_value = ttest_ind(data1, data2)
