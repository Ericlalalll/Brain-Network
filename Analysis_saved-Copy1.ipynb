# %%
import scipy.io
import numpy as np
import networkx as nx
import os
import json
import time   #预估运行时间(可删除)
from scipy.stats import ttest_ind, ttest_rel

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/5h/x_p7ky7d4ts4dz4c7g75h28c0000gn/T/ipykernel_3285/1115058941.py in <module>
# ----> 1 print(nx.__version__)
#
# NameError: name 'nx' is not defined

# %%
# 储存文件路径
folder_path = '/Users/shenxiaoyu/Desktop/FC'

file_paths = [
    'shamfc_s1.mat', 'shamfc_s2.mat', 'shamfc_s3.mat',
    'tacs6fc_s1.mat', 'tacs6fc_s2.mat', 'tacs6fc_s3.mat',
    'tacs10fc_s1.mat', 'tacs10fc_s2.mat', 'tacs10fc_s3.mat',
    'tdcsfc_s1.mat', 'tdcsfc_s2.mat', 'tdcsfc_s3.mat'
]


# preprocessing brain data
def data_preprocessing(matrix, fc_threshold=0.5, zfc_threshold=1.5):
    # matrix = np.where(np.isinf(matrix), np.nan, matrix)  # Replace infinite values with NaN
    
    # Apply threshold to create a binary adjacency matrix
    threshold = zfc_threshold if 'zfc' in file_path.lower() else fc_threshold
    binary_weighted_matrix = np.where(matrix >= fc_threshold, matrix, 0)
    
    # Remove self-loops
    np.fill_diagonal(binary_weighted_matrix, 0)
    
    return binary_weighted_matrix


# Function to save metrics
def save_metrics(metrics, filename='metrics.json'):
    with open(filename, 'w') as f:
        json.dump(metrics, f)

# Function to load metrics
def load_metrics(filename='metrics.json'):
    if os.path.exists(filename):
        with open(filename, 'r') as f:
            return json.load(f)
    return {}

def clear_specific_property_from_metrics(property_name, filename='metrics.json'):
    if os.path.exists(filename):
        with open(filename, 'r') as f:
            metrics = json.load(f)
        for graph_id in metrics:
            if property_name in metrics[graph_id]:
                del metrics[graph_id][property_name]
        with open(filename, 'w') as f:
            json.dump(metrics, f)
    else:
        print("Metrics file not found.")

# Clear specific property before recomputing
#clear_specific_property_from_metrics('rich_club_coefficient')

#clear_specific_property_from_metrics('participation_coefficient')
# Function to delete the metrics file
def delete_metrics_file(filename='metrics.json'):
    if os.path.exists(filename):
        os.remove(filename)

# Delete the metrics file before recomputing
delete_metrics_file()

# 创建一个dict来存储每种条件下的graph
graphs = {
    'sham': {'s1': [], 's2': [], 's3': []},
    'tacs6': {'s1': [], 's2': [], 's3': []},
    'tacs10': {'s1': [], 's2': [], 's3': []},
    'tdcs': {'s1': [], 's2': [], 's3': []}
}

# 读取文件里的matrix和提取ZFC
for file_name in file_paths:
    file_path = os.path.join(folder_path, file_name)
    mat = scipy.io.loadmat(file_path)
    key = [k for k in mat.keys() if not k.startswith('__')][0]  # 提取主要数据的key
    matrix = mat[key]
    
    # condition是刺激类型, time_point对应刺激前中后
    base_name = file_name.replace('.mat', '')
    parts = base_name.split('_')
    if len(parts) == 2:
        condition_time, time_point = parts
        if 'zfc' in condition_time:
            condition = condition_time.replace('zfc', '')
            matrix_type = 'zfc'
        else:
            condition = condition_time.replace('fc', '')
            matrix_type = 'fc'
    else:
        condition, matrix_type, time_point = parts

    
    if matrix_type == 'fc':
        # 将其转换为graph
        for i in range(matrix.shape[0]):
            adj_matrix_binary = data_preprocessing(matrix[i])
            G = nx.from_numpy_matrix(adj_matrix_binary)
            graphs[condition][time_point].append(G)

# %%
# WhitakerLab. (n.d.). Scona: Structural Covariance Networks. Retrieved [date], from https://whitakerlab.github.io/scona/_modules/scona/graph_measures.html
def participation_coefficient(G, module_partition):
    """ Calculate the participation coefficient for each node in the graph. """
    pc_dict = {}

    for m in module_partition.keys():
        M = set(module_partition[m])
        for v in M:
            degree = float(nx.degree(G=G, nbunch=v))
            if degree == 0:
                pc_dict[v] = 0
                continue

            wm_degree = float(sum([1 for u in M if (u, v) in G.edges()]))
            pc_dict[v] = 1 - ((float(wm_degree) / float(degree))**2)

    return pc_dict

# %%
# 定义所需要计算的graph property
def compute_graph_metrics(G, existing_metrics=None):
    
    metrics = existing_metrics if existing_metrics else {}
    
    if 'degree_centrality' not in metrics:
        metrics['degree_centrality'] = np.mean(list(nx.degree_centrality(G).values()))
        
    if 'betweenness_centrality' not in metrics:
        metrics['betweenness_centrality'] = np.mean(list(nx.betweenness_centrality(G, weight='weight').values()))
        
    if 'eigenvector_centrality' not in metrics:
        metrics['eigenvector_centrality'] = np.mean(list(nx.eigenvector_centrality(G, max_iter=10000, weight='weight').values()))
        
    if 'clustering_coefficient' not in metrics:
        metrics['clustering_coefficient'] = nx.average_clustering(G, weight='weight')
        
    if 'modularity' not in metrics:
        communities = list(nx.community.greedy_modularity_communities(G, weight='weight'))
        metrics['modularity'] = nx.algorithms.community.quality.modularity(G, communities, weight='weight')
        
    if 'rich_club_coefficient' not in metrics:
        try:
            rich_club = nx.rich_club_coefficient(G)
            avg_rich_club_coefficient = np.mean([v for v in rich_club.values() if v is not None])
        except ZeroDivisionError:
            avg_rich_club_coefficient = None
        metrics['rich_club_coefficient'] = avg_rich_club_coefficient
        
    if 'participation_coefficient' not in metrics:
        communities = list(nx.community.greedy_modularity_communities(G, weight='weight'))
        module_partition = {i: list(c) for i, c in enumerate(communities)}
        pc = participation_coefficient(G, module_partition)
        metrics['participation_coefficient'] = np.mean(list(pc.values()))
        
    if 'path_length' not in metrics:
        components = list(nx.connected_components(G))
        component_lengths = []
        for component in components:
            subgraph = G.subgraph(component)
            if len(component) > 1:  # Ensure the component has more than one node
                length = nx.average_shortest_path_length(subgraph, weight='weight')
                component_lengths.append(length)
        avg_length = np.mean(component_lengths)
        metrics['path_length'] = avg_length
                                                           
    if 'connected_components' not in metrics:
        metrics['connected_components'] = nx.number_connected_components(G)
                                                           
    if 'minimum_spanning_tree' not in metrics:
        if nx.is_connected(G):
            metrics['minimum_spanning_tree'] = nx.minimum_spanning_tree(G, weight='weight').size(weight='weight')
        else:
            mst_edges = nx.minimum_spanning_edges(G, weight='weight', data=False)
            mst_weight = sum(G[u][v]['weight'] for u, v in mst_edges)
            metrics['minimum_spanning_tree'] = mst_weight 
                                                           
    if 'cut_vertices' not in metrics:
        metrics['cut_vertices'] = len(list(nx.articulation_points(G)))
                                                           
    if 'biconnected_components' not in metrics:
        metrics['biconnected_components'] = len(list(nx.biconnected_components(G)))
    
        
    return metrics


# Store the computed metrics
metrics = load_metrics()

# 预估运行时间(可删除)
metrics_start_time = time.time()
total_graphs = sum(len(graphs[condition][time_point]) for condition in graphs for time_point in graphs[condition])
processed_graphs = 0

# Compute metrics for all graphs
for condition in graphs:
    for time_point in graphs[condition]:
        for idx, G in enumerate(graphs[condition][time_point]):
            graph_id = f"{condition}_{time_point}_{idx}"
            if graph_id not in metrics:
                metrics[graph_id] = compute_graph_metrics(G, metrics.get(graph_id, {}))
                
                
                # 预估运行时间(可删除)
                processed_graphs += 1
                elapsed_time = time.time() - metrics_start_time
                estimated_total_time = (elapsed_time / processed_graphs) * total_graphs
                remaining_time = estimated_total_time - elapsed_time
                print(f"Processed {processed_graphs}/{total_graphs} graphs. Estimated remaining time: {remaining_time:.2f} seconds.")

# Save the computed metrics
save_metrics(metrics)
# Out:
# Processed 1/252 graphs. Estimated remaining time: 1532.85 seconds.
# Processed 2/252 graphs. Estimated remaining time: 1401.05 seconds.
# Processed 3/252 graphs. Estimated remaining time: 1406.11 seconds.
# Processed 4/252 graphs. Estimated remaining time: 1873.95 seconds.
# Processed 5/252 graphs. Estimated remaining time: 1912.39 seconds.
# Processed 6/252 graphs. Estimated remaining time: 1857.24 seconds.
# Processed 7/252 graphs. Estimated remaining time: 1876.78 seconds.
# Processed 8/252 graphs. Estimated remaining time: 1776.72 seconds.
# Processed 9/252 graphs. Estimated remaining time: 1722.76 seconds.
# Processed 10/252 graphs. Estimated remaining time: 1671.85 seconds.
# Processed 11/252 graphs. Estimated remaining time: 1662.14 seconds.
# Processed 12/252 graphs. Estimated remaining time: 1663.43 seconds.
# Processed 13/252 graphs. Estimated remaining time: 1832.96 seconds.
# Processed 14/252 graphs. Estimated remaining time: 1775.60 seconds.
# Processed 15/252 graphs. Estimated remaining time: 1744.89 seconds.
# Processed 16/252 graphs. Estimated remaining time: 1811.08 seconds.
# Processed 17/252 graphs. Estimated remaining time: 1804.71 seconds.
# Processed 18/252 graphs. Estimated remaining time: 1781.54 seconds.
# Processed 19/252 graphs. Estimated remaining time: 1755.94 seconds.
# Processed 20/252 graphs. Estimated remaining time: 1696.15 seconds.
# Processed 21/252 graphs. Estimated remaining time: 1687.36 seconds.
# Processed 22/252 graphs. Estimated remaining time: 1676.30 seconds.
# Processed 23/252 graphs. Estimated remaining time: 1638.29 seconds.
# Processed 24/252 graphs. Estimated remaining time: 1637.48 seconds.
# Processed 25/252 graphs. Estimated remaining time: 1685.19 seconds.
# Processed 26/252 graphs. Estimated remaining time: 1660.98 seconds.
# Processed 27/252 graphs. Estimated remaining time: 1652.32 seconds.
# Processed 28/252 graphs. Estimated remaining time: 1631.59 seconds.
# Processed 29/252 graphs. Estimated remaining time: 1622.90 seconds.
# Processed 30/252 graphs. Estimated remaining time: 1607.35 seconds.
# Processed 31/252 graphs. Estimated remaining time: 1591.63 seconds.
# Processed 32/252 graphs. Estimated remaining time: 1589.36 seconds.
# Processed 33/252 graphs. Estimated remaining time: 1594.41 seconds.
# Processed 34/252 graphs. Estimated remaining time: 1563.61 seconds.
# Processed 35/252 graphs. Estimated remaining time: 1556.19 seconds.
# Processed 36/252 graphs. Estimated remaining time: 1585.79 seconds.
# Processed 37/252 graphs. Estimated remaining time: 1586.28 seconds.
# Processed 38/252 graphs. Estimated remaining time: 1578.40 seconds.
# Processed 39/252 graphs. Estimated remaining time: 1568.40 seconds.
# Processed 40/252 graphs. Estimated remaining time: 1542.36 seconds.
# Processed 41/252 graphs. Estimated remaining time: 1520.32 seconds.
# Processed 42/252 graphs. Estimated remaining time: 1520.57 seconds.
# Processed 43/252 graphs. Estimated remaining time: 1505.28 seconds.
# Processed 44/252 graphs. Estimated remaining time: 1505.48 seconds.
# Processed 45/252 graphs. Estimated remaining time: 1499.34 seconds.
# Processed 46/252 graphs. Estimated remaining time: 1474.12 seconds.
# Processed 47/252 graphs. Estimated remaining time: 1457.87 seconds.
# Processed 48/252 graphs. Estimated remaining time: 1447.47 seconds.
# Processed 49/252 graphs. Estimated remaining time: 1442.93 seconds.
# Processed 50/252 graphs. Estimated remaining time: 1429.78 seconds.
# Processed 51/252 graphs. Estimated remaining time: 1410.30 seconds.
# Processed 52/252 graphs. Estimated remaining time: 1406.27 seconds.
# Processed 53/252 graphs. Estimated remaining time: 1426.40 seconds.
# Processed 54/252 graphs. Estimated remaining time: 1407.35 seconds.
# Processed 55/252 graphs. Estimated remaining time: 1400.85 seconds.
# Processed 56/252 graphs. Estimated remaining time: 1426.57 seconds.
# Processed 57/252 graphs. Estimated remaining time: 1449.04 seconds.
# Processed 58/252 graphs. Estimated remaining time: 1440.36 seconds.
# Processed 59/252 graphs. Estimated remaining time: 1434.46 seconds.
# Processed 60/252 graphs. Estimated remaining time: 1418.30 seconds.
# Processed 61/252 graphs. Estimated remaining time: 1411.60 seconds.
# Processed 62/252 graphs. Estimated remaining time: 1397.96 seconds.
# Processed 63/252 graphs. Estimated remaining time: 1389.47 seconds.
# Processed 64/252 graphs. Estimated remaining time: 1381.54 seconds.
# Processed 65/252 graphs. Estimated remaining time: 1379.67 seconds.
# Processed 66/252 graphs. Estimated remaining time: 1395.54 seconds.
# Processed 67/252 graphs. Estimated remaining time: 1389.71 seconds.
# Processed 68/252 graphs. Estimated remaining time: 1381.12 seconds.
# Processed 69/252 graphs. Estimated remaining time: 1379.52 seconds.
# Processed 70/252 graphs. Estimated remaining time: 1389.06 seconds.
# Processed 71/252 graphs. Estimated remaining time: 1384.05 seconds.
# Processed 72/252 graphs. Estimated remaining time: 1376.00 seconds.
# Processed 73/252 graphs. Estimated remaining time: 1372.56 seconds.
# Processed 74/252 graphs. Estimated remaining time: 1367.54 seconds.
# Processed 75/252 graphs. Estimated remaining time: 1360.54 seconds.
# Processed 76/252 graphs. Estimated remaining time: 1365.95 seconds.
# Processed 77/252 graphs. Estimated remaining time: 1351.05 seconds.
# Processed 78/252 graphs. Estimated remaining time: 1339.03 seconds.
# Processed 79/252 graphs. Estimated remaining time: 1325.29 seconds.
# Processed 80/252 graphs. Estimated remaining time: 1321.07 seconds.
# Processed 81/252 graphs. Estimated remaining time: 1306.97 seconds.
# Processed 82/252 graphs. Estimated remaining time: 1296.44 seconds.
# Processed 83/252 graphs. Estimated remaining time: 1286.40 seconds.
# Processed 84/252 graphs. Estimated remaining time: 1282.33 seconds.
# Processed 85/252 graphs. Estimated remaining time: 1274.47 seconds.
# Processed 86/252 graphs. Estimated remaining time: 1268.20 seconds.
# Processed 87/252 graphs. Estimated remaining time: 1261.65 seconds.
# Processed 88/252 graphs. Estimated remaining time: 1258.92 seconds.
# Processed 89/252 graphs. Estimated remaining time: 1256.22 seconds.
# Processed 90/252 graphs. Estimated remaining time: 1248.44 seconds.
# Processed 91/252 graphs. Estimated remaining time: 1241.11 seconds.
# Processed 92/252 graphs. Estimated remaining time: 1240.97 seconds.
# Processed 93/252 graphs. Estimated remaining time: 1236.12 seconds.
# Processed 94/252 graphs. Estimated remaining time: 1225.91 seconds.
# Processed 95/252 graphs. Estimated remaining time: 1217.34 seconds.
# Processed 96/252 graphs. Estimated remaining time: 1215.55 seconds.
# Processed 97/252 graphs. Estimated remaining time: 1206.66 seconds.
# Processed 98/252 graphs. Estimated remaining time: 1220.41 seconds.
# Processed 99/252 graphs. Estimated remaining time: 1208.87 seconds.
# Processed 100/252 graphs. Estimated remaining time: 1198.45 seconds.
# Processed 101/252 graphs. Estimated remaining time: 1187.12 seconds.
# Processed 102/252 graphs. Estimated remaining time: 1175.34 seconds.
# Processed 103/252 graphs. Estimated remaining time: 1162.64 seconds.
# Processed 104/252 graphs. Estimated remaining time: 1155.72 seconds.
# Processed 105/252 graphs. Estimated remaining time: 1148.76 seconds.
# Processed 106/252 graphs. Estimated remaining time: 1139.50 seconds.
# Processed 107/252 graphs. Estimated remaining time: 1128.25 seconds.
# Processed 108/252 graphs. Estimated remaining time: 1120.81 seconds.
# Processed 109/252 graphs. Estimated remaining time: 1118.88 seconds.
# Processed 110/252 graphs. Estimated remaining time: 1115.40 seconds.
# Processed 111/252 graphs. Estimated remaining time: 1107.25 seconds.
# Processed 112/252 graphs. Estimated remaining time: 1097.97 seconds.
# Processed 113/252 graphs. Estimated remaining time: 1095.66 seconds.
# Processed 114/252 graphs. Estimated remaining time: 1095.81 seconds.
# Processed 115/252 graphs. Estimated remaining time: 1091.15 seconds.
# Processed 116/252 graphs. Estimated remaining time: 1096.77 seconds.
# Processed 117/252 graphs. Estimated remaining time: 1086.31 seconds.
# Processed 118/252 graphs. Estimated remaining time: 1080.32 seconds.
# Processed 119/252 graphs. Estimated remaining time: 1070.67 seconds.
# Processed 120/252 graphs. Estimated remaining time: 1065.49 seconds.
# Processed 121/252 graphs. Estimated remaining time: 1058.61 seconds.
# Processed 122/252 graphs. Estimated remaining time: 1047.19 seconds.
# Processed 123/252 graphs. Estimated remaining time: 1036.08 seconds.
# Processed 124/252 graphs. Estimated remaining time: 1027.49 seconds.
# Processed 125/252 graphs. Estimated remaining time: 1016.49 seconds.
# Processed 126/252 graphs. Estimated remaining time: 1009.70 seconds.
# Processed 127/252 graphs. Estimated remaining time: 1000.79 seconds.
# Processed 128/252 graphs. Estimated remaining time: 994.02 seconds.
# Processed 129/252 graphs. Estimated remaining time: 984.10 seconds.
# Processed 130/252 graphs. Estimated remaining time: 974.17 seconds.
# Processed 131/252 graphs. Estimated remaining time: 965.14 seconds.
# Processed 132/252 graphs. Estimated remaining time: 957.13 seconds.
# Processed 133/252 graphs. Estimated remaining time: 951.43 seconds.
# Processed 134/252 graphs. Estimated remaining time: 941.05 seconds.
# Processed 135/252 graphs. Estimated remaining time: 929.91 seconds.
# Processed 136/252 graphs. Estimated remaining time: 921.11 seconds.
# Processed 137/252 graphs. Estimated remaining time: 914.61 seconds.
# Processed 138/252 graphs. Estimated remaining time: 903.81 seconds.
# Processed 139/252 graphs. Estimated remaining time: 894.98 seconds.
# Processed 140/252 graphs. Estimated remaining time: 886.84 seconds.
# Processed 141/252 graphs. Estimated remaining time: 877.33 seconds.
# Processed 142/252 graphs. Estimated remaining time: 869.13 seconds.
# Processed 143/252 graphs. Estimated remaining time: 860.22 seconds.
# Processed 144/252 graphs. Estimated remaining time: 851.09 seconds.
# Processed 145/252 graphs. Estimated remaining time: 845.66 seconds.
# Processed 146/252 graphs. Estimated remaining time: 835.29 seconds.
# Processed 147/252 graphs. Estimated remaining time: 828.74 seconds.
# Processed 148/252 graphs. Estimated remaining time: 824.89 seconds.
# Processed 149/252 graphs. Estimated remaining time: 815.64 seconds.
# Processed 150/252 graphs. Estimated remaining time: 807.67 seconds.
# Processed 151/252 graphs. Estimated remaining time: 799.97 seconds.
# Processed 152/252 graphs. Estimated remaining time: 792.59 seconds.
# Processed 153/252 graphs. Estimated remaining time: 787.11 seconds.
# Processed 154/252 graphs. Estimated remaining time: 784.30 seconds.
# Processed 155/252 graphs. Estimated remaining time: 775.43 seconds.
# Processed 156/252 graphs. Estimated remaining time: 765.50 seconds.
# Processed 157/252 graphs. Estimated remaining time: 758.85 seconds.
# Processed 158/252 graphs. Estimated remaining time: 751.22 seconds.
# Processed 159/252 graphs. Estimated remaining time: 745.56 seconds.
# Processed 160/252 graphs. Estimated remaining time: 736.59 seconds.
# Processed 161/252 graphs. Estimated remaining time: 727.89 seconds.
# Processed 162/252 graphs. Estimated remaining time: 719.64 seconds.
# Processed 163/252 graphs. Estimated remaining time: 710.32 seconds.
# Processed 164/252 graphs. Estimated remaining time: 701.33 seconds.
# Processed 165/252 graphs. Estimated remaining time: 696.31 seconds.
# Processed 166/252 graphs. Estimated remaining time: 688.32 seconds.
# Processed 167/252 graphs. Estimated remaining time: 681.87 seconds.
# Processed 168/252 graphs. Estimated remaining time: 672.29 seconds.
# Processed 169/252 graphs. Estimated remaining time: 663.94 seconds.
# Processed 170/252 graphs. Estimated remaining time: 660.80 seconds.
# Processed 171/252 graphs. Estimated remaining time: 651.80 seconds.
# Processed 172/252 graphs. Estimated remaining time: 644.33 seconds.
# Processed 173/252 graphs. Estimated remaining time: 635.50 seconds.
# Processed 174/252 graphs. Estimated remaining time: 626.84 seconds.
# Processed 175/252 graphs. Estimated remaining time: 618.99 seconds.
# Processed 176/252 graphs. Estimated remaining time: 611.08 seconds.
# Processed 177/252 graphs. Estimated remaining time: 603.36 seconds.
# Processed 178/252 graphs. Estimated remaining time: 595.38 seconds.
# Processed 179/252 graphs. Estimated remaining time: 586.19 seconds.
# Processed 180/252 graphs. Estimated remaining time: 578.97 seconds.
# Processed 181/252 graphs. Estimated remaining time: 574.89 seconds.
# Processed 182/252 graphs. Estimated remaining time: 566.14 seconds.
# Processed 183/252 graphs. Estimated remaining time: 558.29 seconds.
# Processed 184/252 graphs. Estimated remaining time: 550.44 seconds.
# Processed 185/252 graphs. Estimated remaining time: 541.86 seconds.
# Processed 186/252 graphs. Estimated remaining time: 532.94 seconds.
# Processed 187/252 graphs. Estimated remaining time: 524.93 seconds.
# Processed 188/252 graphs. Estimated remaining time: 516.71 seconds.
# Processed 189/252 graphs. Estimated remaining time: 509.11 seconds.
# Processed 190/252 graphs. Estimated remaining time: 500.80 seconds.
# Processed 191/252 graphs. Estimated remaining time: 497.31 seconds.
# Processed 192/252 graphs. Estimated remaining time: 491.22 seconds.
# Processed 193/252 graphs. Estimated remaining time: 484.63 seconds.
# Processed 194/252 graphs. Estimated remaining time: 476.56 seconds.
# Processed 195/252 graphs. Estimated remaining time: 467.99 seconds.
# Processed 196/252 graphs. Estimated remaining time: 459.81 seconds.
# Processed 197/252 graphs. Estimated remaining time: 451.25 seconds.
# Processed 198/252 graphs. Estimated remaining time: 442.90 seconds.
# Processed 199/252 graphs. Estimated remaining time: 434.15 seconds.
# Processed 200/252 graphs. Estimated remaining time: 425.42 seconds.
# Processed 201/252 graphs. Estimated remaining time: 416.94 seconds.
# Processed 202/252 graphs. Estimated remaining time: 407.95 seconds.
# Processed 203/252 graphs. Estimated remaining time: 399.84 seconds.
# Processed 204/252 graphs. Estimated remaining time: 391.50 seconds.
# Processed 205/252 graphs. Estimated remaining time: 384.26 seconds.
# Processed 206/252 graphs. Estimated remaining time: 376.13 seconds.
# Processed 207/252 graphs. Estimated remaining time: 367.59 seconds.
# Processed 208/252 graphs. Estimated remaining time: 358.87 seconds.
# Processed 209/252 graphs. Estimated remaining time: 350.87 seconds.
# Processed 210/252 graphs. Estimated remaining time: 342.05 seconds.
# Processed 211/252 graphs. Estimated remaining time: 334.35 seconds.
# Processed 212/252 graphs. Estimated remaining time: 326.63 seconds.
# Processed 213/252 graphs. Estimated remaining time: 318.00 seconds.
# Processed 214/252 graphs. Estimated remaining time: 309.75 seconds.
# Processed 215/252 graphs. Estimated remaining time: 301.32 seconds.
# Processed 216/252 graphs. Estimated remaining time: 292.88 seconds.
# Processed 217/252 graphs. Estimated remaining time: 284.56 seconds.
# Processed 218/252 graphs. Estimated remaining time: 276.29 seconds.
# Processed 219/252 graphs. Estimated remaining time: 268.25 seconds.
# Processed 220/252 graphs. Estimated remaining time: 259.66 seconds.
# Processed 221/252 graphs. Estimated remaining time: 251.29 seconds.
# Processed 222/252 graphs. Estimated remaining time: 242.73 seconds.
# Processed 223/252 graphs. Estimated remaining time: 234.68 seconds.
# Processed 224/252 graphs. Estimated remaining time: 226.73 seconds.
# Processed 225/252 graphs. Estimated remaining time: 218.95 seconds.
# Processed 226/252 graphs. Estimated remaining time: 211.08 seconds.
# Processed 227/252 graphs. Estimated remaining time: 202.86 seconds.
# Processed 228/252 graphs. Estimated remaining time: 194.41 seconds.
# Processed 229/252 graphs. Estimated remaining time: 186.89 seconds.
# Processed 230/252 graphs. Estimated remaining time: 178.42 seconds.
# Processed 231/252 graphs. Estimated remaining time: 170.40 seconds.
# Processed 232/252 graphs. Estimated remaining time: 162.34 seconds.
# Processed 233/252 graphs. Estimated remaining time: 154.11 seconds.
# Processed 234/252 graphs. Estimated remaining time: 146.10 seconds.
# Processed 235/252 graphs. Estimated remaining time: 137.91 seconds.
# Processed 236/252 graphs. Estimated remaining time: 129.98 seconds.
# Processed 237/252 graphs. Estimated remaining time: 121.71 seconds.
# Processed 238/252 graphs. Estimated remaining time: 113.60 seconds.
# Processed 239/252 graphs. Estimated remaining time: 105.80 seconds.
# Processed 240/252 graphs. Estimated remaining time: 97.62 seconds.
# Processed 241/252 graphs. Estimated remaining time: 89.50 seconds.
# Processed 242/252 graphs. Estimated remaining time: 81.24 seconds.
# Processed 243/252 graphs. Estimated remaining time: 73.07 seconds.
# Processed 244/252 graphs. Estimated remaining time: 64.96 seconds.
# Processed 245/252 graphs. Estimated remaining time: 57.23 seconds.
# Processed 246/252 graphs. Estimated remaining time: 49.09 seconds.
# Processed 247/252 graphs. Estimated remaining time: 40.87 seconds.
# Processed 248/252 graphs. Estimated remaining time: 32.65 seconds.
# Processed 249/252 graphs. Estimated remaining time: 24.49 seconds.
# Processed 250/252 graphs. Estimated remaining time: 16.33 seconds.
# Processed 251/252 graphs. Estimated remaining time: 8.16 seconds.
# Processed 252/252 graphs. Estimated remaining time: 0.00 seconds.

# %%
def compare_analysis(metrics, condition1, time_point1, condition2, time_point2, graph_property, paired=False):
    data1 = [metrics[f"{condition1}_{time_point1}_{i}"][graph_property] for i in range(20) if f"{condition1}_{time_point1}_{i}" in metrics and metrics[f"{condition1}_{time_point1}_{i}"].get(graph_property) is not None]
    data2 = [metrics[f"{condition2}_{time_point2}_{i}"][graph_property] for i in range(20) if f"{condition2}_{time_point2}_{i}" in metrics and metrics[f"{condition2}_{time_point2}_{i}"].get(graph_property) is not None]
    
    # Filter out None values
    data1 = [x for x in data1 if x is not None]
    data2 = [x for x in data2 if x is not None]
    
    if len(data1) > 0 and len(data2) > 0:
        if paired:
            t_stat, p_value = ttest_rel(data1, data2)
        else:
            t_stat, p_value = ttest_ind(data1, data2)
    else:
        t_stat, p_value = None, None
    return t_stat, p_value

# %%
# 1. 验证四组s1相似性 
print("S_1:")
for condition in ['tacs6', 'tacs10', 'tdcs']:
    for graph_property in ['degree_centrality', 'betweenness_centrality', 'eigenvector_centrality', 'clustering_coefficient', 'modularity', 'rich_club_coefficient', 'participation_coefficient', 'path_length', 'connected_components', 'minimum_spanning_tree', 'cut_vertices', 'biconnected_components', 'path_length']:
        t_stat, p_value = compare_analysis(metrics, 'sham', 's1', condition, 's1', graph_property)
        print(f"Sham S1 vs {condition} S1 - {graph_property}: T-statistic: {t_stat}, P-value: {p_value}")
# Out:
# S_1:
# Sham S1 vs tacs6 S1 - degree_centrality: T-statistic: -1.356238985597168, P-value: 0.18302745841402832
# Sham S1 vs tacs6 S1 - betweenness_centrality: T-statistic: 0.5166641707294843, P-value: 0.6083846645652429
# Sham S1 vs tacs6 S1 - eigenvector_centrality: T-statistic: 0.580435842100867, P-value: 0.5650471838419071
# Sham S1 vs tacs6 S1 - clustering_coefficient: T-statistic: -1.8530498345070596, P-value: 0.07165263344467601
# Sham S1 vs tacs6 S1 - modularity: T-statistic: 0.029343902043755518, P-value: 0.9767438889378435
# Sham S1 vs tacs6 S1 - rich_club_coefficient: T-statistic: 0.2224669619051357, P-value: 0.8264551600320729
# Sham S1 vs tacs6 S1 - participation_coefficient: T-statistic: -0.4278435467158241, P-value: 0.6711800982587
# Sham S1 vs tacs6 S1 - path_length: T-statistic: -0.2283851480391083, P-value: 0.8205714169551995
# Sham S1 vs tacs6 S1 - connected_components: T-statistic: 1.7650809469888495, P-value: 0.08558613728311856
# Sham S1 vs tacs6 S1 - minimum_spanning_tree: T-statistic: -1.6967442510746593, P-value: 0.09792305637042835
# Sham S1 vs tacs6 S1 - cut_vertices: T-statistic: 2.7686802746401438, P-value: 0.00865350269012977
# Sham S1 vs tacs6 S1 - biconnected_components: T-statistic: 2.5470523302291848, P-value: 0.015034953245150747
# Sham S1 vs tacs6 S1 - path_length: T-statistic: -0.2283851480391083, P-value: 0.8205714169551995
# Sham S1 vs tacs10 S1 - degree_centrality: T-statistic: 0.2326148277276969, P-value: 0.817308861263633
# Sham S1 vs tacs10 S1 - betweenness_centrality: T-statistic: -0.11958072137068756, P-value: 0.905445273194602
# Sham S1 vs tacs10 S1 - eigenvector_centrality: T-statistic: 0.4378222235965532, P-value: 0.6639937972504268
# Sham S1 vs tacs10 S1 - clustering_coefficient: T-statistic: -0.5414091845995019, P-value: 0.5913859103476771
# Sham S1 vs tacs10 S1 - modularity: T-statistic: -0.820864622894744, P-value: 0.4168434302598609
# Sham S1 vs tacs10 S1 - rich_club_coefficient: T-statistic: 0.5706204440187382, P-value: 0.5761838727953404
# Sham S1 vs tacs10 S1 - participation_coefficient: T-statistic: 0.6479511636495999, P-value: 0.5209125904343987
# Sham S1 vs tacs10 S1 - path_length: T-statistic: -0.005121837668750481, P-value: 0.9959401774499244
# Sham S1 vs tacs10 S1 - connected_components: T-statistic: 0.5610990957189954, P-value: 0.5780240160312
# Sham S1 vs tacs10 S1 - minimum_spanning_tree: T-statistic: -0.5306375618629326, P-value: 0.5987576649065943
# Sham S1 vs tacs10 S1 - cut_vertices: T-statistic: 0.6834178665606546, P-value: 0.49848899577487005
# Sham S1 vs tacs10 S1 - biconnected_components: T-statistic: 0.5725050374805953, P-value: 0.5703518821101642
# Sham S1 vs tacs10 S1 - path_length: T-statistic: -0.005121837668750481, P-value: 0.9959401774499244
# Sham S1 vs tdcs S1 - degree_centrality: T-statistic: -0.16751828646900654, P-value: 0.8678506002296278
# Sham S1 vs tdcs S1 - betweenness_centrality: T-statistic: -0.08989385665358786, P-value: 0.9288437150486013
# Sham S1 vs tdcs S1 - eigenvector_centrality: T-statistic: 0.7384635198832525, P-value: 0.4647695306680135
# Sham S1 vs tdcs S1 - clustering_coefficient: T-statistic: -0.7541243006024446, P-value: 0.455422540558723
# Sham S1 vs tdcs S1 - modularity: T-statistic: -0.9967829699177115, P-value: 0.3251751477750888
# Sham S1 vs tdcs S1 - rich_club_coefficient: T-statistic: -0.4592940560918809, P-value: 0.6512344234306461
# Sham S1 vs tdcs S1 - participation_coefficient: T-statistic: 0.606894971464822, P-value: 0.5475298636949302
# Sham S1 vs tdcs S1 - path_length: T-statistic: -0.05054990527548301, P-value: 0.9599489645972269
# Sham S1 vs tdcs S1 - connected_components: T-statistic: 0.667724196183168, P-value: 0.5083449379849218
# Sham S1 vs tdcs S1 - minimum_spanning_tree: T-statistic: -0.6090198998877759, P-value: 0.546135252719661
# Sham S1 vs tdcs S1 - cut_vertices: T-statistic: 1.3126441655710002, P-value: 0.19717584306742972
# Sham S1 vs tdcs S1 - biconnected_components: T-statistic: 1.1768618024044593, P-value: 0.24657000138643345
# Sham S1 vs tdcs S1 - path_length: T-statistic: -0.05054990527548301, P-value: 0.9599489645972269

# %%
# 2. 验证真实刺激的s2与sham组的对比
print("S_2:")
for condition in ['tacs6', 'tacs10', 'tdcs']:
    for graph_property in ['degree_centrality', 'betweenness_centrality', 'eigenvector_centrality', 'clustering_coefficient', 'modularity', 'rich_club_coefficient', 'participation_coefficient', 'path_length', 'connected_components', 'minimum_spanning_tree', 'cut_vertices', 'biconnected_components', 'path_length']:
        # 比较 s2
        t_stat, p_value = compare_analysis(metrics, 'sham', 's2', condition, 's2', graph_property)
        print(f"{condition} S2 vs Sham S2 - {graph_property}: T-statistic: {t_stat}, P-value: {p_value}")
# Out:
# S_2:
# tacs6 S2 vs Sham S2 - degree_centrality: T-statistic: -1.610131470067859, P-value: 0.11564616832232982
# tacs6 S2 vs Sham S2 - betweenness_centrality: T-statistic: 1.3131529559045905, P-value: 0.19700604505660846
# tacs6 S2 vs Sham S2 - eigenvector_centrality: T-statistic: -1.2256022785251577, P-value: 0.227890320941281
# tacs6 S2 vs Sham S2 - clustering_coefficient: T-statistic: -1.5010242810287713, P-value: 0.14161353425746148
# tacs6 S2 vs Sham S2 - modularity: T-statistic: 0.13560666418630687, P-value: 0.8928480550199416
# tacs6 S2 vs Sham S2 - rich_club_coefficient: T-statistic: 1.6205502359686261, P-value: 0.1187450945476144
# tacs6 S2 vs Sham S2 - participation_coefficient: T-statistic: -0.5020911578964928, P-value: 0.6185004893962899
# tacs6 S2 vs Sham S2 - path_length: T-statistic: 0.07019983560539199, P-value: 0.9444027469419529
# tacs6 S2 vs Sham S2 - connected_components: T-statistic: 1.0713214601305328, P-value: 0.29078221808837657
# tacs6 S2 vs Sham S2 - minimum_spanning_tree: T-statistic: -0.7989841218431037, P-value: 0.4292654742813007
# tacs6 S2 vs Sham S2 - cut_vertices: T-statistic: 1.8713374993724414, P-value: 0.0690121825795821
# tacs6 S2 vs Sham S2 - biconnected_components: T-statistic: 1.8759605170415807, P-value: 0.06835800282263413
# tacs6 S2 vs Sham S2 - path_length: T-statistic: 0.07019983560539199, P-value: 0.9444027469419529
# tacs10 S2 vs Sham S2 - degree_centrality: T-statistic: -0.5518046212440769, P-value: 0.5843129930976989
# tacs10 S2 vs Sham S2 - betweenness_centrality: T-statistic: 0.0243359510379096, P-value: 0.9807119856875604
# tacs10 S2 vs Sham S2 - eigenvector_centrality: T-statistic: 0.04914884543682068, P-value: 0.9610581037956556
# tacs10 S2 vs Sham S2 - clustering_coefficient: T-statistic: -1.332675512308243, P-value: 0.19057458437345035
# tacs10 S2 vs Sham S2 - modularity: T-statistic: -0.25584573335735517, P-value: 0.7994498651637315
# tacs10 S2 vs Sham S2 - rich_club_coefficient: T-statistic: 0.2392627704163643, P-value: 0.8136049983920624
# tacs10 S2 vs Sham S2 - participation_coefficient: T-statistic: 0.528782709241467, P-value: 0.6000314287575699
# tacs10 S2 vs Sham S2 - path_length: T-statistic: -0.8456937688652896, P-value: 0.40301751545439746
# tacs10 S2 vs Sham S2 - connected_components: T-statistic: 0.0, P-value: 1.0
# tacs10 S2 vs Sham S2 - minimum_spanning_tree: T-statistic: -0.022342559087072656, P-value: 0.9822916122223702
# tacs10 S2 vs Sham S2 - cut_vertices: T-statistic: 0.8006796813614421, P-value: 0.4282949386320425
# tacs10 S2 vs Sham S2 - biconnected_components: T-statistic: 0.7936502089660389, P-value: 0.4323272534974625
# tacs10 S2 vs Sham S2 - path_length: T-statistic: -0.8456937688652896, P-value: 0.40301751545439746
# tdcs S2 vs Sham S2 - degree_centrality: T-statistic: 0.23158558505246005, P-value: 0.8181024651562777
# tdcs S2 vs Sham S2 - betweenness_centrality: T-statistic: -0.9327014479971699, P-value: 0.35686283360260107
# tdcs S2 vs Sham S2 - eigenvector_centrality: T-statistic: 0.7111065931219207, P-value: 0.4813605884155314
# tdcs S2 vs Sham S2 - clustering_coefficient: T-statistic: -0.4882574306580506, P-value: 0.6281732448043658
# tdcs S2 vs Sham S2 - modularity: T-statistic: -0.822216067795115, P-value: 0.4160834785079035
# tdcs S2 vs Sham S2 - rich_club_coefficient: T-statistic: -1.3445438909232383, P-value: 0.19382458371670175
# tdcs S2 vs Sham S2 - participation_coefficient: T-statistic: -0.24387282765754745, P-value: 0.8086411984237287
# tdcs S2 vs Sham S2 - path_length: T-statistic: -0.7088193204919503, P-value: 0.4827627780062831
# tdcs S2 vs Sham S2 - connected_components: T-statistic: 0.38015018899283887, P-value: 0.7059505451434367
# tdcs S2 vs Sham S2 - minimum_spanning_tree: T-statistic: -0.53500744075124, P-value: 0.5957618350553495
# tdcs S2 vs Sham S2 - cut_vertices: T-statistic: 0.9195623490089209, P-value: 0.36360222864415426
# tdcs S2 vs Sham S2 - biconnected_components: T-statistic: 1.0076733319264564, P-value: 0.3199850298277215
# tdcs S2 vs Sham S2 - path_length: T-statistic: -0.7088193204919503, P-value: 0.4827627780062831

# %%
# 2. 验证真实刺激的s3与sham组的对比
print("S_3:")
for condition in ['tacs6', 'tacs10', 'tdcs']:
    for graph_property in ['degree_centrality', 'betweenness_centrality', 'eigenvector_centrality', 'clustering_coefficient', 'modularity', 'rich_club_coefficient', 'participation_coefficient', 'path_length', 'connected_components', 'minimum_spanning_tree', 'cut_vertices', 'biconnected_components']:        
        # 比较 s3
        t_stat, p_value = compare_analysis(metrics, 'sham', 's3', condition, 's3', graph_property)
        print(f"{condition} S3 vs Sham S3 - {graph_property}: T-statistic: {t_stat}, P-value: {p_value}")
# Out:
# S_3:
# tacs6 S3 vs Sham S3 - degree_centrality: T-statistic: -1.4410785163725837, P-value: 0.15775262634705217
# tacs6 S3 vs Sham S3 - betweenness_centrality: T-statistic: 0.33476293924078254, P-value: 0.7396447915062847
# tacs6 S3 vs Sham S3 - eigenvector_centrality: T-statistic: -0.6784223827779217, P-value: 0.5016147550072982
# tacs6 S3 vs Sham S3 - clustering_coefficient: T-statistic: -1.1327823043353418, P-value: 0.26440275718427203
# tacs6 S3 vs Sham S3 - modularity: T-statistic: 2.064614185387995, P-value: 0.04583312153398437
# tacs6 S3 vs Sham S3 - rich_club_coefficient: T-statistic: -0.7499614061201181, P-value: 0.46246422303375323
# tacs6 S3 vs Sham S3 - participation_coefficient: T-statistic: -2.0955052339757057, P-value: 0.04284239934843639
# tacs6 S3 vs Sham S3 - path_length: T-statistic: -1.5923230720460275, P-value: 0.11959771153456851
# tacs6 S3 vs Sham S3 - connected_components: T-statistic: 2.1629533091032114, P-value: 0.036902118690777294
# tacs6 S3 vs Sham S3 - minimum_spanning_tree: T-statistic: -2.0877720197608123, P-value: 0.04357454380803942
# tacs6 S3 vs Sham S3 - cut_vertices: T-statistic: 1.5511599926023072, P-value: 0.1291529243209923
# tacs6 S3 vs Sham S3 - biconnected_components: T-statistic: 1.9446023945234543, P-value: 0.05925185995576107
# tacs10 S3 vs Sham S3 - degree_centrality: T-statistic: -0.1141359362252944, P-value: 0.9097309614055367
# tacs10 S3 vs Sham S3 - betweenness_centrality: T-statistic: -0.10330053387432118, P-value: 0.9182677070773164
# tacs10 S3 vs Sham S3 - eigenvector_centrality: T-statistic: 0.3840333643896145, P-value: 0.70309429779535
# tacs10 S3 vs Sham S3 - clustering_coefficient: T-statistic: -1.136892332714059, P-value: 0.2627018881140127
# tacs10 S3 vs Sham S3 - modularity: T-statistic: -1.0676908443199098, P-value: 0.2923962276031929
# tacs10 S3 vs Sham S3 - rich_club_coefficient: T-statistic: 0.29494422386122693, P-value: 0.7708018892070568
# tacs10 S3 vs Sham S3 - participation_coefficient: T-statistic: 0.030273296116085393, P-value: 0.9760075376500668
# tacs10 S3 vs Sham S3 - path_length: T-statistic: -0.7443812232520511, P-value: 0.46122462133872755
# tacs10 S3 vs Sham S3 - connected_components: T-statistic: 1.6038105174343316, P-value: 0.11703634669372275
# tacs10 S3 vs Sham S3 - minimum_spanning_tree: T-statistic: -1.3818811586947033, P-value: 0.1750785292688205
# tacs10 S3 vs Sham S3 - cut_vertices: T-statistic: 1.6774971044017062, P-value: 0.10165339002172584
# tacs10 S3 vs Sham S3 - biconnected_components: T-statistic: 1.8057361455336627, P-value: 0.07888609938712383
# tdcs S3 vs Sham S3 - degree_centrality: T-statistic: -0.40732235342278683, P-value: 0.6860568033024137
# tdcs S3 vs Sham S3 - betweenness_centrality: T-statistic: -0.4189635868635685, P-value: 0.6776015677784109
# tdcs S3 vs Sham S3 - eigenvector_centrality: T-statistic: 0.259800719098893, P-value: 0.7964199773770713
# tdcs S3 vs Sham S3 - clustering_coefficient: T-statistic: -0.7459777158555755, P-value: 0.4602709643735553
# tdcs S3 vs Sham S3 - modularity: T-statistic: 0.48113324030720545, P-value: 0.6331807613777469
# tdcs S3 vs Sham S3 - rich_club_coefficient: T-statistic: -0.571250042228264, P-value: 0.5738936519996238
# tdcs S3 vs Sham S3 - participation_coefficient: T-statistic: -1.4962751548509434, P-value: 0.14284208970540968
# tdcs S3 vs Sham S3 - path_length: T-statistic: -1.8612708503859146, P-value: 0.0704551807342649
# tdcs S3 vs Sham S3 - connected_components: T-statistic: 1.7477220643825637, P-value: 0.0885893268610903
# tdcs S3 vs Sham S3 - minimum_spanning_tree: T-statistic: -1.659401287623093, P-value: 0.10526713772900873
# tdcs S3 vs Sham S3 - cut_vertices: T-statistic: 1.6062534959893593, P-value: 0.11649744882916867
# tdcs S3 vs Sham S3 - biconnected_components: T-statistic: 1.8907110659487933, P-value: 0.06630605355571621
