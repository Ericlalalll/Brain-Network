# %%
import time
import scipy.io
import numpy as np
import networkx as nx
import os
from scipy.stats import ttest_rel, ttest_ind

# 记录开始时间
start_time = time.time()

# 定义文件路径列表
folder_path = '/Users/shenxiaoyu/Desktop/Brain data'
file_paths = [
    'shamfc_s1.mat', 'shamfc_s2.mat', 'shamfc_s3.mat',
    'shamzfc_s1.mat', 'shamzfc_s2.mat', 'shamzfc_s3.mat',
    'tacs6fc_s1.mat', 'tacs6fc_s2.mat', 'tacs6fc_s3.mat',
    'tacs6zfc_s1.mat', 'tacs6zfc_s2.mat', 'tacs6zfc_s3.mat',
    'tacs10fc_s1.mat', 'tacs10fc_s2.mat', 'tacs10fc_s3.mat',
    'tacs10zfc_s1.mat', 'tacs10zfc_s2.mat', 'tacs10zfc_s3.mat',
    'tdcsfc_s1.mat', 'tdcsfc_s2.mat', 'tdcsfc_s3.mat',
    'tdcszfc_s1.mat', 'tdcszfc_s2.mat', 'tdcszfc_s3.mat'
]

# 创建一个字典来存储每种条件下的图
graphs = {
    'sham': {'s1': [], 's2': [], 's3': []},
    'tacs6': {'s1': [], 's2': [], 's3': []},
    'tacs10': {'s1': [], 's2': [], 's3': []},
    'tdcs': {'s1': [], 's2': [], 's3': []}
}

total_files = len(file_paths)
processed_files = 0

# 数据预处理：读取文件并提取 zfc 矩阵
for file_name in file_paths:
    file_path = os.path.join(folder_path, file_name)
    mat = scipy.io.loadmat(file_path)
    key = [k for k in mat.keys() if not k.startswith('__')][0]
    matrix = mat[key]
    
    
    
    # 获取条件和时间点信息
    base_name = file_name.replace('.mat', '')
    parts = base_name.split('_')
    if len(parts) == 2:
        condition_time, time_point = parts
        if 'zfc' in condition_time:
            condition = condition_time.replace('zfc', '')
            matrix_type = 'zfc'
        else:
            condition = condition_time.replace('fc', '')
            matrix_type = 'fc'
    else:
        condition, matrix_type, time_point = parts

   
    
    if matrix_type == 'zfc':
        # 转换为图结构并存储
        for i in range(matrix.shape[0]):
            adj_matrix = matrix[i]
            G = nx.from_numpy_matrix(adj_matrix)
            graphs[condition][time_point].append(G)
           
    
    # 更新处理文件的计数
    processed_files += 1
    
    # 计算并打印已处理文件的时间和估计剩余时间
    elapsed_time = time.time() - start_time
    estimated_total_time = (elapsed_time / processed_files) * total_files
    remaining_time = estimated_total_time - elapsed_time
    print(f"Processed {processed_files}/{total_files} files. Estimated remaining time: {remaining_time:.2f} seconds.")



# 定义函数计算图论指标
def compute_graph_metrics(G):
    degree_centrality = np.mean(list(nx.degree_centrality(G).values()))
    betweenness_centrality = np.mean(list(nx.betweenness_centrality(G).values()))
    eigenvector_centrality = np.mean(list(nx.eigenvector_centrality(G).values()))
    clustering_coefficient = nx.average_clustering(G)
    modularity = nx.algorithms.community.quality.modularity(G, nx.community.greedy_modularity_communities(G))
    connected_components = nx.number_connected_components(G)
    minimum_spanning_tree = nx.minimum_spanning_tree(G, weight='weight', ignore_nan=True).size(weight='weight') if nx.is_connected(G) else None

    
    return {
        'degree_centrality': degree_centrality,
        'betweenness_centrality': betweenness_centrality,
        'eigenvector_centrality': eigenvector_centrality,
        'clustering_coefficient': clustering_coefficient,
        'modularity': modularity,
        'connected_components': connected_components,
        'minimum_spanning_tree': minimum_spanning_tree
    }

# 计算每个图的指标
metrics = {
    'sham': {'s1': [], 's2': [], 's3': []},
    'tacs6': {'s1': [], 's2': [], 's3': []},
    'tacs10': {'s1': [], 's2': [], 's3': []},
    'tdcs': {'s1': [], 's2': [], 's3': []}
}

# 记录指标计算开始时间
metrics_start_time = time.time()
total_graphs = sum(len(graphs[condition][time_point]) for condition in graphs for time_point in graphs[condition])
processed_graphs = 0

for condition in graphs:
    for time_point in graphs[condition]:
        for G in graphs[condition][time_point]:
            metric = compute_graph_metrics(G)
            metrics[condition][time_point].append(metric)
           
            
            # 更新处理图的计数
            processed_graphs += 1
            
            # 计算并打印已处理图的时间和估计剩余时间
            elapsed_time = time.time() - metrics_start_time
            estimated_total_time = (elapsed_time / processed_graphs) * total_graphs
            remaining_time = estimated_total_time - elapsed_time
            print(f"Processed {processed_graphs}/{total_graphs} graphs. Estimated remaining time: {remaining_time:.2f} seconds.")

# 记录比较分析开始时间
compare_start_time = time.time()

# 比较分析
def compare_metrics(metrics, condition1, time_point1, condition2, time_point2, metric_name, paired=False):
    data1 = [m[metric_name] for m in metrics[condition1][time_point1] if m[metric_name] is not None]
    data2 = [m[metric_name] for m in metrics[condition2][time_point2] if m[metric_name] is not None]

    if len(data1) > 0 and len(data2) > 0:
        if paired:
            t_stat, p_value = ttest_rel(data1, data2)
        else:
            t_stat, p_value = ttest_ind(data1, data2)
    else:
        t_stat, p_value = None, None
    return t_stat, p_value

total_comparisons = 0
for condition in ['tacs6', 'tacs10', 'tdcs']:
    total_comparisons += 3  # Sham vs. each condition at s1
    total_comparisons += 3  # Sham vs. each condition at s2
    total_comparisons += 3  # Sham vs. each condition at s3
    total_comparisons += 2 * 3  # Pre vs. Post for each condition

processed_comparisons = 0

# 1. 验证 Sham 组的稳定性
print("Sham Group Stability:")
for metric in ['degree_centrality', 'betweenness_centrality', 'eigenvector_centrality', 'clustering_coefficient', 'modularity', 'connected_components', 'minimum_spanning_tree']:
    t_stat, p_value = compare_metrics(metrics, 'sham', 's1', 'sham', 's2', metric, paired=True)
    print(f"Sham S1 vs S2 - {metric}: T-statistic: {t_stat}, P-value: {p_value}")
    
    t_stat, p_value = compare_metrics(metrics, 'sham', 's1', 'sham', 's3', metric, paired=True)
    print(f"Sham S1 vs S3 - {metric}: T-statistic: {t_stat}, P-value: {p_value}")
    
    # 更新处理比较的计数
    processed_comparisons += 2
    elapsed_time = time.time() - compare_start_time
    estimated_total_time = (elapsed_time / processed_comparisons) * total_comparisons
    remaining_time = estimated_total_time - elapsed_time
    print(f"Processed {processed_comparisons}/{total_comparisons} comparisons. Estimated remaining time: {remaining_time:.2f} seconds.")


# 2. 验证四组的基线相似性
print("\nS_1 Similarity:")
for condition in ['tacs6', 'tacs10', 'tdcs']:
    for metric in ['degree_centrality', 'betweenness_centrality', 'eigenvector_centrality', 'clustering_coefficient', 'modularity', 'connected_components', 'minimum_spanning_tree']:
        t_stat, p_value = compare_metrics(metrics, 'sham', 's1', condition, 's1', metric)
        print(f"Sham S1 vs {condition.upper()} S1 - {metric}: T-statistic: {t_stat}, P-value: {p_value}")
        
        
        # 更新处理比较的计数
        processed_comparisons += 1
        elapsed_time = time.time() - compare_start_time
        estimated_total_time = (elapsed_time / processed_comparisons) * total_comparisons
        remaining_time = estimated_total_time - elapsed_time
        print(f"Processed {processed_comparisons}/{total_comparisons} comparisons. Estimated remaining time: {remaining_time:.2f} seconds.")


# 3. 验证真实刺激的效果
# 3.1 比较真实刺激组与 Sham 组的差异
print("\nReal Stimulation vs Sham:")
for condition in ['tacs6', 'tacs10', 'tdcs']:
    for metric in ['degree_centrality', 'betweenness_centrality', 'eigenvector_centrality', 'clustering_coefficient', 'modularity', 'connected_components', 'minimum_spanning_tree']:
        t_stat, p_value = compare_metrics(metrics, 'sham', 's2', condition, 's2', metric)
        print(f"Sham S2 vs {condition.upper()} S2 - {metric}: T-statistic: {t_stat}, P-value: {p_value}")
        
        t_stat, p_value = compare_metrics(metrics, 'sham', 's3', condition, 's3', metric)
        print(f"Sham S3 vs {condition.upper()} S3 - {metric}: T-statistic: {t_stat}, P-value: {p_value}")
        
        
        # 更新处理比较的计数
        processed_comparisons += 2
        elapsed_time = time.time() - compare_start_time
        estimated_total_time = (elapsed_time / processed_comparisons) * total_comparisons
        remaining_time = estimated_total_time - elapsed_time
        print(f"Processed {processed_comparisons}/{total_comparisons} comparisons. Estimated remaining time: {remaining_time:.2f} seconds.")

# 3.2 比较刺激前后的变化
print("\nPre vs Post Stimulation:")
for condition in ['tacs6', 'tacs10', 'tdcs']:
    for metric in ['degree_centrality', 'betweenness_centrality', 'eigenvector_centrality', 'clustering_coefficient', 'modularity', 'connected_components', 'minimum_spanning_tree']:
        t_stat, p_value = compare_metrics(metrics, condition, 's1', condition, 's2', metric, paired=True)
        print(f"{condition.upper()} S1 vs S2 - {metric}: T-statistic: {t_stat}, P-value: {p_value}")
        
        t_stat, p_value = compare_metrics(metrics, condition, 's1', condition, 's3', metric, paired=True)
        print(f"{condition.upper()} S1 vs S3 - {metric}: T-statistic: {t_stat}, P-value: {p_value}")
        
        # 更新处理比较的计数
        processed_comparisons += 2
        elapsed_time = time.time() - compare_start_time
        estimated_total_time = (elapsed_time / processed_comparisons) * total_comparisons
        remaining_time = estimated_total_time - elapsed_time
        print(f"Processed {processed_comparisons}/{total_comparisons} comparisons. Estimated remaining time: {remaining_time:.2f} seconds.")


# 记录比较分析结束时间
compare_end_time = time.time()
print(f"Time to compare metrics: {compare_end_time - compare_start_time} seconds")

# 记录总运行时间
total_end_time = time.time()
print(f"Total execution time: {total_end_time - start_time} seconds")
# Out:
# Processed 1/24 files. Estimated remaining time: 3.41 seconds.
# Processed 2/24 files. Estimated remaining time: 3.18 seconds.
# Processed 3/24 files. Estimated remaining time: 2.99 seconds.
# Processed 4/24 files. Estimated remaining time: 27.17 seconds.
# Processed 5/24 files. Estimated remaining time: 38.78 seconds.
# Processed 6/24 files. Estimated remaining time: 43.66 seconds.
# Processed 7/24 files. Estimated remaining time: 35.61 seconds.
# Processed 8/24 files. Estimated remaining time: 29.54 seconds.
# Processed 9/24 files. Estimated remaining time: 24.85 seconds.
# Processed 10/24 files. Estimated remaining time: 28.14 seconds.
# Processed 233/243 graphs. Estimated remaining time: 88.77 seconds.
# Processed 234/243 graphs. Estimated remaining time: 79.89 seconds.
# Processed 235/243 graphs. Estimated remaining time: 71.02 seconds.
# Processed 236/243 graphs. Estimated remaining time: 62.12 seconds.
# Processed 237/243 graphs. Estimated remaining time: 53.25 seconds.
# Processed 238/243 graphs. Estimated remaining time: 44.37 seconds.
# Processed 239/243 graphs. Estimated remaining time: 35.51 seconds.
# Processed 240/243 graphs. Estimated remaining time: 26.63 seconds.
# Processed 241/243 graphs. Estimated remaining time: 17.75 seconds.
# Processed 242/243 graphs. Estimated remaining time: 8.87 seconds.
# Processed 243/243 graphs. Estimated remaining time: 0.00 seconds.
# Sham Group Stability:
# Sham S1 vs S2 - degree_centrality: T-statistic: nan, P-value: nan
# Sham S1 vs S3 - degree_centrality: T-statistic: nan, P-value: nan
# Processed 2/45 comparisons. Estimated remaining time: 0.33 seconds.
# Sham S1 vs S2 - betweenness_centrality: T-statistic: nan, P-value: nan
# Sham S1 vs S3 - betweenness_centrality: T-statistic: nan, P-value: nan
# Processed 4/45 comparisons. Estimated remaining time: 0.19 seconds.
# Sham S1 vs S2 - eigenvector_centrality: T-statistic: nan, P-value: nan
# Sham S1 vs S3 - eigenvector_centrality: T-statistic: nan, P-value: nan
# Processed 6/45 comparisons. Estimated remaining time: 0.13 seconds.
# Sham S1 vs S2 - clustering_coefficient: T-statistic: nan, P-value: nan
# Sham S1 vs S3 - clustering_coefficient: T-statistic: nan, P-value: nan
# Processed 8/45 comparisons. Estimated remaining time: 0.10 seconds.
# Sham S1 vs S2 - modularity: T-statistic: nan, P-value: nan
# Sham S1 vs S3 - modularity: T-statistic: nan, P-value: nan
# Processed 10/45 comparisons. Estimated remaining time: 0.08 seconds.
# Sham S1 vs S2 - connected_components: T-statistic: nan, P-value: nan
# Sham S1 vs S3 - connected_components: T-statistic: nan, P-value: nan
# Processed 12/45 comparisons. Estimated remaining time: 0.07 seconds.
# Sham S1 vs S2 - minimum_spanning_tree: T-statistic: -0.2838615691550636, P-value: 0.7795866846788981
# Sham S1 vs S3 - minimum_spanning_tree: T-statistic: -0.6725458129070642, P-value: 0.5093335944473527
# Processed 14/45 comparisons. Estimated remaining time: 0.06 seconds.
#
# S_1 Similarity:
# Sham S1 vs TACS6 S1 - degree_centrality: T-statistic: -1.9599651564847136, P-value: 0.057173159528571556
# Processed 15/45 comparisons. Estimated remaining time: 0.06 seconds.
# Sham S1 vs TACS6 S1 - betweenness_centrality: T-statistic: nan, P-value: nan
# Processed 16/45 comparisons. Estimated remaining time: 0.05 seconds.
# Sham S1 vs TACS6 S1 - eigenvector_centrality: T-statistic: 0.0, P-value: 1.0
# Processed 17/45 comparisons. Estimated remaining time: 0.05 seconds.
# Sham S1 vs TACS6 S1 - clustering_coefficient: T-statistic: nan, P-value: nan
# Processed 18/45 comparisons. Estimated remaining time: 0.04 seconds.
# Sham S1 vs TACS6 S1 - modularity: T-statistic: nan, P-value: nan
# Processed 19/45 comparisons. Estimated remaining time: 0.04 seconds.
# Sham S1 vs TACS6 S1 - connected_components: T-statistic: nan, P-value: nan
# Processed 20/45 comparisons. Estimated remaining time: 0.04 seconds.
# Sham S1 vs TACS6 S1 - minimum_spanning_tree: T-statistic: -0.052344497176790176, P-value: 0.9585213996804467
# Processed 21/45 comparisons. Estimated remaining time: 0.03 seconds.
# Sham S1 vs TACS10 S1 - degree_centrality: T-statistic: -1.9599651564847136, P-value: 0.057173159528571556
# Processed 22/45 comparisons. Estimated remaining time: 0.03 seconds.
# Sham S1 vs TACS10 S1 - betweenness_centrality: T-statistic: nan, P-value: nan
# Processed 23/45 comparisons. Estimated remaining time: 0.03 seconds.
# Sham S1 vs TACS10 S1 - eigenvector_centrality: T-statistic: 0.0, P-value: 1.0
# Processed 24/45 comparisons. Estimated remaining time: 0.03 seconds.
# Sham S1 vs TACS10 S1 - clustering_coefficient: T-statistic: nan, P-value: nan
# Processed 25/45 comparisons. Estimated remaining time: 0.03 seconds.
# Sham S1 vs TACS10 S1 - modularity: T-statistic: nan, P-value: nan
# Processed 26/45 comparisons. Estimated remaining time: 0.02 seconds.
# Sham S1 vs TACS10 S1 - connected_components: T-statistic: nan, P-value: nan
# Processed 27/45 comparisons. Estimated remaining time: 0.02 seconds.
# Sham S1 vs TACS10 S1 - minimum_spanning_tree: T-statistic: -0.0746835179513051, P-value: 0.9408482910897904
# Processed 28/45 comparisons. Estimated remaining time: 0.02 seconds.
# Sham S1 vs TDCS S1 - degree_centrality: T-statistic: 0.0, P-value: 1.0
# Processed 29/45 comparisons. Estimated remaining time: 0.02 seconds.
# Sham S1 vs TDCS S1 - betweenness_centrality: T-statistic: nan, P-value: nan
# Processed 30/45 comparisons. Estimated remaining time: 0.02 seconds.
# Sham S1 vs TDCS S1 - eigenvector_centrality: T-statistic: 0.0, P-value: 1.0
# Processed 31/45 comparisons. Estimated remaining time: 0.02 seconds.
# Sham S1 vs TDCS S1 - clustering_coefficient: T-statistic: nan, P-value: nan
# Processed 32/45 comparisons. Estimated remaining time: 0.01 seconds.
# Sham S1 vs TDCS S1 - modularity: T-statistic: nan, P-value: nan
# Processed 33/45 comparisons. Estimated remaining time: 0.01 seconds.
# Sham S1 vs TDCS S1 - connected_components: T-statistic: nan, P-value: nan
# Processed 34/45 comparisons. Estimated remaining time: 0.01 seconds.
# Sham S1 vs TDCS S1 - minimum_spanning_tree: T-statistic: 0.67486129606331, P-value: 0.5039594133110199
# Processed 35/45 comparisons. Estimated remaining time: 0.01 seconds.
#
# Real Stimulation vs Sham:
# Sham S2 vs TACS6 S2 - degree_centrality: T-statistic: -1.9599651564847136, P-value: 0.057173159528571556
# Sham S3 vs TACS6 S3 - degree_centrality: T-statistic: -1.9599651564847136, P-value: 0.057173159528571556
# Processed 37/45 comparisons. Estimated remaining time: 0.01 seconds.
# Sham S2 vs TACS6 S2 - betweenness_centrality: T-statistic: nan, P-value: nan
# Sham S3 vs TACS6 S3 - betweenness_centrality: T-statistic: nan, P-value: nan
# Processed 39/45 comparisons. Estimated remaining time: 0.01 seconds.
# Sham S2 vs TACS6 S2 - eigenvector_centrality: T-statistic: 0.0, P-value: 1.0
# Sham S3 vs TACS6 S3 - eigenvector_centrality: T-statistic: 0.0, P-value: 1.0
# Processed 41/45 comparisons. Estimated remaining time: 0.00 seconds.
# Sham S2 vs TACS6 S2 - clustering_coefficient: T-statistic: nan, P-value: nan
# Sham S3 vs TACS6 S3 - clustering_coefficient: T-statistic: nan, P-value: nan
# Processed 43/45 comparisons. Estimated remaining time: 0.00 seconds.
# Sham S2 vs TACS6 S2 - modularity: T-statistic: nan, P-value: nan
# Sham S3 vs TACS6 S3 - modularity: T-statistic: nan, P-value: nan
# Processed 45/45 comparisons. Estimated remaining time: 0.00 seconds.
# Sham S2 vs TACS6 S2 - connected_components: T-statistic: nan, P-value: nan
# Sham S3 vs TACS6 S3 - connected_components: T-statistic: nan, P-value: nan
# Processed 47/45 comparisons. Estimated remaining time: -0.00 seconds.
# Sham S2 vs TACS6 S2 - minimum_spanning_tree: T-statistic: 0.7098951561647099, P-value: 0.48199239984200193
# Sham S3 vs TACS6 S3 - minimum_spanning_tree: T-statistic: 0.816781182125203, P-value: 0.4190150055587575
# Processed 49/45 comparisons. Estimated remaining time: -0.00 seconds.
# Sham S2 vs TACS10 S2 - degree_centrality: T-statistic: -1.9599651564847136, P-value: 0.057173159528571556
# Sham S3 vs TACS10 S3 - degree_centrality: T-statistic: -1.9599651564847136, P-value: 0.057173159528571556
# Processed 51/45 comparisons. Estimated remaining time: -0.00 seconds.
# Sham S2 vs TACS10 S2 - betweenness_centrality: T-statistic: nan, P-value: nan
# Sham S3 vs TACS10 S3 - betweenness_centrality: T-statistic: nan, P-value: nan
# Processed 53/45 comparisons. Estimated remaining time: -0.01 seconds.
# Sham S2 vs TACS10 S2 - eigenvector_centrality: T-statistic: 0.0, P-value: 1.0
# Sham S3 vs TACS10 S3 - eigenvector_centrality: T-statistic: 0.0, P-value: 1.0
# Processed 55/45 comparisons. Estimated remaining time: -0.01 seconds.
# Sham S2 vs TACS10 S2 - clustering_coefficient: T-statistic: nan, P-value: nan
# Sham S3 vs TACS10 S3 - clustering_coefficient: T-statistic: nan, P-value: nan
# Processed 57/45 comparisons. Estimated remaining time: -0.01 seconds.
# Sham S2 vs TACS10 S2 - modularity: T-statistic: nan, P-value: nan
# Sham S3 vs TACS10 S3 - modularity: T-statistic: nan, P-value: nan
# Processed 59/45 comparisons. Estimated remaining time: -0.01 seconds.
# Sham S2 vs TACS10 S2 - connected_components: T-statistic: nan, P-value: nan
# Sham S3 vs TACS10 S3 - connected_components: T-statistic: nan, P-value: nan
# Processed 61/45 comparisons. Estimated remaining time: -0.01 seconds.
# Sham S2 vs TACS10 S2 - minimum_spanning_tree: T-statistic: 0.5957092058385912, P-value: 0.5548111098973545
# Sham S3 vs TACS10 S3 - minimum_spanning_tree: T-statistic: 0.07584113178013037, P-value: 0.9399332119632022
# Processed 63/45 comparisons. Estimated remaining time: -0.01 seconds.
# Sham S2 vs TDCS S2 - degree_centrality: T-statistic: 0.0, P-value: 1.0
# Sham S3 vs TDCS S3 - degree_centrality: T-statistic: 0.0, P-value: 1.0
# Processed 65/45 comparisons. Estimated remaining time: -0.01 seconds.
# Sham S2 vs TDCS S2 - betweenness_centrality: T-statistic: nan, P-value: nan
# Sham S3 vs TDCS S3 - betweenness_centrality: T-statistic: nan, P-value: nan
# Processed 67/45 comparisons. Estimated remaining time: -0.02 seconds.
# Sham S2 vs TDCS S2 - eigenvector_centrality: T-statistic: 0.0, P-value: 1.0
# Sham S3 vs TDCS S3 - eigenvector_centrality: T-statistic: 0.0, P-value: 1.0
# Processed 69/45 comparisons. Estimated remaining time: -0.02 seconds.
# Sham S2 vs TDCS S2 - clustering_coefficient: T-statistic: nan, P-value: nan
# Sham S3 vs TDCS S3 - clustering_coefficient: T-statistic: nan, P-value: nan
# Processed 71/45 comparisons. Estimated remaining time: -0.02 seconds.
# Sham S2 vs TDCS S2 - modularity: T-statistic: nan, P-value: nan
# Sham S3 vs TDCS S3 - modularity: T-statistic: nan, P-value: nan
# Processed 73/45 comparisons. Estimated remaining time: -0.02 seconds.
# Sham S2 vs TDCS S2 - connected_components: T-statistic: nan, P-value: nan
# Sham S3 vs TDCS S3 - connected_components: T-statistic: nan, P-value: nan
# Processed 75/45 comparisons. Estimated remaining time: -0.02 seconds.
# Sham S2 vs TDCS S2 - minimum_spanning_tree: T-statistic: 0.6136937881920139, P-value: 0.5431725351314414
# Sham S3 vs TDCS S3 - minimum_spanning_tree: T-statistic: 0.30560456177543144, P-value: 0.7616185561178892
# Processed 77/45 comparisons. Estimated remaining time: -0.02 seconds.
#
# Pre vs Post Stimulation:
# TACS6 S1 vs S2 - degree_centrality: T-statistic: nan, P-value: nan
# TACS6 S1 vs S3 - degree_centrality: T-statistic: nan, P-value: nan
# Processed 79/45 comparisons. Estimated remaining time: -0.02 seconds.
# TACS6 S1 vs S2 - betweenness_centrality: T-statistic: nan, P-value: nan
# TACS6 S1 vs S3 - betweenness_centrality: T-statistic: nan, P-value: nan
# Processed 81/45 comparisons. Estimated remaining time: -0.02 seconds.
# TACS6 S1 vs S2 - eigenvector_centrality: T-statistic: nan, P-value: nan
# TACS6 S1 vs S3 - eigenvector_centrality: T-statistic: nan, P-value: nan
# Processed 83/45 comparisons. Estimated remaining time: -0.03 seconds.
# TACS6 S1 vs S2 - clustering_coefficient: T-statistic: nan, P-value: nan
# TACS6 S1 vs S3 - clustering_coefficient: T-statistic: nan, P-value: nan
# Processed 85/45 comparisons. Estimated remaining time: -0.03 seconds.
# TACS6 S1 vs S2 - modularity: T-statistic: nan, P-value: nan
# TACS6 S1 vs S3 - modularity: T-statistic: nan, P-value: nan
# Processed 87/45 comparisons. Estimated remaining time: -0.03 seconds.
# TACS6 S1 vs S2 - connected_components: T-statistic: nan, P-value: nan
# TACS6 S1 vs S3 - connected_components: T-statistic: nan, P-value: nan
# Processed 89/45 comparisons. Estimated remaining time: -0.03 seconds.
# TACS6 S1 vs S2 - minimum_spanning_tree: T-statistic: 0.9989955571879454, P-value: 0.3297310040381485
# TACS6 S1 vs S3 - minimum_spanning_tree: T-statistic: 0.5104584770214549, P-value: 0.6153182894786454
# Processed 91/45 comparisons. Estimated remaining time: -0.03 seconds.
# TACS10 S1 vs S2 - degree_centrality: T-statistic: nan, P-value: nan
# TACS10 S1 vs S3 - degree_centrality: T-statistic: nan, P-value: nan
# Processed 93/45 comparisons. Estimated remaining time: -0.03 seconds.
# TACS10 S1 vs S2 - betweenness_centrality: T-statistic: nan, P-value: nan
# TACS10 S1 vs S3 - betweenness_centrality: T-statistic: nan, P-value: nan
# Processed 95/45 comparisons. Estimated remaining time: -0.03 seconds.
# TACS10 S1 vs S2 - eigenvector_centrality: T-statistic: nan, P-value: nan
# TACS10 S1 vs S3 - eigenvector_centrality: T-statistic: nan, P-value: nan
# Processed 97/45 comparisons. Estimated remaining time: -0.03 seconds.
# TACS10 S1 vs S2 - clustering_coefficient: T-statistic: nan, P-value: nan
# TACS10 S1 vs S3 - clustering_coefficient: T-statistic: nan, P-value: nan
# Processed 99/45 comparisons. Estimated remaining time: -0.04 seconds.
# TACS10 S1 vs S2 - modularity: T-statistic: nan, P-value: nan
# TACS10 S1 vs S3 - modularity: T-statistic: nan, P-value: nan
# Processed 101/45 comparisons. Estimated remaining time: -0.04 seconds.
# TACS10 S1 vs S2 - connected_components: T-statistic: nan, P-value: nan
# TACS10 S1 vs S3 - connected_components: T-statistic: nan, P-value: nan
# Processed 103/45 comparisons. Estimated remaining time: -0.04 seconds.
# TACS10 S1 vs S2 - minimum_spanning_tree: T-statistic: 0.6985547094837432, P-value: 0.4928739448296868
# TACS10 S1 vs S3 - minimum_spanning_tree: T-statistic: -0.494693807429281, P-value: 0.6262067321801121
# Processed 105/45 comparisons. Estimated remaining time: -0.04 seconds.
# TDCS S1 vs S2 - degree_centrality: T-statistic: nan, P-value: nan
# TDCS S1 vs S3 - degree_centrality: T-statistic: nan, P-value: nan
# Processed 107/45 comparisons. Estimated remaining time: -0.04 seconds.
# TDCS S1 vs S2 - betweenness_centrality: T-statistic: nan, P-value: nan
# TDCS S1 vs S3 - betweenness_centrality: T-statistic: nan, P-value: nan
# Processed 109/45 comparisons. Estimated remaining time: -0.04 seconds.
# TDCS S1 vs S2 - eigenvector_centrality: T-statistic: nan, P-value: nan
# TDCS S1 vs S3 - eigenvector_centrality: T-statistic: nan, P-value: nan
# Processed 111/45 comparisons. Estimated remaining time: -0.04 seconds.
# TDCS S1 vs S2 - clustering_coefficient: T-statistic: nan, P-value: nan
# TDCS S1 vs S3 - clustering_coefficient: T-statistic: nan, P-value: nan
# Processed 113/45 comparisons. Estimated remaining time: -0.04 seconds.
# TDCS S1 vs S2 - modularity: T-statistic: nan, P-value: nan
# TDCS S1 vs S3 - modularity: T-statistic: nan, P-value: nan
# Processed 115/45 comparisons. Estimated remaining time: -0.04 seconds.
# TDCS S1 vs S2 - connected_components: T-statistic: nan, P-value: nan
# TDCS S1 vs S3 - connected_components: T-statistic: nan, P-value: nan
# Processed 117/45 comparisons. Estimated remaining time: -0.05 seconds.
# TDCS S1 vs S2 - minimum_spanning_tree: T-statistic: -0.2702284990608855, P-value: 0.7900584235642077
# TDCS S1 vs S3 - minimum_spanning_tree: T-statistic: -1.54684328377412, P-value: 0.13930224816378142
# Processed 119/45 comparisons. Estimated remaining time: -0.05 seconds.
# Time to compare metrics: 0.07468700408935547 seconds
# Total execution time: 2213.4984567165375 seconds
# /var/folders/5h/x_p7ky7d4ts4dz4c7g75h28c0000gn/T/ipykernel_65246/827160284.py:141: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   t_stat, p_value = ttest_ind(data1, data2)
