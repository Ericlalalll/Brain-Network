# %%
import scipy.io
import numpy as np
import networkx as nx
import os
import json
from scipy.stats import ttest_ind, ttest_rel
from tqdm import tqdm

# %%
# 储存文件路径
folder_path = '/Users/shenxiaoyu/Desktop/FC'

file_paths = [
    'shamfc_s1.mat', 'shamfc_s2.mat', 'shamfc_s3.mat',
    'tacs6fc_s1.mat', 'tacs6fc_s2.mat', 'tacs6fc_s3.mat',
    'tacs10fc_s1.mat', 'tacs10fc_s2.mat', 'tacs10fc_s3.mat',
    'tdcsfc_s1.mat', 'tdcsfc_s2.mat', 'tdcsfc_s3.mat'
]


# preprocessing brain data
def data_preprocessing(matrix, fc_threshold=0.5, zfc_threshold=1.5):
    # matrix = np.where(np.isinf(matrix), np.nan, matrix)  # Replace infinite values with NaN
    
    # Apply threshold to create a binary adjacency matrix
    threshold = zfc_threshold if 'zfc' in file_path.lower() else fc_threshold
    binary_weighted_matrix = np.where(np.abs(matrix) >= threshold, matrix, 0)
    
    # Remove self-loops
    np.fill_diagonal(binary_weighted_matrix, 0)
    
    return binary_weighted_matrix


# Function to save metrics
def save_metrics(metrics, filename='metrics.json'):
    with open(filename, 'w') as f:
        json.dump(metrics, f)

# Function to load metrics
def load_metrics(filename='metrics.json'):
    if os.path.exists(filename):
        with open(filename, 'r') as f:
            return json.load(f)
    return {}

def clear_specific_property_from_metrics(property_name, filename='metrics.json'):
    if os.path.exists(filename):
        with open(filename, 'r') as f:
            metrics = json.load(f)
        for graph_id in metrics:
            if property_name in metrics[graph_id]:
                del metrics[graph_id][property_name]
        with open(filename, 'w') as f:
            json.dump(metrics, f)
    else:
        print("Metrics file not found.")

# Uncomment the line below if you want to clear a specific computed result
#clear_specific_property_from_metrics('minimum_spanning_tree')
#clear_specific_property_from_metrics('maximum_spanning_tree')


# Function to delete the metrics file
def delete_metrics_file(filename='metrics.json'):
    if os.path.exists(filename):
        os.remove(filename)

# Uncomment the line below if you want to empty all previously computed results
delete_metrics_file()

# 创建一个dict来存储每种条件下的graph
graphs = {
    'sham': {'s1': [], 's2': [], 's3': []},
    'tacs6': {'s1': [], 's2': [], 's3': []},
    'tacs10': {'s1': [], 's2': [], 's3': []},
    'tdcs': {'s1': [], 's2': [], 's3': []}
}

# 读取文件里的matrix和提取ZFC
for file_name in file_paths:
    file_path = os.path.join(folder_path, file_name)
    mat = scipy.io.loadmat(file_path)
    key = [k for k in mat.keys() if not k.startswith('__')][0]  # 提取主要数据的key
    matrix = mat[key]
    
    # condition是刺激类型, time_point对应刺激前中后
    base_name = file_name.replace('.mat', '')
    parts = base_name.split('_')
    if len(parts) == 2:
        condition_time, time_point = parts
        if 'zfc' in condition_time:
            condition = condition_time.replace('zfc', '')
            matrix_type = 'zfc'
        else:
            condition = condition_time.replace('fc', '')
            matrix_type = 'fc'
    else:
        condition, matrix_type, time_point = parts

    
    if matrix_type == 'fc':
        # 将其转换为graph
        for i in range(matrix.shape[0]):
            adj_matrix_binary = data_preprocessing(matrix[i])
            G = nx.from_numpy_matrix(adj_matrix_binary)
            graphs[condition][time_point].append(G)

# %%
# WhitakerLab. (n.d.). Scona: Structural Covariance Networks. Retrieved [date], from https://whitakerlab.github.io/scona/_modules/scona/graph_measures.html
def participation_coefficient(G, module_partition):
    """ Calculate the participation coefficient for each node in the graph. """
    pc_dict = {}

    for m in module_partition.keys():
        M = set(module_partition[m])
        for v in M:
            degree = float(nx.degree(G=G, nbunch=v))
            if degree == 0:
                pc_dict[v] = 0
                continue

            wm_degree = float(sum([1 for u in M if (u, v) in G.edges()]))
            pc_dict[v] = 1 - ((float(wm_degree) / float(degree))**2)

    return pc_dict

# %%
# 定义所需要计算的graph property
def compute_graph_metrics(G, existing_metrics=None):
    
    metrics = existing_metrics if existing_metrics else {}
    
    if 'degree_centrality' not in metrics:
        metrics['degree_centrality'] = np.mean(list(nx.degree_centrality(G).values()))
        
    if 'betweenness_centrality' not in metrics:
        metrics['betweenness_centrality'] = np.mean(list(nx.betweenness_centrality(G, weight='weight').values()))
        
    if 'eigenvector_centrality' not in metrics:
        metrics['eigenvector_centrality'] = np.mean(list(nx.eigenvector_centrality(G, max_iter=10000, weight='weight').values()))
        
    if 'clustering_coefficient' not in metrics:
        metrics['clustering_coefficient'] = nx.average_clustering(G, weight='weight')
        
    if 'modularity' not in metrics:
        communities = list(nx.community.greedy_modularity_communities(G, weight='weight'))
        metrics['modularity'] = nx.algorithms.community.quality.modularity(G, communities, weight='weight')
        
    if 'rich_club_coefficient' not in metrics:
        try:
            rich_club = nx.rich_club_coefficient(G)
            avg_rich_club_coefficient = np.mean([v for v in rich_club.values() if v is not None])
        except ZeroDivisionError:
            avg_rich_club_coefficient = None
        metrics['rich_club_coefficient'] = avg_rich_club_coefficient
        
    if 'participation_coefficient' not in metrics:
        communities = list(nx.community.greedy_modularity_communities(G, weight='weight'))
        module_partition = {i: list(c) for i, c in enumerate(communities)}
        pc = participation_coefficient(G, module_partition)
        metrics['participation_coefficient'] = np.mean(list(pc.values()))
                                                           
    if 'connected_components' not in metrics:
        metrics['connected_components'] = nx.number_connected_components(G)
                                                           
    if 'minimum_spanning_tree' not in metrics:
        metrics['minimum_spanning_tree'] = nx.minimum_spanning_tree(G, weight='weight').size(weight='weight') 
                                                           
    if 'cut_vertices' not in metrics:
        metrics['cut_vertices'] = len(list(nx.articulation_points(G)))
                                                           
    if 'biconnected_components' not in metrics:
        metrics['biconnected_components'] = len(list(nx.biconnected_components(G)))
    
    if 'maximum_spanning_tree' not in metrics:
        metrics['maximum_spanning_tree'] = nx.maximum_spanning_tree(G, weight='weight').size(weight='weight') 
                                                           
        
    return metrics


# Store the computed metrics
metrics = load_metrics()


total_graphs = sum(len(graphs[condition][time_point]) for condition in graphs for time_point in graphs[condition])
with tqdm(total=total_graphs, desc="Overall Progress") as pbar:
    for condition in graphs:
        for time_point in graphs[condition]:
            for idx, G in enumerate(graphs[condition][time_point]):
                graph_id = f"{condition}_{time_point}_{idx}"
                if graph_id not in metrics:
                    metrics[graph_id] = compute_graph_metrics(G, metrics.get(graph_id, {}))
                pbar.update(1)
                
                

# Save the computed metrics to avoid redundant computation
save_metrics(metrics)
# Out:
# Overall Progress: 100%|███████████████████████| 252/252 [27:19<00:00,  6.51s/it]

# %%
def compare_analysis(metrics, condition1, time_point1, condition2, time_point2, graph_property, paired=False):
    data1 = [metrics[f"{condition1}_{time_point1}_{i}"][graph_property] for i in range(20) if f"{condition1}_{time_point1}_{i}" in metrics and metrics[f"{condition1}_{time_point1}_{i}"].get(graph_property) is not None]
    data2 = [metrics[f"{condition2}_{time_point2}_{i}"][graph_property] for i in range(20) if f"{condition2}_{time_point2}_{i}" in metrics and metrics[f"{condition2}_{time_point2}_{i}"].get(graph_property) is not None]
    
    # Filter out None values
    data1 = [x for x in data1 if x is not None]
    data2 = [x for x in data2 if x is not None]
    
    if len(data1) > 0 and len(data2) > 0:
        if paired:
            t_stat, p_value = ttest_rel(data1, data2)
        else:
            t_stat, p_value = ttest_ind(data1, data2)
    else:
        t_stat, p_value = None, None
    return t_stat, p_value

# %%
# 1. 验证四组s1相似性 
print("S_1:")
for condition in ['tacs6', 'tacs10', 'tdcs']:
    for graph_property in ['degree_centrality', 'betweenness_centrality', 'eigenvector_centrality', 'clustering_coefficient', 'modularity', 'rich_club_coefficient', 'participation_coefficient', 'connected_components', 'minimum_spanning_tree', 'cut_vertices', 'biconnected_components', 'maximum_spanning_tree']:
        t_stat, p_value = compare_analysis(metrics, 'sham', 's1', condition, 's1', graph_property)
        print(f"Sham S1 vs {condition} S1 - {graph_property}: T-statistic: {t_stat}, P-value: {p_value}")
# Out:
# S_1:
# Sham S1 vs tacs6 S1 - degree_centrality: T-statistic: -1.5353794600591404, P-value: 0.13297584582069283
# Sham S1 vs tacs6 S1 - betweenness_centrality: T-statistic: -1.5808803002142664, P-value: 0.12219432540521831
# Sham S1 vs tacs6 S1 - eigenvector_centrality: T-statistic: 0.38449095293897173, P-value: 0.7027580070372911
# Sham S1 vs tacs6 S1 - clustering_coefficient: T-statistic: -1.4682315753920003, P-value: 0.15027094807384525
# Sham S1 vs tacs6 S1 - modularity: T-statistic: -0.48362452112469917, P-value: 0.6314276626388355
# Sham S1 vs tacs6 S1 - rich_club_coefficient: T-statistic: -0.0031593686895281807, P-value: 0.9975104939451678
# Sham S1 vs tacs6 S1 - participation_coefficient: T-statistic: -0.9638492999375361, P-value: 0.3412154493993782
# Sham S1 vs tacs6 S1 - connected_components: T-statistic: 1.7914336063242515, P-value: 0.08119080913572568
# Sham S1 vs tacs6 S1 - minimum_spanning_tree: T-statistic: 1.2584970205906756, P-value: 0.21588950259046188
# Sham S1 vs tacs6 S1 - cut_vertices: T-statistic: 2.740960266223574, P-value: 0.009284384826773242
# Sham S1 vs tacs6 S1 - biconnected_components: T-statistic: 2.6739193145997393, P-value: 0.010990595970444111
# Sham S1 vs tacs6 S1 - maximum_spanning_tree: T-statistic: -2.023374254057972, P-value: 0.05010982655990843
# Sham S1 vs tacs10 S1 - degree_centrality: T-statistic: 0.12587723806444626, P-value: 0.9004927483954
# Sham S1 vs tacs10 S1 - betweenness_centrality: T-statistic: -0.5741208884466222, P-value: 0.5692690838317087
# Sham S1 vs tacs10 S1 - eigenvector_centrality: T-statistic: 0.8457209959459178, P-value: 0.40300251271988274
# Sham S1 vs tacs10 S1 - clustering_coefficient: T-statistic: -0.38788331242135643, P-value: 0.7002667861486696
# Sham S1 vs tacs10 S1 - modularity: T-statistic: -1.1095352404354706, P-value: 0.27417178881895
# Sham S1 vs tacs10 S1 - rich_club_coefficient: T-statistic: 1.0581832423006823, P-value: 0.3025859425675327
# Sham S1 vs tacs10 S1 - participation_coefficient: T-statistic: -0.29591530017490075, P-value: 0.7689058961954214
# Sham S1 vs tacs10 S1 - connected_components: T-statistic: 0.4680120963477002, P-value: 0.6424492284646062
# Sham S1 vs tacs10 S1 - minimum_spanning_tree: T-statistic: 0.5746356572118246, P-value: 0.5689243464891482
# Sham S1 vs tacs10 S1 - cut_vertices: T-statistic: 0.6828092574087803, P-value: 0.4988692359090726
# Sham S1 vs tacs10 S1 - biconnected_components: T-statistic: 0.6150898338691148, P-value: 0.542161607206471
# Sham S1 vs tacs10 S1 - maximum_spanning_tree: T-statistic: -0.689741926593724, P-value: 0.4945474198859998
# Sham S1 vs tdcs S1 - degree_centrality: T-statistic: -0.41000511997646016, P-value: 0.6841045854920004
# Sham S1 vs tdcs S1 - betweenness_centrality: T-statistic: -1.1674776491354617, P-value: 0.2502911500975049
# Sham S1 vs tdcs S1 - eigenvector_centrality: T-statistic: 0.5392446338082754, P-value: 0.5928637741899034
# Sham S1 vs tdcs S1 - clustering_coefficient: T-statistic: -0.3582735473357911, P-value: 0.7221213160932836
# Sham S1 vs tdcs S1 - modularity: T-statistic: -1.1534043272452141, P-value: 0.2559478842077649
# Sham S1 vs tdcs S1 - rich_club_coefficient: T-statistic: -0.6182142806495472, P-value: 0.5422570653500991
# Sham S1 vs tdcs S1 - participation_coefficient: T-statistic: -0.22978169164943493, P-value: 0.8194938354636648
# Sham S1 vs tdcs S1 - connected_components: T-statistic: 0.6311330556049703, P-value: 0.5317316850663509
# Sham S1 vs tdcs S1 - minimum_spanning_tree: T-statistic: 1.246226548742073, P-value: 0.2203095667707872
# Sham S1 vs tdcs S1 - cut_vertices: T-statistic: 1.0291548185006834, P-value: 0.30991335613173665
# Sham S1 vs tdcs S1 - biconnected_components: T-statistic: 0.8904292346963807, P-value: 0.3788385338501338
# Sham S1 vs tdcs S1 - maximum_spanning_tree: T-statistic: -0.6270134338552663, P-value: 0.5343997885890843

# %%
# 2. 验证真实刺激的s2与sham组的对比
print("S_2:")
for condition in ['tacs6', 'tacs10', 'tdcs']:
    for graph_property in ['degree_centrality', 'betweenness_centrality', 'eigenvector_centrality', 'clustering_coefficient', 'modularity', 'rich_club_coefficient', 'participation_coefficient', 'connected_components', 'minimum_spanning_tree', 'cut_vertices', 'biconnected_components', 'maximum_spanning_tree']:
        # 比较 s2
        t_stat, p_value = compare_analysis(metrics, 'sham', 's2', condition, 's2', graph_property)
        print(f"{condition} S2 vs Sham S2 - {graph_property}: T-statistic: {t_stat}, P-value: {p_value}")
# Out:
# S_2:
# tacs6 S2 vs Sham S2 - degree_centrality: T-statistic: -2.0125328788151142, P-value: 0.051290308861893896
# tacs6 S2 vs Sham S2 - betweenness_centrality: T-statistic: -2.4289098273536367, P-value: 0.019983732617555258
# tacs6 S2 vs Sham S2 - eigenvector_centrality: T-statistic: -0.37502844850505773, P-value: 0.7097244035386876
# tacs6 S2 vs Sham S2 - clustering_coefficient: T-statistic: -1.023335909492655, P-value: 0.31261983843824465
# tacs6 S2 vs Sham S2 - modularity: T-statistic: -0.2690442140518425, P-value: 0.7893511083439481
# tacs6 S2 vs Sham S2 - rich_club_coefficient: T-statistic: 3.250332039452289, P-value: 0.005379645200283547
# tacs6 S2 vs Sham S2 - participation_coefficient: T-statistic: -2.137559852606514, P-value: 0.039047200176669516
# tacs6 S2 vs Sham S2 - connected_components: T-statistic: 0.8543226041999918, P-value: 0.3982802680263561
# tacs6 S2 vs Sham S2 - minimum_spanning_tree: T-statistic: 2.2675905928334177, P-value: 0.029124800561420056
# tacs6 S2 vs Sham S2 - cut_vertices: T-statistic: 1.7420586686696062, P-value: 0.08958803841239046
# tacs6 S2 vs Sham S2 - biconnected_components: T-statistic: 1.7791017501273054, P-value: 0.08322334010367538
# tacs6 S2 vs Sham S2 - maximum_spanning_tree: T-statistic: -1.7032560299013546, P-value: 0.09668702185048997
# tacs10 S2 vs Sham S2 - degree_centrality: T-statistic: -0.993001829781887, P-value: 0.3269904088631369
# tacs10 S2 vs Sham S2 - betweenness_centrality: T-statistic: -1.7076196454810921, P-value: 0.0958660234048947
# tacs10 S2 vs Sham S2 - eigenvector_centrality: T-statistic: 0.7476818948860657, P-value: 0.45925424838382256
# tacs10 S2 vs Sham S2 - clustering_coefficient: T-statistic: -1.1726664107802867, P-value: 0.24822861178364994
# tacs10 S2 vs Sham S2 - modularity: T-statistic: -1.3690504829725934, P-value: 0.17902185097763074
# tacs10 S2 vs Sham S2 - rich_club_coefficient: T-statistic: 0.8071546522022383, P-value: 0.43141333719387587
# tacs10 S2 vs Sham S2 - participation_coefficient: T-statistic: -1.168402241944971, P-value: 0.249922715011928
# tacs10 S2 vs Sham S2 - connected_components: T-statistic: -0.15808788384964623, P-value: 0.8752246653378126
# tacs10 S2 vs Sham S2 - minimum_spanning_tree: T-statistic: 1.4864418836830389, P-value: 0.14541289607703273
# tacs10 S2 vs Sham S2 - cut_vertices: T-statistic: 0.8059891663724099, P-value: 0.4252643979489752
# tacs10 S2 vs Sham S2 - biconnected_components: T-statistic: 0.7502056766801317, P-value: 0.4577509619440957
# tacs10 S2 vs Sham S2 - maximum_spanning_tree: T-statistic: -0.5125783546823018, P-value: 0.611213091257745
# tdcs S2 vs Sham S2 - degree_centrality: T-statistic: -0.32432575810623004, P-value: 0.7474700103106153
# tdcs S2 vs Sham S2 - betweenness_centrality: T-statistic: -3.1948730479938594, P-value: 0.002812559435804485
# tdcs S2 vs Sham S2 - eigenvector_centrality: T-statistic: 0.9550817866142851, P-value: 0.34557302143177115
# tdcs S2 vs Sham S2 - clustering_coefficient: T-statistic: -0.071088277401803, P-value: 0.943700321843493
# tdcs S2 vs Sham S2 - modularity: T-statistic: -1.8889073342847076, P-value: 0.0665541062934841
# tdcs S2 vs Sham S2 - rich_club_coefficient: T-statistic: 1.3375943717202565, P-value: 0.19682094822011842
# tdcs S2 vs Sham S2 - participation_coefficient: T-statistic: -2.155378668480913, P-value: 0.03753079266504767
# tdcs S2 vs Sham S2 - connected_components: T-statistic: 0.18057304068346994, P-value: 0.85766232616206
# tdcs S2 vs Sham S2 - minimum_spanning_tree: T-statistic: 2.4846536231228566, P-value: 0.01748868102973339
# tdcs S2 vs Sham S2 - cut_vertices: T-statistic: 0.7642772883615153, P-value: 0.4494220537357957
# tdcs S2 vs Sham S2 - biconnected_components: T-statistic: 0.8240738063731736, P-value: 0.41504021405680414
# tdcs S2 vs Sham S2 - maximum_spanning_tree: T-statistic: -0.246187996167109, P-value: 0.806861707929805

# %%
# 2. 验证真实刺激的s3与sham组的对比
print("S_3:")
for condition in ['tacs6', 'tacs10', 'tdcs']:
    for graph_property in ['degree_centrality', 'betweenness_centrality', 'eigenvector_centrality', 'clustering_coefficient', 'modularity', 'rich_club_coefficient', 'participation_coefficient', 'connected_components', 'minimum_spanning_tree', 'cut_vertices', 'biconnected_components', 'maximum_spanning_tree']:        
        # 比较 s3
        t_stat, p_value = compare_analysis(metrics, 'sham', 's3', condition, 's3', graph_property)
        print(f"{condition} S3 vs Sham S3 - {graph_property}: T-statistic: {t_stat}, P-value: {p_value}")
# Out:
# S_3:
# tacs6 S3 vs Sham S3 - degree_centrality: T-statistic: -1.7554168676560173, P-value: 0.08724735143654236
# tacs6 S3 vs Sham S3 - betweenness_centrality: T-statistic: -2.1043114794769404, P-value: 0.04202185157810498
# tacs6 S3 vs Sham S3 - eigenvector_centrality: T-statistic: 0.37752957565688205, P-value: 0.7078805626698998
# tacs6 S3 vs Sham S3 - clustering_coefficient: T-statistic: -0.9647578779864273, P-value: 0.34076597445302925
# tacs6 S3 vs Sham S3 - modularity: T-statistic: 1.179924174615348, P-value: 0.2453644281654195
# tacs6 S3 vs Sham S3 - rich_club_coefficient: T-statistic: -0.3455453233657686, P-value: 0.7352119197632481
# tacs6 S3 vs Sham S3 - participation_coefficient: T-statistic: -2.7062855974052304, P-value: 0.010133591150543603
# tacs6 S3 vs Sham S3 - connected_components: T-statistic: 2.125248834478217, P-value: 0.040126247784223204
# tacs6 S3 vs Sham S3 - minimum_spanning_tree: T-statistic: 2.19206615859726, P-value: 0.03457178697785331
# tacs6 S3 vs Sham S3 - cut_vertices: T-statistic: 1.5137754674906596, P-value: 0.13835665390144122
# tacs6 S3 vs Sham S3 - biconnected_components: T-statistic: 1.837258908852845, P-value: 0.0740013711179166
# tacs6 S3 vs Sham S3 - maximum_spanning_tree: T-statistic: -1.8995996835428526, P-value: 0.0650952090275589
# tacs10 S3 vs Sham S3 - degree_centrality: T-statistic: -0.5821694327341499, P-value: 0.5638909257679076
# tacs10 S3 vs Sham S3 - betweenness_centrality: T-statistic: -2.081680889993523, P-value: 0.044158936283729175
# tacs10 S3 vs Sham S3 - eigenvector_centrality: T-statistic: 2.46267776597045, P-value: 0.018436315302764197
# tacs10 S3 vs Sham S3 - clustering_coefficient: T-statistic: -0.7869111280994799, P-value: 0.43621437569155297
# tacs10 S3 vs Sham S3 - modularity: T-statistic: -1.6371534194175206, P-value: 0.10985464609880598
# tacs10 S3 vs Sham S3 - rich_club_coefficient: T-statistic: -1.0866913816897912, P-value: 0.2943280118828399
# tacs10 S3 vs Sham S3 - participation_coefficient: T-statistic: -1.4844704093829268, P-value: 0.14593272499864413
# tacs10 S3 vs Sham S3 - connected_components: T-statistic: 1.528704560321462, P-value: 0.13462005759122814
# tacs10 S3 vs Sham S3 - minimum_spanning_tree: T-statistic: 1.5391460610371226, P-value: 0.13205518607821648
# tacs10 S3 vs Sham S3 - cut_vertices: T-statistic: 1.5650224568605484, P-value: 0.1258683557186203
# tacs10 S3 vs Sham S3 - biconnected_components: T-statistic: 1.7213388430628012, P-value: 0.09332252466997351
# tacs10 S3 vs Sham S3 - maximum_spanning_tree: T-statistic: -1.355449509068613, P-value: 0.18327653568903332
# tdcs S3 vs Sham S3 - degree_centrality: T-statistic: -1.067198146437299, P-value: 0.29261574030768145
# tdcs S3 vs Sham S3 - betweenness_centrality: T-statistic: -4.449321918729178, P-value: 7.290150082518089e-05
# tdcs S3 vs Sham S3 - eigenvector_centrality: T-statistic: 2.512182844655492, P-value: 0.016364284463898003
# tdcs S3 vs Sham S3 - clustering_coefficient: T-statistic: -0.15365115289152478, P-value: 0.8786978923253619
# tdcs S3 vs Sham S3 - modularity: T-statistic: -1.511624904759797, P-value: 0.13890170119857642
# tdcs S3 vs Sham S3 - rich_club_coefficient: T-statistic: -1.1101690000754794, P-value: 0.28077937891605653
# tdcs S3 vs Sham S3 - participation_coefficient: T-statistic: -3.634042643217161, P-value: 0.0008223776040075413
# tdcs S3 vs Sham S3 - connected_components: T-statistic: 1.491610925945354, P-value: 0.14405694702063973
# tdcs S3 vs Sham S3 - minimum_spanning_tree: T-statistic: 3.7717521953241944, P-value: 0.0005523319109797287
# tdcs S3 vs Sham S3 - cut_vertices: T-statistic: 1.817517754113245, P-value: 0.07702940403633587
# tdcs S3 vs Sham S3 - biconnected_components: T-statistic: 1.9805384222472537, P-value: 0.05491623426939905
# tdcs S3 vs Sham S3 - maximum_spanning_tree: T-statistic: -1.4059302044881454, P-value: 0.16786938390940986
