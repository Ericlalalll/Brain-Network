# %%
import scipy.io
import numpy as np
import networkx as nx
import os

# Define the folder path and file paths
folder_path = '/Users/shenxiaoyu/Desktop/FC'
file_paths = [
    'shamfc_s1.mat', 'shamfc_s2.mat', 'shamfc_s3.mat',
    'tacs6fc_s1.mat', 'tacs6fc_s2.mat', 'tacs6fc_s3.mat',
    'tacs10fc_s1.mat', 'tacs10fc_s2.mat', 'tacs10fc_s3.mat',
    'tdcsfc_s1.mat', 'tdcsfc_s2.mat', 'tdcsfc_s3.mat'
]

# Preprocess the brain data
def data_preprocessing(matrix, fc_threshold=0.5):
    weighted_matrix = np.where(matrix >= fc_threshold, matrix, 0)
    np.fill_diagonal(weighted_matrix, 0)
    return weighted_matrix

# Create a dictionary to store graphs
graphs = {
    'sham': {'s1': [], 's2': [], 's3': []},
    'tacs6': {'s1': [], 's2': [], 's3': []},
    'tacs10': {'s1': [], 's2': [], 's3': []},
    'tdcs': {'s1': [], 's2': [], 's3': []}
}

# Load the files and create graphs
for file_name in file_paths:
    file_path = os.path.join(folder_path, file_name)
    mat = scipy.io.loadmat(file_path)
    key = [k for k in mat.keys() if not k.startswith('__')][0]
    matrix = mat[key]
    
    base_name = file_name.replace('.mat', '')
    parts = base_name.split('_')
    condition = parts[0].replace('fc', '')
    time_point = parts[1]

    for i in range(matrix.shape[0]):
        adj_matrix = data_preprocessing(matrix[i])
        
        # Print basic statistics of the adjacency matrix
        print(f"Subject {i+1}'s adjacency matrix statistics: min={adj_matrix.min()}, max={adj_matrix.max()}, mean={adj_matrix.mean()}, std={adj_matrix.std()}")
        #print(f"Subject {i+1}'s adjacency matrix:\n{adj_matrix}")

        # Convert to NetworkX graph
        G = nx.from_numpy_matrix(adj_matrix)
        
        # Print basic info about the graph for debugging
        print(f"Subject {i+1}'s graph has {G.number_of_nodes()} nodes and {G.number_of_edges()} edges")
        
        graphs[condition][time_point].append(G)





# Function to compute and print rich club coefficient and participation coefficient
def compute_graph_properties(G):
    conected_component = nx.number_connected_components(G)
    print(f"conected_component for current graph: {conected_component}")
    
    biconnected_components = len(list(nx.biconnected_components(G)))
    print(f"biconnected_components for current graph: {biconnected_components}")
    
    cut_vertices = len(list(nx.articulation_points(G)))
    print(f"cut_vertices for current graph: {cut_vertices}")



# Compute properties for all graphs
for condition in graphs:
    for time_point in graphs[condition]:
        for idx, G in enumerate(graphs[condition][time_point]):
            compute_graph_properties(G)
# Out:
# Subject 1's adjacency matrix statistics: min=0.0, max=0.9669296518852937, mean=0.026754576171030824, std=0.125519595443347
# Subject 1's graph has 360 nodes and 2874 edges
# Subject 2's adjacency matrix statistics: min=0.0, max=0.9064871443245813, mean=0.022275358764450946, std=0.114923796882681
# Subject 2's graph has 360 nodes and 2392 edges
# Subject 3's adjacency matrix statistics: min=0.0, max=0.9215171434557743, mean=0.023418361685435794, std=0.11761171434693833
# Subject 3's graph has 360 nodes and 2517 edges
# Subject 4's adjacency matrix statistics: min=0.0, max=0.9528517972659791, mean=0.05274378267958288, std=0.17421345456950066
# Subject 4's graph has 360 nodes and 5562 edges
# Subject 5's adjacency matrix statistics: min=0.0, max=0.9581659637912631, mean=0.03615223425327563, std=0.14474192596000882
# Subject 5's graph has 360 nodes and 3883 edges
# Subject 6's adjacency matrix statistics: min=0.0, max=0.9634769108927196, mean=0.02873920597582041, std=0.13167396340698395
# Subject 6's graph has 360 nodes and 3016 edges
# Subject 7's adjacency matrix statistics: min=0.0, max=0.9422250575653092, mean=0.034426958657743686, std=0.14223717567649924
# Subject 7's graph has 360 nodes and 3660 edges
# Subject 8's adjacency matrix statistics: min=0.0, max=0.9373750733811733, mean=0.01980843436731463, std=0.10937496437471078
# Subject 8's graph has 360 nodes and 2102 edges
# Subject 9's adjacency matrix statistics: min=0.0, max=0.9413807490766201, mean=0.023881846950457124, std=0.11963117055208376
# Subject 9's graph has 360 nodes and 2542 edges
# Subject 10's adjacency matrix statistics: min=0.0, max=0.9505933384915863, mean=0.022120035696253287, std=0.1147981264600159
# Subject 10's graph has 360 nodes and 2369 edges
# Subject 11's adjacency matrix statistics: min=0.0, max=0.940372802363991, mean=0.029420478730703668, std=0.13216291957042675
# Subject 11's graph has 360 nodes and 3122 edges
# Subject 12's adjacency matrix statistics: min=0.0, max=0.9706418352557465, mean=0.032225844750959194, std=0.1389470268686275
# Subject 12's graph has 360 nodes and 3382 edges
# Subject 13's adjacency matrix statistics: min=0.0, max=0.9509951133807468, mean=0.062014513760328696, std=0.18822405962192948
# Subject 13's graph has 360 nodes and 6480 edges
# Subject 14's adjacency matrix statistics: min=0.0, max=0.9559061697936487, mean=0.020533775235129354, std=0.10965000017763048
# Subject 14's graph has 360 nodes and 2234 edges
# Subject 15's adjacency matrix statistics: min=0.0, max=0.9361003720763431, mean=0.025168301248068174, std=0.12292929954880615
# Subject 15's graph has 360 nodes and 2661 edges
# Subject 16's adjacency matrix statistics: min=0.0, max=0.9514127177508455, mean=0.0494842956271585, std=0.16884429433728648
# Subject 16's graph has 360 nodes and 5234 edges
# Subject 17's adjacency matrix statistics: min=0.0, max=0.9619055219819213, mean=0.033410155242452264, std=0.1406406348815574
# Subject 17's graph has 360 nodes and 3537 edges
# Subject 18's adjacency matrix statistics: min=0.0, max=0.9243338147936707, mean=0.02829724768666538, std=0.12890804059818056
# Subject 18's graph has 360 nodes and 3038 edges
# Subject 19's adjacency matrix statistics: min=0.0, max=0.9479517471019343, mean=0.02634376018541437, std=0.1254065979143746
# Subject 19's graph has 360 nodes and 2797 edges
# Subject 20's adjacency matrix statistics: min=0.0, max=0.8966027814194812, mean=0.013220293589340217, std=0.08836411306192642
# Subject 20's graph has 360 nodes and 1443 edges
# Subject 1's adjacency matrix statistics: min=0.0, max=0.9664982292611872, mean=0.030121901914277684, std=0.13303754099988166
# Subject 1's graph has 360 nodes and 3226 edges
# Subject 2's adjacency matrix statistics: min=0.0, max=0.9457056810486273, mean=0.030433318519268573, std=0.13443562261847763
# Subject 2's graph has 360 nodes and 3222 edges
# Subject 3's adjacency matrix statistics: min=0.0, max=0.910738176172647, mean=0.0176976229976583, std=0.10291940536992307
# Subject 3's graph has 360 nodes and 1896 edges
# Subject 4's adjacency matrix statistics: min=0.0, max=0.9480314822087506, mean=0.033724746551005776, std=0.14154644671529587
# Subject 4's graph has 360 nodes and 3556 edges
# Subject 5's adjacency matrix statistics: min=0.0, max=0.9506683939152714, mean=0.05360561537548575, std=0.17555621722017256
# Subject 5's graph has 360 nodes and 5646 edges
# Subject 6's adjacency matrix statistics: min=0.0, max=0.948182133303956, mean=0.024749806283673764, std=0.12164155645076088
# Subject 6's graph has 360 nodes and 2633 edges
# Subject 7's adjacency matrix statistics: min=0.0, max=0.9430412609223636, mean=0.030814273737209144, std=0.13461259840094358
# Subject 7's graph has 360 nodes and 3290 edges
# Subject 8's adjacency matrix statistics: min=0.0, max=0.9167975406595192, mean=0.02450249452594743, std=0.12045425520985424
# Subject 8's graph has 360 nodes and 2624 edges
# Subject 9's adjacency matrix statistics: min=0.0, max=0.9307840405059915, mean=0.02827294919337147, std=0.12947132983430867
# Subject 9's graph has 360 nodes and 3014 edges
# Subject 10's adjacency matrix statistics: min=0.0, max=0.957674512237694, mean=0.027045848575042015, std=0.12696465165634224
# Subject 10's graph has 360 nodes and 2872 edges
# Subject 11's adjacency matrix statistics: min=0.0, max=0.9477996820777254, mean=0.025531227344901375, std=0.1228262954749944
# Subject 11's graph has 360 nodes and 2738 edges
# Subject 12's adjacency matrix statistics: min=0.0, max=0.9607153704978622, mean=0.034121083487849514, std=0.14281138420589048
# Subject 12's graph has 360 nodes and 3586 edges
# Subject 13's adjacency matrix statistics: min=0.0, max=0.9320301464076358, mean=0.03772860819166914, std=0.14935276858926874
# Subject 13's graph has 360 nodes and 3968 edges
# Subject 14's adjacency matrix statistics: min=0.0, max=0.9223918050695004, mean=0.0154475590287392, std=0.09489776597375343
# Subject 14's graph has 360 nodes and 1700 edges
# Subject 15's adjacency matrix statistics: min=0.0, max=0.9326049964763298, mean=0.0317129695802455, std=0.13808932235822838
# Subject 15's graph has 360 nodes and 3317 edges
# Subject 16's adjacency matrix statistics: min=0.0, max=0.9575355480425892, mean=0.05209506282486461, std=0.17321419998958063
# Subject 16's graph has 360 nodes and 5491 edges
# Subject 17's adjacency matrix statistics: min=0.0, max=0.9507107540141754, mean=0.03588239506274236, std=0.14472181081648244
# Subject 17's graph has 360 nodes and 3829 edges
# Subject 18's adjacency matrix statistics: min=0.0, max=0.9599589969008974, mean=0.030976623695974398, std=0.1346466141460245
# Subject 18's graph has 360 nodes and 3320 edges
# Subject 19's adjacency matrix statistics: min=0.0, max=0.9433978480022323, mean=0.029575270524970616, std=0.13206651815508566
# Subject 19's graph has 360 nodes and 3159 edges
# Subject 20's adjacency matrix statistics: min=0.0, max=0.9190767967696106, mean=0.0163018446996954, std=0.09834208849636815
# Subject 20's graph has 360 nodes and 1765 edges
# Subject 1's adjacency matrix statistics: min=0.0, max=0.9134073178953455, mean=0.01892643790074564, std=0.10660946244139244
# Subject 1's graph has 360 nodes and 2022 edges
# Subject 2's adjacency matrix statistics: min=0.0, max=0.9422061206338165, mean=0.03698075427315469, std=0.14700215884567414
# Subject 2's graph has 360 nodes and 3936 edges
# Subject 3's adjacency matrix statistics: min=0.0, max=0.9065132359624088, mean=0.02384534232918631, std=0.11846715647761999
# Subject 3's graph has 360 nodes and 2570 edges
# Subject 4's adjacency matrix statistics: min=0.0, max=0.9463559188549127, mean=0.03734545147597506, std=0.14871890744512203
# Subject 4's graph has 360 nodes and 3931 edges
# Subject 5's adjacency matrix statistics: min=0.0, max=0.9408526935750857, mean=0.03226689109661764, std=0.13785048176530998
# Subject 5's graph has 360 nodes and 3434 edges
# Subject 6's adjacency matrix statistics: min=0.0, max=0.9293334758649785, mean=0.014195529510975136, std=0.09168361323114536
# Subject 6's graph has 360 nodes and 1545 edges
# Subject 7's adjacency matrix statistics: min=0.0, max=0.9258477045997606, mean=0.021600102960042524, std=0.11378241101772744
# Subject 7's graph has 360 nodes and 2300 edges
# Subject 8's adjacency matrix statistics: min=0.0, max=0.9311948186715803, mean=0.02630120469093231, std=0.12454898531365158
# Subject 8's graph has 360 nodes and 2822 edges
# Subject 9's adjacency matrix statistics: min=0.0, max=0.9524318452761428, mean=0.03323653808668562, std=0.14054896980453346
# Subject 9's graph has 360 nodes and 3511 edges
# Subject 10's adjacency matrix statistics: min=0.0, max=0.9250355670817497, mean=0.025266061189671177, std=0.12274609516505008
# Subject 10's graph has 360 nodes and 2690 edges
# Subject 11's adjacency matrix statistics: min=0.0, max=0.9223937489773745, mean=0.017001493841910558, std=0.10080984671132388
# Subject 11's graph has 360 nodes and 1827 edges
# Subject 12's adjacency matrix statistics: min=0.0, max=0.9705979842851385, mean=0.0338985550175075, std=0.14361671008366572
# Subject 12's graph has 360 nodes and 3505 edges
# Subject 13's adjacency matrix statistics: min=0.0, max=0.9534444918607518, mean=0.054817553804983536, std=0.17655799216713863
# Subject 13's graph has 360 nodes and 5811 edges
# Subject 14's adjacency matrix statistics: min=0.0, max=0.9061989664938784, mean=0.01665544982796175, std=0.09910459128035728
# Subject 14's graph has 360 nodes and 1812 edges
# Subject 15's adjacency matrix statistics: min=0.0, max=0.9493998273936559, mean=0.03041932427301944, std=0.13517729694931901
# Subject 15's graph has 360 nodes and 3190 edges
# Subject 16's adjacency matrix statistics: min=0.0, max=0.9320510677601358, mean=0.062015313179001816, std=0.1887930802624641
# Subject 16's graph has 360 nodes and 6452 edges
# Subject 17's adjacency matrix statistics: min=0.0, max=0.9381330941312649, mean=0.06232921113023155, std=0.1869195953718378
# Subject 17's graph has 360 nodes and 6618 edges
# Subject 18's adjacency matrix statistics: min=0.0, max=0.9442686205967452, mean=0.02797696462460252, std=0.1290521458489873
# Subject 18's graph has 360 nodes and 2970 edges
# Subject 19's adjacency matrix statistics: min=0.0, max=0.9645008734908712, mean=0.03383304506766939, std=0.1425761409711749
# Subject 19's graph has 360 nodes and 3532 edges
# Subject 20's adjacency matrix statistics: min=0.0, max=0.9489411239040797, mean=0.020144922490465386, std=0.10942138979616049
# Subject 20's graph has 360 nodes and 2166 edges
# Subject 1's adjacency matrix statistics: min=0.0, max=0.9548859028884548, mean=0.03156416927885157, std=0.13626033229748052
# Subject 1's graph has 360 nodes and 3366 edges
# Subject 2's adjacency matrix statistics: min=0.0, max=0.9771512583772158, mean=0.021467583577689457, std=0.11413949898938251
# Subject 2's graph has 360 nodes and 2263 edges
# Subject 3's adjacency matrix statistics: min=0.0, max=0.9316048107879115, mean=0.029750954333102833, std=0.13193654369693963
# Subject 3's graph has 360 nodes and 3197 edges
# Subject 4's adjacency matrix statistics: min=0.0, max=0.9429487787997829, mean=0.027106552378223136, std=0.12851437632122467
# Subject 4's graph has 360 nodes and 2825 edges
# Subject 5's adjacency matrix statistics: min=0.0, max=0.9730165828338554, mean=0.03942198132171776, std=0.15365319029339963
# Subject 5's graph has 360 nodes and 4100 edges
# Subject 6's adjacency matrix statistics: min=0.0, max=0.9544831253388125, mean=0.062334953926909444, std=0.1876009632986507
# Subject 6's graph has 360 nodes and 6581 edges
# Subject 7's adjacency matrix statistics: min=0.0, max=0.9607412225809658, mean=0.03510716890113819, std=0.14416510292709464
# Subject 7's graph has 360 nodes and 3712 edges
# Subject 8's adjacency matrix statistics: min=0.0, max=0.9613396083449647, mean=0.030968611648309347, std=0.1359929343613223
# Subject 8's graph has 360 nodes and 3266 edges
# Subject 9's adjacency matrix statistics: min=0.0, max=0.9602259186048651, mean=0.04045196361398876, std=0.15294927699953154
# Subject 9's graph has 360 nodes and 4322 edges
# Subject 10's adjacency matrix statistics: min=0.0, max=0.9557581285138472, mean=0.05623966114007093, std=0.18045460919288242
# Subject 10's graph has 360 nodes and 5869 edges
# Subject 11's adjacency matrix statistics: min=0.0, max=0.9632383426286446, mean=0.038096067622834656, std=0.15067957777623797
# Subject 11's graph has 360 nodes and 3980 edges
# Subject 12's adjacency matrix statistics: min=0.0, max=0.9444510996204667, mean=0.031774945190721174, std=0.13664626169395946
# Subject 12's graph has 360 nodes and 3389 edges
# Subject 13's adjacency matrix statistics: min=0.0, max=0.9715892252506984, mean=0.03976532157705063, std=0.15373618352519053
# Subject 13's graph has 360 nodes and 4159 edges
# Subject 14's adjacency matrix statistics: min=0.0, max=0.9615018590038277, mean=0.0369030533552856, std=0.14778663438012923
# Subject 14's graph has 360 nodes and 3886 edges
# Subject 15's adjacency matrix statistics: min=0.0, max=0.9719461142354608, mean=0.03399335426220099, std=0.142350478161893
# Subject 15's graph has 360 nodes and 3573 edges
# Subject 16's adjacency matrix statistics: min=0.0, max=0.9653934452697235, mean=0.053980655762272046, std=0.1765246752161475
# Subject 16's graph has 360 nodes and 5662 edges
# Subject 17's adjacency matrix statistics: min=0.0, max=0.9253168419351018, mean=0.019570045181846248, std=0.10791742469514248
# Subject 17's graph has 360 nodes and 2105 edges
# Subject 18's adjacency matrix statistics: min=0.0, max=0.9553788418093632, mean=0.025075806227356813, std=0.12317883369372157
# Subject 18's graph has 360 nodes and 2641 edges
# Subject 19's adjacency matrix statistics: min=0.0, max=0.9362085899818018, mean=0.021220236697181757, std=0.1128190318089675
# Subject 19's graph has 360 nodes and 2259 edges
# Subject 20's adjacency matrix statistics: min=0.0, max=0.9312967708833259, mean=0.038528753561546183, std=0.14897297132430687
# Subject 20's graph has 360 nodes and 4143 edges
# Subject 21's adjacency matrix statistics: min=0.0, max=0.9515561372272572, mean=0.0202383535300261, std=0.10994693427251712
# Subject 21's graph has 360 nodes and 2166 edges
# Subject 22's adjacency matrix statistics: min=0.0, max=0.950368900306805, mean=0.028516186536170822, std=0.13057400753772386
# Subject 22's graph has 360 nodes and 3012 edges
# Subject 1's adjacency matrix statistics: min=0.0, max=0.9101732555332531, mean=0.02846802830415932, std=0.12973106104256624
# Subject 1's graph has 360 nodes and 3035 edges
# Subject 2's adjacency matrix statistics: min=0.0, max=0.9792428334780711, mean=0.03077486763347099, std=0.1363483375442493
# Subject 2's graph has 360 nodes and 3212 edges
# Subject 3's adjacency matrix statistics: min=0.0, max=0.9302432660707737, mean=0.032875848021306796, std=0.13906391445711838
# Subject 3's graph has 360 nodes and 3500 edges
# Subject 4's adjacency matrix statistics: min=0.0, max=0.9497644820102211, mean=0.03780706215494461, std=0.14958130562395303
# Subject 4's graph has 360 nodes and 3980 edges
# Subject 5's adjacency matrix statistics: min=0.0, max=0.9549163448037884, mean=0.03579053819621971, std=0.14612550148477368
# Subject 5's graph has 360 nodes and 3745 edges
# Subject 6's adjacency matrix statistics: min=0.0, max=0.9498687449252489, mean=0.04338746012378149, std=0.1573045048249587
# Subject 6's graph has 360 nodes and 4673 edges
# Subject 7's adjacency matrix statistics: min=0.0, max=0.932621480325621, mean=0.042390832111239195, std=0.15625736868412413
# Subject 7's graph has 360 nodes and 4531 edges
# Subject 8's adjacency matrix statistics: min=0.0, max=0.9498508742523029, mean=0.03345015980700405, std=0.14058633762289013
# Subject 8's graph has 360 nodes and 3546 edges
# Subject 9's adjacency matrix statistics: min=0.0, max=0.9514557545783926, mean=0.03404049750832805, std=0.14168849608991183
# Subject 9's graph has 360 nodes and 3616 edges
# Subject 10's adjacency matrix statistics: min=0.0, max=0.94829925776626, mean=0.05039084913981339, std=0.17139399893547755
# Subject 10's graph has 360 nodes and 5271 edges
# Subject 11's adjacency matrix statistics: min=0.0, max=0.9580013364339429, mean=0.04021041119039329, std=0.15462338260710495
# Subject 11's graph has 360 nodes and 4197 edges
# Subject 12's adjacency matrix statistics: min=0.0, max=0.949332693085492, mean=0.027931790296745043, std=0.1285894987038045
# Subject 12's graph has 360 nodes and 2982 edges
# Subject 13's adjacency matrix statistics: min=0.0, max=0.9418970444731612, mean=0.0324181469969615, std=0.1384126859751977
# Subject 13's graph has 360 nodes and 3440 edges
# Subject 14's adjacency matrix statistics: min=0.0, max=0.9674231598604128, mean=0.05000834977653512, std=0.17229263593767463
# Subject 14's graph has 360 nodes and 5150 edges
# Subject 15's adjacency matrix statistics: min=0.0, max=0.975993968422101, mean=0.030912201296277298, std=0.13528934951176963
# Subject 15's graph has 360 nodes and 3281 edges
# Subject 16's adjacency matrix statistics: min=0.0, max=0.9634640931809231, mean=0.0726926491185649, std=0.20037460287538525
# Subject 16's graph has 360 nodes and 7693 edges
# Subject 17's adjacency matrix statistics: min=0.0, max=0.9430050141289893, mean=0.02437986753641139, std=0.12024533825303142
# Subject 17's graph has 360 nodes and 2610 edges
# Subject 18's adjacency matrix statistics: min=0.0, max=0.9413701179504177, mean=0.027885313072992714, std=0.12943395750902936
# Subject 18's graph has 360 nodes and 2941 edges
# Subject 19's adjacency matrix statistics: min=0.0, max=0.9418004625968367, mean=0.023433214752336454, std=0.11947901808293372
# Subject 19's graph has 360 nodes and 2458 edges
# Subject 20's adjacency matrix statistics: min=0.0, max=0.9280830079619515, mean=0.022866789973319892, std=0.11654772398089895
# Subject 20's graph has 360 nodes and 2449 edges
# Subject 21's adjacency matrix statistics: min=0.0, max=0.9564896975645086, mean=0.0196191617813964, std=0.10837613851895071
# Subject 21's graph has 360 nodes and 2097 edges
# Subject 22's adjacency matrix statistics: min=0.0, max=0.9417937141411908, mean=0.03214361660567343, std=0.13804585951274623
# Subject 22's graph has 360 nodes and 3406 edges
# Subject 1's adjacency matrix statistics: min=0.0, max=0.9544261043823905, mean=0.03583705389315535, std=0.144317995370223
# Subject 1's graph has 360 nodes and 3835 edges
# Subject 2's adjacency matrix statistics: min=0.0, max=0.9727239235464205, mean=0.02988445820140712, std=0.13367865595500417
# Subject 2's graph has 360 nodes and 3151 edges
# Subject 3's adjacency matrix statistics: min=0.0, max=0.9503789421332455, mean=0.022762511704998184, std=0.11608846366602871
# Subject 3's graph has 360 nodes and 2447 edges
# Subject 4's adjacency matrix statistics: min=0.0, max=0.9419698249600601, mean=0.03101108569428798, std=0.13709878055363156
# Subject 4's graph has 360 nodes and 3227 edges
# Subject 5's adjacency matrix statistics: min=0.0, max=0.9682403762972762, mean=0.04657968066744567, std=0.1648528875990268
# Subject 5's graph has 360 nodes and 4897 edges
# Subject 6's adjacency matrix statistics: min=0.0, max=0.9528676296851747, mean=0.04844521742340141, std=0.1668913086485932
# Subject 6's graph has 360 nodes and 5142 edges
# Subject 7's adjacency matrix statistics: min=0.0, max=0.9537474285792572, mean=0.03326149126530449, std=0.1417791676039291
# Subject 7's graph has 360 nodes and 3457 edges
# Subject 8's adjacency matrix statistics: min=0.0, max=0.9631736357023163, mean=0.029985673914204945, std=0.13383346135995328
# Subject 8's graph has 360 nodes and 3165 edges
# Subject 9's adjacency matrix statistics: min=0.0, max=0.9547923653981745, mean=0.047256746945237606, std=0.16443953802130562
# Subject 9's graph has 360 nodes and 5042 edges
# Subject 10's adjacency matrix statistics: min=0.0, max=0.9545442089294572, mean=0.05860909994225739, std=0.1850778438356929
# Subject 10's graph has 360 nodes and 6045 edges
# Subject 11's adjacency matrix statistics: min=0.0, max=0.9523124174519958, mean=0.047355522442703066, std=0.1676398718081692
# Subject 11's graph has 360 nodes and 4907 edges
# Subject 12's adjacency matrix statistics: min=0.0, max=0.9416928753698234, mean=0.061749250312475086, std=0.18832007184795457
# Subject 12's graph has 360 nodes and 6417 edges
# Subject 13's adjacency matrix statistics: min=0.0, max=0.9415874167580535, mean=0.02622831589199554, std=0.12484307629113571
# Subject 13's graph has 360 nodes and 2796 edges
# Subject 14's adjacency matrix statistics: min=0.0, max=0.9707701307296552, mean=0.04370514950254916, std=0.16095696249610997
# Subject 14's graph has 360 nodes and 4554 edges
# Subject 15's adjacency matrix statistics: min=0.0, max=0.965381655808108, mean=0.029228057818833073, std=0.13155649783743914
# Subject 15's graph has 360 nodes and 3113 edges
# Subject 16's adjacency matrix statistics: min=0.0, max=0.9482143609416127, mean=0.04523808734956251, std=0.16182852710370085
# Subject 16's graph has 360 nodes and 4796 edges
# Subject 17's adjacency matrix statistics: min=0.0, max=0.9420881459315552, mean=0.03607994047236912, std=0.14460662691799056
# Subject 17's graph has 360 nodes and 3871 edges
# Subject 18's adjacency matrix statistics: min=0.0, max=0.9376061515741468, mean=0.02217248552900947, std=0.11601742886861467
# Subject 18's graph has 360 nodes and 2336 edges
# Subject 19's adjacency matrix statistics: min=0.0, max=0.9407945035024113, mean=0.022426368988121472, std=0.11511431311597589
# Subject 19's graph has 360 nodes and 2416 edges
# Subject 20's adjacency matrix statistics: min=0.0, max=0.9365462001989501, mean=0.030367616825557622, std=0.1329896908823659
# Subject 20's graph has 360 nodes and 3272 edges
# Subject 21's adjacency matrix statistics: min=0.0, max=0.942623461124676, mean=0.022416407680457547, std=0.11536946126357205
# Subject 21's graph has 360 nodes and 2404 edges
# Subject 22's adjacency matrix statistics: min=0.0, max=0.9483393070296826, mean=0.03852755302468878, std=0.1514186573708764
# Subject 22's graph has 360 nodes and 4031 edges
# Subject 1's adjacency matrix statistics: min=0.0, max=0.9491540488123955, mean=0.031037043105582304, std=0.13464539257825736
# Subject 1's graph has 360 nodes and 3334 edges
# Subject 2's adjacency matrix statistics: min=0.0, max=0.9672737482717683, mean=0.04049638470306349, std=0.15399852483039775
# Subject 2's graph has 360 nodes and 4288 edges
# Subject 3's adjacency matrix statistics: min=0.0, max=0.942516115096892, mean=0.026930233557572774, std=0.12710563785225473
# Subject 3's graph has 360 nodes and 2849 edges
# Subject 4's adjacency matrix statistics: min=0.0, max=0.9258769567255971, mean=0.025422081801147873, std=0.12302998836264022
# Subject 4's graph has 360 nodes and 2707 edges
# Subject 5's adjacency matrix statistics: min=0.0, max=0.9417900524484261, mean=0.03103666751634448, std=0.1362901681207222
# Subject 5's graph has 360 nodes and 3266 edges
# Subject 6's adjacency matrix statistics: min=0.0, max=0.9602512619874819, mean=0.0351949058467159, std=0.1445105808104585
# Subject 6's graph has 360 nodes and 3707 edges
# Subject 7's adjacency matrix statistics: min=0.0, max=0.9762039998121014, mean=0.04300504490355806, std=0.15896115970775931
# Subject 7's graph has 360 nodes and 4519 edges
# Subject 8's adjacency matrix statistics: min=0.0, max=0.963515635208757, mean=0.02350937053528921, std=0.11851116655080639
# Subject 8's graph has 360 nodes and 2503 edges
# Subject 9's adjacency matrix statistics: min=0.0, max=0.923255569523481, mean=0.018917836731438303, std=0.10537210375816591
# Subject 9's graph has 360 nodes and 2061 edges
# Subject 10's adjacency matrix statistics: min=0.0, max=0.9448315804204179, mean=0.030311388764194924, std=0.1344711771640273
# Subject 10's graph has 360 nodes and 3204 edges
# Subject 11's adjacency matrix statistics: min=0.0, max=0.9788040682242725, mean=0.041607462091275325, std=0.15685975464931431
# Subject 11's graph has 360 nodes and 4363 edges
# Subject 12's adjacency matrix statistics: min=0.0, max=0.9374367500073845, mean=0.020595642700068657, std=0.1118016690497201
# Subject 12's graph has 360 nodes and 2172 edges
# Subject 13's adjacency matrix statistics: min=0.0, max=0.9282968256608651, mean=0.029070937926434767, std=0.13128749875706094
# Subject 13's graph has 360 nodes and 3089 edges
# Subject 14's adjacency matrix statistics: min=0.0, max=0.9452504295242211, mean=0.03305854141265974, std=0.139998306753688
# Subject 14's graph has 360 nodes and 3500 edges
# Subject 15's adjacency matrix statistics: min=0.0, max=0.9593289356438128, mean=0.02396294890679722, std=0.119119483054957
# Subject 15's graph has 360 nodes and 2571 edges
# Subject 16's adjacency matrix statistics: min=0.0, max=0.9125574854028047, mean=0.030065903341573937, std=0.13268756890373098
# Subject 16's graph has 360 nodes and 3226 edges
# Subject 17's adjacency matrix statistics: min=0.0, max=0.9419098736206476, mean=0.02831701946474378, std=0.1306458243022065
# Subject 17's graph has 360 nodes and 2975 edges
# Subject 18's adjacency matrix statistics: min=0.0, max=0.9329269928663044, mean=0.028001434873428984, std=0.13016639116730314
# Subject 18's graph has 360 nodes and 2930 edges
# Subject 19's adjacency matrix statistics: min=0.0, max=0.927898967451469, mean=0.03946965880677065, std=0.15246659554954406
# Subject 19's graph has 360 nodes and 4156 edges
# Subject 20's adjacency matrix statistics: min=0.0, max=0.9396875628276556, mean=0.01781240360532205, std=0.10319211995456672
# Subject 20's graph has 360 nodes and 1910 edges
# Subject 21's adjacency matrix statistics: min=0.0, max=0.9681985894310113, mean=0.034872203221561975, std=0.14419256582166873
# Subject 21's graph has 360 nodes and 3661 edges
# Subject 22's adjacency matrix statistics: min=0.0, max=0.9501086435118123, mean=0.04766450629782264, std=0.16583528572297757
# Subject 22's graph has 360 nodes and 5046 edges
# Subject 1's adjacency matrix statistics: min=0.0, max=0.9387714391595144, mean=0.022340055547273422, std=0.11467579160863425
# Subject 1's graph has 360 nodes and 2415 edges
# Subject 2's adjacency matrix statistics: min=0.0, max=0.9594549875185595, mean=0.031077330932378494, std=0.13617503702548026
# Subject 2's graph has 360 nodes and 3282 edges
# Subject 3's adjacency matrix statistics: min=0.0, max=0.9272645493396504, mean=0.03269826592627912, std=0.13936963570502953
# Subject 3's graph has 360 nodes and 3453 edges
# Subject 4's adjacency matrix statistics: min=0.0, max=0.9417426764460364, mean=0.034026285120797015, std=0.14238979401517055
# Subject 4's graph has 360 nodes and 3577 edges
# Subject 5's adjacency matrix statistics: min=0.0, max=0.9515282554017107, mean=0.04297336833805664, std=0.15871581347660013
# Subject 5's graph has 360 nodes and 4527 edges
# Subject 6's adjacency matrix statistics: min=0.0, max=0.9571234354404528, mean=0.05699217162324464, std=0.18328624586744968
# Subject 6's graph has 360 nodes and 5848 edges
# Subject 7's adjacency matrix statistics: min=0.0, max=0.9654314302078004, mean=0.026041771264011932, std=0.12449295591763575
# Subject 7's graph has 360 nodes and 2773 edges
# Subject 8's adjacency matrix statistics: min=0.0, max=0.9533416554431915, mean=0.019915098764229665, std=0.11024305543250458
# Subject 8's graph has 360 nodes and 2096 edges
# Subject 9's adjacency matrix statistics: min=0.0, max=0.9537994264573424, mean=0.0377228481726472, std=0.1481383106150834
# Subject 9's graph has 360 nodes and 4028 edges
# Subject 10's adjacency matrix statistics: min=0.0, max=0.9435994389158573, mean=0.03431912594955265, std=0.14280005084329078
# Subject 10's graph has 360 nodes and 3617 edges
# Subject 11's adjacency matrix statistics: min=0.0, max=0.9599166267556982, mean=0.044358990055158073, std=0.1603227875964544
# Subject 11's graph has 360 nodes and 4706 edges
# Subject 12's adjacency matrix statistics: min=0.0, max=0.9543037035360191, mean=0.026259351192100416, std=0.125760875344868
# Subject 12's graph has 360 nodes and 2766 edges
# Subject 13's adjacency matrix statistics: min=0.0, max=0.9541875146934331, mean=0.025191637661474267, std=0.12279648560145755
# Subject 13's graph has 360 nodes and 2672 edges
# Subject 14's adjacency matrix statistics: min=0.0, max=0.9404754567869152, mean=0.030539098627765007, std=0.1355696516588581
# Subject 14's graph has 360 nodes and 3202 edges
# Subject 15's adjacency matrix statistics: min=0.0, max=0.9205880391354362, mean=0.019208031207762648, std=0.1068598338657053
# Subject 15's graph has 360 nodes and 2068 edges
# Subject 16's adjacency matrix statistics: min=0.0, max=0.9589700587376027, mean=0.02454459020051072, std=0.12062626902805416
# Subject 16's graph has 360 nodes and 2630 edges
# Subject 17's adjacency matrix statistics: min=0.0, max=0.9506808730967122, mean=0.04737671748118208, std=0.16749402187346607
# Subject 17's graph has 360 nodes and 4915 edges
# Subject 18's adjacency matrix statistics: min=0.0, max=0.9388471395286335, mean=0.03215375239605225, std=0.13885283222931336
# Subject 18's graph has 360 nodes and 3370 edges
# Subject 19's adjacency matrix statistics: min=0.0, max=0.9272028198670925, mean=0.040971349105587265, std=0.15442462629986026
# Subject 19's graph has 360 nodes and 4345 edges
# Subject 20's adjacency matrix statistics: min=0.0, max=0.9548697013071274, mean=0.019945395074481467, std=0.10877538331070462
# Subject 20's graph has 360 nodes and 2148 edges
# Subject 21's adjacency matrix statistics: min=0.0, max=0.9343539068444425, mean=0.029068592955374162, std=0.13235889891622768
# Subject 21's graph has 360 nodes and 3050 edges
# Subject 22's adjacency matrix statistics: min=0.0, max=0.9654755900847272, mean=0.05647156200320008, std=0.18210516852918007
# Subject 22's graph has 360 nodes and 5819 edges
# Subject 1's adjacency matrix statistics: min=0.0, max=0.9507361269487463, mean=0.024228307060850798, std=0.12014271872686495
# Subject 1's graph has 360 nodes and 2583 edges
# Subject 2's adjacency matrix statistics: min=0.0, max=0.9524606793482024, mean=0.036759748037088466, std=0.14791777610006013
# Subject 2's graph has 360 nodes and 3859 edges
# Subject 3's adjacency matrix statistics: min=0.0, max=0.9410776344113897, mean=0.02390191713059114, std=0.11992874458098442
# Subject 3's graph has 360 nodes and 2528 edges
# Subject 4's adjacency matrix statistics: min=0.0, max=0.9293589206275266, mean=0.025907118113415856, std=0.12383140449742708
# Subject 4's graph has 360 nodes and 2774 edges
# Subject 5's adjacency matrix statistics: min=0.0, max=0.9313563559780178, mean=0.03312703219652957, std=0.1398463527460724
# Subject 5's graph has 360 nodes and 3516 edges
# Subject 6's adjacency matrix statistics: min=0.0, max=0.9657536416522372, mean=0.03258975347191116, std=0.1395052436590426
# Subject 6's graph has 360 nodes and 3429 edges
# Subject 7's adjacency matrix statistics: min=0.0, max=0.9692522414595429, mean=0.03279367185990197, std=0.1394475957898249
# Subject 7's graph has 360 nodes and 3472 edges
# Subject 8's adjacency matrix statistics: min=0.0, max=0.9668495592186163, mean=0.0306992180064113, std=0.13532890211649734
# Subject 8's graph has 360 nodes and 3242 edges
# Subject 9's adjacency matrix statistics: min=0.0, max=0.944088884681664, mean=0.020641258989764988, std=0.11087173914254564
# Subject 9's graph has 360 nodes and 2217 edges
# Subject 10's adjacency matrix statistics: min=0.0, max=0.9574326995466188, mean=0.03892341332343734, std=0.15206007898932686
# Subject 10's graph has 360 nodes and 4073 edges
# Subject 11's adjacency matrix statistics: min=0.0, max=0.9427239724127809, mean=0.06262400207775184, std=0.18742227923884794
# Subject 11's graph has 360 nodes and 6642 edges
# Subject 12's adjacency matrix statistics: min=0.0, max=0.9599263285164855, mean=0.026822647702506905, std=0.12670136663603257
# Subject 12's graph has 360 nodes and 2840 edges
# Subject 13's adjacency matrix statistics: min=0.0, max=0.9317040561303152, mean=0.03411843676810013, std=0.14226253167012912
# Subject 13's graph has 360 nodes and 3599 edges
# Subject 14's adjacency matrix statistics: min=0.0, max=0.962344356217722, mean=0.0347785364797662, std=0.14450813045818223
# Subject 14's graph has 360 nodes and 3633 edges
# Subject 15's adjacency matrix statistics: min=0.0, max=0.9546533891429737, mean=0.026209859377341264, std=0.12484665259426078
# Subject 15's graph has 360 nodes and 2793 edges
# Subject 16's adjacency matrix statistics: min=0.0, max=0.9412485249785417, mean=0.02385047039545884, std=0.11928812859567699
# Subject 16's graph has 360 nodes and 2541 edges
# Subject 17's adjacency matrix statistics: min=0.0, max=0.957470544258093, mean=0.03359494800866506, std=0.14214365032129156
# Subject 17's graph has 360 nodes and 3502 edges
# Subject 18's adjacency matrix statistics: min=0.0, max=0.9554472814307094, mean=0.03191699942417984, std=0.1382913891477466
# Subject 18's graph has 360 nodes and 3351 edges
# Subject 19's adjacency matrix statistics: min=0.0, max=0.9343510831392667, mean=0.035547858637154046, std=0.14431522628893712
# Subject 19's graph has 360 nodes and 3782 edges
# Subject 20's adjacency matrix statistics: min=0.0, max=0.9331258008610522, mean=0.0293886643369551, std=0.13130941126324466
# Subject 20's graph has 360 nodes and 3152 edges
# Subject 21's adjacency matrix statistics: min=0.0, max=0.9670006919280774, mean=0.07646755721688983, std=0.20525067401046762
# Subject 21's graph has 360 nodes and 8071 edges
# Subject 22's adjacency matrix statistics: min=0.0, max=0.9447404239708517, mean=0.053051906332814376, std=0.17390695917492968
# Subject 22's graph has 360 nodes and 5629 edges
# Subject 1's adjacency matrix statistics: min=0.0, max=0.9755422597437449, mean=0.04795936428650466, std=0.16701821553644708
# Subject 1's graph has 360 nodes and 5052 edges
# Subject 2's adjacency matrix statistics: min=0.0, max=0.9399364417138443, mean=0.03443399035069727, std=0.1427943171674947
# Subject 2's graph has 360 nodes and 3637 edges
# Subject 3's adjacency matrix statistics: min=0.0, max=0.9388866409916046, mean=0.028779559880873936, std=0.1316934510971298
# Subject 3's graph has 360 nodes and 3023 edges
# Subject 4's adjacency matrix statistics: min=0.0, max=0.9453725918731727, mean=0.03348578237822494, std=0.1416192925957431
# Subject 4's graph has 360 nodes and 3509 edges
# Subject 5's adjacency matrix statistics: min=0.0, max=0.9549133745589204, mean=0.02405279380466655, std=0.11976369094186755
# Subject 5's graph has 360 nodes and 2566 edges
# Subject 6's adjacency matrix statistics: min=0.0, max=0.9536370603745348, mean=0.031309852367120916, std=0.13735464248982268
# Subject 6's graph has 360 nodes and 3277 edges
# Subject 7's adjacency matrix statistics: min=0.0, max=0.9673463797782552, mean=0.023636345735381377, std=0.11729852651624612
# Subject 7's graph has 360 nodes and 2575 edges
# Subject 8's adjacency matrix statistics: min=0.0, max=0.9487419627024094, mean=0.02445621112084877, std=0.11989510249899629
# Subject 8's graph has 360 nodes and 2638 edges
# Subject 9's adjacency matrix statistics: min=0.0, max=0.9462416067261569, mean=0.02868998927946678, std=0.13188463482146184
# Subject 9's graph has 360 nodes and 2996 edges
# Subject 10's adjacency matrix statistics: min=0.0, max=0.9557036667669847, mean=0.019834386238932803, std=0.10888318515766685
# Subject 10's graph has 360 nodes and 2126 edges
# Subject 11's adjacency matrix statistics: min=0.0, max=0.9693513729470312, mean=0.03370040958643634, std=0.14172566235325407
# Subject 11's graph has 360 nodes and 3549 edges
# Subject 12's adjacency matrix statistics: min=0.0, max=0.9247749031512342, mean=0.030373592756261513, std=0.1355550087911812
# Subject 12's graph has 360 nodes and 3170 edges
# Subject 13's adjacency matrix statistics: min=0.0, max=0.9704906434819482, mean=0.044851865140633405, std=0.16235328266013824
# Subject 13's graph has 360 nodes and 4702 edges
# Subject 14's adjacency matrix statistics: min=0.0, max=0.9379259679841913, mean=0.03300342985433151, std=0.13979489806024287
# Subject 14's graph has 360 nodes and 3496 edges
# Subject 15's adjacency matrix statistics: min=0.0, max=0.9558926475004498, mean=0.026897408921815597, std=0.12672640268267382
# Subject 15's graph has 360 nodes and 2853 edges
# Subject 16's adjacency matrix statistics: min=0.0, max=0.9593683790415515, mean=0.02284361330043367, std=0.11656833360653324
# Subject 16's graph has 360 nodes and 2444 edges
# Subject 17's adjacency matrix statistics: min=0.0, max=0.9758963460170481, mean=0.03552874737289217, std=0.1451196196794627
# Subject 17's graph has 360 nodes and 3748 edges
# Subject 18's adjacency matrix statistics: min=0.0, max=0.9555184356143814, mean=0.019545806215894135, std=0.10791945718156398
# Subject 18's graph has 360 nodes and 2102 edges
# Subject 19's adjacency matrix statistics: min=0.0, max=0.9333008263995622, mean=0.04019884287522537, std=0.15286283698462313
# Subject 19's graph has 360 nodes and 4275 edges
# Subject 20's adjacency matrix statistics: min=0.0, max=0.9564337065366517, mean=0.03963438976973811, std=0.15177814859695637
# Subject 20's graph has 360 nodes and 4222 edges
# Subject 1's adjacency matrix statistics: min=0.0, max=0.9462129460864551, mean=0.023179040303652896, std=0.11768709394894486
# Subject 1's graph has 360 nodes and 2475 edges
# Subject 2's adjacency matrix statistics: min=0.0, max=0.9423748845372812, mean=0.03009630628380646, std=0.1329889326416055
# Subject 2's graph has 360 nodes and 3219 edges
# Subject 3's adjacency matrix statistics: min=0.0, max=0.9493978532760831, mean=0.026153658178199424, std=0.1254980554072372
# Subject 3's graph has 360 nodes and 2760 edges
# Subject 4's adjacency matrix statistics: min=0.0, max=0.9296356327521694, mean=0.025274082085762827, std=0.12215551545081826
# Subject 4's graph has 360 nodes and 2714 edges
# Subject 5's adjacency matrix statistics: min=0.0, max=0.9497057246465406, mean=0.02816947782910948, std=0.12969499197083875
# Subject 5's graph has 360 nodes and 2983 edges
# Subject 6's adjacency matrix statistics: min=0.0, max=0.9858856378142619, mean=0.029988687305936082, std=0.13585914881529718
# Subject 6's graph has 360 nodes and 3086 edges
# Subject 7's adjacency matrix statistics: min=0.0, max=0.922950783341848, mean=0.033088339806865166, std=0.13799655381551895
# Subject 7's graph has 360 nodes and 3587 edges
# Subject 8's adjacency matrix statistics: min=0.0, max=0.92173764392436, mean=0.019786359760870863, std=0.10878224816852719
# Subject 8's graph has 360 nodes and 2117 edges
# Subject 9's adjacency matrix statistics: min=0.0, max=0.9400343484708538, mean=0.025245335679481062, std=0.12330911848901367
# Subject 9's graph has 360 nodes and 2663 edges
# Subject 10's adjacency matrix statistics: min=0.0, max=0.9295278889238622, mean=0.019269454530265687, std=0.1072379071838442
# Subject 10's graph has 360 nodes and 2065 edges
# Subject 11's adjacency matrix statistics: min=0.0, max=0.9348167655884869, mean=0.03238692425897189, std=0.13719674348793676
# Subject 11's graph has 360 nodes and 3487 edges
# Subject 12's adjacency matrix statistics: min=0.0, max=0.9637853239172275, mean=0.036833091296517476, std=0.1481385852801359
# Subject 12's graph has 360 nodes and 3856 edges
# Subject 13's adjacency matrix statistics: min=0.0, max=0.9608616368470748, mean=0.04197939565401502, std=0.15624324575438567
# Subject 13's graph has 360 nodes and 4457 edges
# Subject 14's adjacency matrix statistics: min=0.0, max=0.945093078181529, mean=0.039933696512047874, std=0.15373629251794196
# Subject 14's graph has 360 nodes and 4189 edges
# Subject 15's adjacency matrix statistics: min=0.0, max=0.9623627383678698, mean=0.028825847269564588, std=0.13087499262601315
# Subject 15's graph has 360 nodes and 3064 edges
# Subject 16's adjacency matrix statistics: min=0.0, max=0.9392760806881362, mean=0.020436305232766388, std=0.11034659400700217
# Subject 16's graph has 360 nodes and 2192 edges
# Subject 17's adjacency matrix statistics: min=0.0, max=0.974614621827708, mean=0.04916787604405647, std=0.1692067507666636
# Subject 17's graph has 360 nodes and 5162 edges
# Subject 18's adjacency matrix statistics: min=0.0, max=0.9534026155164885, mean=0.0186590995368483, std=0.10544331739723938
# Subject 18's graph has 360 nodes and 2007 edges
# Subject 19's adjacency matrix statistics: min=0.0, max=0.9232878105154364, mean=0.03526381186471526, std=0.14407016325863325
# Subject 19's graph has 360 nodes and 3737 edges
# Subject 20's adjacency matrix statistics: min=0.0, max=0.9478165271925287, mean=0.03473528746228447, std=0.14355687027402989
# Subject 20's graph has 360 nodes and 3661 edges
# Subject 1's adjacency matrix statistics: min=0.0, max=0.9537089739321755, mean=0.02678391477049027, std=0.12615024095643032
# Subject 1's graph has 360 nodes and 2856 edges
# Subject 2's adjacency matrix statistics: min=0.0, max=0.9676174447577259, mean=0.03746019592685029, std=0.14908474620846082
# Subject 2's graph has 360 nodes and 3933 edges
# Subject 3's adjacency matrix statistics: min=0.0, max=0.9667019951157734, mean=0.02957953489617394, std=0.1339131939436731
# Subject 3's graph has 360 nodes and 3087 edges
# Subject 4's adjacency matrix statistics: min=0.0, max=0.9429903624021645, mean=0.04199449951491165, std=0.1567859751493044
# Subject 4's graph has 360 nodes and 4433 edges
# Subject 5's adjacency matrix statistics: min=0.0, max=0.9441244120807231, mean=0.02350956859301232, std=0.11883313087580645
# Subject 5's graph has 360 nodes and 2494 edges
# Subject 6's adjacency matrix statistics: min=0.0, max=0.9696622810732635, mean=0.03084746260665981, std=0.13529629797055964
# Subject 6's graph has 360 nodes and 3267 edges
# Subject 7's adjacency matrix statistics: min=0.0, max=0.935240738880908, mean=0.051245748838876955, std=0.170372824914503
# Subject 7's graph has 360 nodes and 5479 edges
# Subject 8's adjacency matrix statistics: min=0.0, max=0.9267711980809181, mean=0.028188689575657285, std=0.12864896816100369
# Subject 8's graph has 360 nodes and 3028 edges
# Subject 9's adjacency matrix statistics: min=0.0, max=0.9512196076244508, mean=0.03225002447653349, std=0.13923141459002064
# Subject 9's graph has 360 nodes and 3374 edges
# Subject 10's adjacency matrix statistics: min=0.0, max=0.9620371781232026, mean=0.02073186439558698, std=0.11126258564395777
# Subject 10's graph has 360 nodes and 2218 edges
# Subject 11's adjacency matrix statistics: min=0.0, max=0.9437117986077586, mean=0.02737966561614377, std=0.12672886119369114
# Subject 11's graph has 360 nodes and 2947 edges
# Subject 12's adjacency matrix statistics: min=0.0, max=0.9735367093527438, mean=0.035622991831694026, std=0.14734142749970164
# Subject 12's graph has 360 nodes and 3666 edges
# Subject 13's adjacency matrix statistics: min=0.0, max=0.9552817999229044, mean=0.06573073098880199, std=0.19301360235290546
# Subject 13's graph has 360 nodes and 6881 edges
# Subject 14's adjacency matrix statistics: min=0.0, max=0.945174271596123, mean=0.03851902954595544, std=0.15070318236259353
# Subject 14's graph has 360 nodes and 4061 edges
# Subject 15's adjacency matrix statistics: min=0.0, max=0.945981800051625, mean=0.02414294048142088, std=0.11995995780652303
# Subject 15's graph has 360 nodes and 2575 edges
# Subject 16's adjacency matrix statistics: min=0.0, max=0.9480199547028249, mean=0.022805098877786464, std=0.11600527134940562
# Subject 16's graph has 360 nodes and 2458 edges
# Subject 17's adjacency matrix statistics: min=0.0, max=0.9627788925949711, mean=0.03446377060567975, std=0.14281396035539545
# Subject 17's graph has 360 nodes and 3646 edges
# Subject 18's adjacency matrix statistics: min=0.0, max=0.9699848243727152, mean=0.03231512166484194, std=0.13864950313837418
# Subject 18's graph has 360 nodes and 3411 edges
# Subject 19's adjacency matrix statistics: min=0.0, max=0.9514105687518891, mean=0.022575198031356013, std=0.1159996464867601
# Subject 19's graph has 360 nodes and 2413 edges
# Subject 20's adjacency matrix statistics: min=0.0, max=0.935556594739122, mean=0.03606704908122916, std=0.14666973978809125
# Subject 20's graph has 360 nodes and 3777 edges
# conected_component for current graph: 18
# biconnected_components for current graph: 11
# cut_vertices for current graph: 9
# conected_component for current graph: 9
# biconnected_components for current graph: 13
# cut_vertices for current graph: 9
# conected_component for current graph: 16
# biconnected_components for current graph: 17
# cut_vertices for current graph: 16
# conected_component for current graph: 6
# biconnected_components for current graph: 5
# cut_vertices for current graph: 4
# conected_component for current graph: 4
# biconnected_components for current graph: 5
# cut_vertices for current graph: 4
# conected_component for current graph: 33
# biconnected_components for current graph: 20
# cut_vertices for current graph: 15
# conected_component for current graph: 10
# biconnected_components for current graph: 15
# cut_vertices for current graph: 14
# conected_component for current graph: 26
# biconnected_components for current graph: 21
# cut_vertices for current graph: 17
# conected_component for current graph: 11
# biconnected_components for current graph: 8
# cut_vertices for current graph: 7
# conected_component for current graph: 14
# biconnected_components for current graph: 32
# cut_vertices for current graph: 28
# conected_component for current graph: 7
# biconnected_components for current graph: 14
# cut_vertices for current graph: 12
# conected_component for current graph: 1
# biconnected_components for current graph: 5
# cut_vertices for current graph: 4
# conected_component for current graph: 11
# biconnected_components for current graph: 11
# cut_vertices for current graph: 8
# conected_component for current graph: 33
# biconnected_components for current graph: 29
# cut_vertices for current graph: 25
# conected_component for current graph: 9
# biconnected_components for current graph: 14
# cut_vertices for current graph: 12
# conected_component for current graph: 3
# biconnected_components for current graph: 4
# cut_vertices for current graph: 3
# conected_component for current graph: 1
# biconnected_components for current graph: 9
# cut_vertices for current graph: 8
# conected_component for current graph: 13
# biconnected_components for current graph: 4
# cut_vertices for current graph: 3
# conected_component for current graph: 17
# biconnected_components for current graph: 17
# cut_vertices for current graph: 16
# conected_component for current graph: 29
# biconnected_components for current graph: 38
# cut_vertices for current graph: 28
# conected_component for current graph: 8
# biconnected_components for current graph: 12
# cut_vertices for current graph: 11
# conected_component for current graph: 7
# biconnected_components for current graph: 7
# cut_vertices for current graph: 6
# conected_component for current graph: 28
# biconnected_components for current graph: 25
# cut_vertices for current graph: 20
# conected_component for current graph: 4
# biconnected_components for current graph: 4
# cut_vertices for current graph: 3
# conected_component for current graph: 3
# biconnected_components for current graph: 6
# cut_vertices for current graph: 5
# conected_component for current graph: 27
# biconnected_components for current graph: 15
# cut_vertices for current graph: 12
# conected_component for current graph: 13
# biconnected_components for current graph: 11
# cut_vertices for current graph: 10
# conected_component for current graph: 20
# biconnected_components for current graph: 31
# cut_vertices for current graph: 27
# conected_component for current graph: 6
# biconnected_components for current graph: 6
# cut_vertices for current graph: 5
# conected_component for current graph: 14
# biconnected_components for current graph: 10
# cut_vertices for current graph: 8
# conected_component for current graph: 12
# biconnected_components for current graph: 15
# cut_vertices for current graph: 10
# conected_component for current graph: 1
# biconnected_components for current graph: 3
# cut_vertices for current graph: 2
# conected_component for current graph: 21
# biconnected_components for current graph: 17
# cut_vertices for current graph: 12
# conected_component for current graph: 32
# biconnected_components for current graph: 36
# cut_vertices for current graph: 32
# conected_component for current graph: 14
# biconnected_components for current graph: 22
# cut_vertices for current graph: 16
# conected_component for current graph: 3
# biconnected_components for current graph: 8
# cut_vertices for current graph: 7
# conected_component for current graph: 1
# biconnected_components for current graph: 6
# cut_vertices for current graph: 5
# conected_component for current graph: 5
# biconnected_components for current graph: 10
# cut_vertices for current graph: 9
# conected_component for current graph: 16
# ...
# biconnected_components for current graph: 8
# cut_vertices for current graph: 6
# conected_component for current graph: 10
# biconnected_components for current graph: 13
# cut_vertices for current graph: 10
# conected_component for current graph: 27
# biconnected_components for current graph: 26
# cut_vertices for current graph: 23
# conected_component for current graph: 9
# biconnected_components for current graph: 12
# cut_vertices for current graph: 10
# conected_component for current graph: 32
# biconnected_components for current graph: 25
# cut_vertices for current graph: 23
# conected_component for current graph: 12
# biconnected_components for current graph: 10
# cut_vertices for current graph: 8
# conected_component for current graph: 14
# biconnected_components for current graph: 14
# cut_vertices for current graph: 11
# conected_component for current graph: 9
# biconnected_components for current graph: 11
# cut_vertices for current graph: 10
# conected_component for current graph: 6
# biconnected_components for current graph: 6
# cut_vertices for current graph: 4
# conected_component for current graph: 3
# biconnected_components for current graph: 10
# cut_vertices for current graph: 8
# conected_component for current graph: 5
# biconnected_components for current graph: 7
# cut_vertices for current graph: 6
# conected_component for current graph: 22
# biconnected_components for current graph: 19
# cut_vertices for current graph: 14
# conected_component for current graph: 10
# biconnected_components for current graph: 4
# cut_vertices for current graph: 3
# conected_component for current graph: 14
# biconnected_components for current graph: 8
# cut_vertices for current graph: 7
# conected_component for current graph: 2
# biconnected_components for current graph: 7
# cut_vertices for current graph: 5
# conected_component for current graph: 16
# biconnected_components for current graph: 27
# cut_vertices for current graph: 23
# conected_component for current graph: 27
# biconnected_components for current graph: 17
# cut_vertices for current graph: 13
# conected_component for current graph: 12
# biconnected_components for current graph: 15
# cut_vertices for current graph: 13
# conected_component for current graph: 4
# biconnected_components for current graph: 8
# cut_vertices for current graph: 7
# conected_component for current graph: 28
# biconnected_components for current graph: 17
# cut_vertices for current graph: 15
# conected_component for current graph: 3
# biconnected_components for current graph: 11
# cut_vertices for current graph: 10
# conected_component for current graph: 19
# biconnected_components for current graph: 18
# cut_vertices for current graph: 13
# conected_component for current graph: 11
# biconnected_components for current graph: 16
# cut_vertices for current graph: 15
# conected_component for current graph: 13
# biconnected_components for current graph: 19
# cut_vertices for current graph: 15
# conected_component for current graph: 10
# biconnected_components for current graph: 8
# cut_vertices for current graph: 5
# conected_component for current graph: 11
# biconnected_components for current graph: 11
# cut_vertices for current graph: 8
# conected_component for current graph: 3
# biconnected_components for current graph: 7
# cut_vertices for current graph: 5
# conected_component for current graph: 20
# biconnected_components for current graph: 27
# cut_vertices for current graph: 23
# conected_component for current graph: 8
# biconnected_components for current graph: 8
# cut_vertices for current graph: 6
# conected_component for current graph: 10
# biconnected_components for current graph: 7
# cut_vertices for current graph: 6
# conected_component for current graph: 11
# biconnected_components for current graph: 15
# cut_vertices for current graph: 11
# conected_component for current graph: 4
# biconnected_components for current graph: 11
# cut_vertices for current graph: 8
# conected_component for current graph: 7
# biconnected_components for current graph: 5
# cut_vertices for current graph: 4
# conected_component for current graph: 18
# biconnected_components for current graph: 30
# cut_vertices for current graph: 24
# conected_component for current graph: 3
# biconnected_components for current graph: 1
# cut_vertices for current graph: 0
# conected_component for current graph: 11
# biconnected_components for current graph: 11
# cut_vertices for current graph: 9
# conected_component for current graph: 12
# biconnected_components for current graph: 10
# cut_vertices for current graph: 8
# conected_component for current graph: 17
# biconnected_components for current graph: 18
# cut_vertices for current graph: 16
# conected_component for current graph: 9
# biconnected_components for current graph: 3
# cut_vertices for current graph: 2
# conected_component for current graph: 15
# biconnected_components for current graph: 12
# cut_vertices for current graph: 11
# conected_component for current graph: 3
# biconnected_components for current graph: 6
# cut_vertices for current graph: 5
# conected_component for current graph: 28
# biconnected_components for current graph: 5
# cut_vertices for current graph: 4
# conected_component for current graph: 9
# biconnected_components for current graph: 13
# cut_vertices for current graph: 11
# conected_component for current graph: 19
# biconnected_components for current graph: 23
# cut_vertices for current graph: 20
# conected_component for current graph: 16
# biconnected_components for current graph: 14
# cut_vertices for current graph: 10
# conected_component for current graph: 20
# biconnected_components for current graph: 21
# cut_vertices for current graph: 18
# conected_component for current graph: 17
# biconnected_components for current graph: 17
# cut_vertices for current graph: 16
# conected_component for current graph: 5
# biconnected_components for current graph: 13
# cut_vertices for current graph: 10
# conected_component for current graph: 4
# biconnected_components for current graph: 7
# cut_vertices for current graph: 6
# conected_component for current graph: 27
# biconnected_components for current graph: 16
# cut_vertices for current graph: 9
# conected_component for current graph: 3
# biconnected_components for current graph: 8
# cut_vertices for current graph: 7
# conected_component for current graph: 16
# biconnected_components for current graph: 17
# cut_vertices for current graph: 13
# conected_component for current graph: 16
# biconnected_components for current graph: 22
# cut_vertices for current graph: 20
# conected_component for current graph: 5
# biconnected_components for current graph: 4
# cut_vertices for current graph: 3
# conected_component for current graph: 8
# biconnected_components for current graph: 11
# cut_vertices for current graph: 9
# conected_component for current graph: 10
# biconnected_components for current graph: 8
# cut_vertices for current graph: 6
# conected_component for current graph: 4
# biconnected_components for current graph: 4
# cut_vertices for current graph: 3
# conected_component for current graph: 8
# biconnected_components for current graph: 6
# cut_vertices for current graph: 4
# conected_component for current graph: 4
# biconnected_components for current graph: 4
# cut_vertices for current graph: 3
# conected_component for current graph: 7
# biconnected_components for current graph: 5
# cut_vertices for current graph: 3
# conected_component for current graph: 12
# biconnected_components for current graph: 13
# cut_vertices for current graph: 10
# conected_component for current graph: 11
# biconnected_components for current graph: 6
# cut_vertices for current graph: 5
# conected_component for current graph: 7
# biconnected_components for current graph: 4
# cut_vertices for current graph: 3
# conected_component for current graph: 20
# biconnected_components for current graph: 8
# cut_vertices for current graph: 6
# conected_component for current graph: 5
# biconnected_components for current graph: 9
# cut_vertices for current graph: 8
# conected_component for current graph: 23
# biconnected_components for current graph: 20
# cut_vertices for current graph: 15
# conected_component for current graph: 16
# biconnected_components for current graph: 15
# cut_vertices for current graph: 11
# conected_component for current graph: 29
# biconnected_components for current graph: 25
# cut_vertices for current graph: 22
# conected_component for current graph: 14
# biconnected_components for current graph: 11
# cut_vertices for current graph: 9
# conected_component for current graph: 10
# biconnected_components for current graph: 5
# cut_vertices for current graph: 3
# conected_component for current graph: 4
# biconnected_components for current graph: 3
# cut_vertices for current graph: 1
# conected_component for current graph: 12
# biconnected_components for current graph: 22
# cut_vertices for current graph: 17
# conected_component for current graph: 1
# biconnected_components for current graph: 3
# cut_vertices for current graph: 2
# conected_component for current graph: 6
# biconnected_components for current graph: 3
# cut_vertices for current graph: 2
# conected_component for current graph: 9
# biconnected_components for current graph: 8
# cut_vertices for current graph: 7
# conected_component for current graph: 6
# biconnected_components for current graph: 10
# cut_vertices for current graph: 9
# conected_component for current graph: 5
# biconnected_components for current graph: 9
# cut_vertices for current graph: 8
# conected_component for current graph: 12
# biconnected_components for current graph: 12
# cut_vertices for current graph: 10
# conected_component for current graph: 10
# biconnected_components for current graph: 12
# cut_vertices for current graph: 8
# conected_component for current graph: 5
# biconnected_components for current graph: 12
# cut_vertices for current graph: 10
# conected_component for current graph: 16
# biconnected_components for current graph: 12
# cut_vertices for current graph: 9
# conected_component for current graph: 17
# biconnected_components for current graph: 16
# cut_vertices for current graph: 13
# conected_component for current graph: 17
# biconnected_components for current graph: 8
# cut_vertices for current graph: 6
# conected_component for current graph: 16
# biconnected_components for current graph: 21
# cut_vertices for current graph: 17
# conected_component for current graph: 4
# biconnected_components for current graph: 6
# cut_vertices for current graph: 5
# conected_component for current graph: 4
# biconnected_components for current graph: 6
# cut_vertices for current graph: 5
# conected_component for current graph: 4
# biconnected_components for current graph: 6
# cut_vertices for current graph: 4
# conected_component for current graph: 10
# biconnected_components for current graph: 9
# cut_vertices for current graph: 7
# conected_component for current graph: 18
# biconnected_components for current graph: 15
# cut_vertices for current graph: 12
# conected_component for current graph: 23
# biconnected_components for current graph: 22
# cut_vertices for current graph: 16
# conected_component for current graph: 11
# biconnected_components for current graph: 10
# cut_vertices for current graph: 7
# conected_component for current graph: 23
# biconnected_components for current graph: 22
# cut_vertices for current graph: 21
# conected_component for current graph: 9
# biconnected_components for current graph: 10
# cut_vertices for current graph: 9
# conected_component for current graph: 17
# biconnected_components for current graph: 9
# cut_vertices for current graph: 6
# conected_component for current graph: 17
# biconnected_components for current graph: 20
# cut_vertices for current graph: 15
# conected_component for current graph: 8
# biconnected_components for current graph: 9
# cut_vertices for current graph: 8
# conected_component for current graph: 4
# biconnected_components for current graph: 7
# cut_vertices for current graph: 6
# conected_component for current graph: 12
# biconnected_components for current graph: 12
# cut_vertices for current graph: 6
# conected_component for current graph: 8
# biconnected_components for current graph: 7
# cut_vertices for current graph: 6
# conected_component for current graph: 15
# biconnected_components for current graph: 11
# cut_vertices for current graph: 10
# conected_component for current graph: 2
# biconnected_components for current graph: 8
# cut_vertices for current graph: 7
# conected_component for current graph: 18
# biconnected_components for current graph: 21
# cut_vertices for current graph: 18
# conected_component for current graph: 11
# biconnected_components for current graph: 17
# cut_vertices for current graph: 16
# conected_component for current graph: 24
# biconnected_components for current graph: 19
# cut_vertices for current graph: 16
# conected_component for current graph: 7
# biconnected_components for current graph: 8
# cut_vertices for current graph: 7
# conected_component for current graph: 3
# biconnected_components for current graph: 6
# cut_vertices for current graph: 5
# conected_component for current graph: 2
# biconnected_components for current graph: 6
# cut_vertices for current graph: 3
# conected_component for current graph: 10
# biconnected_components for current graph: 7
# cut_vertices for current graph: 6
# conected_component for current graph: 11
# biconnected_components for current graph: 9
# cut_vertices for current graph: 8
# conected_component for current graph: 17
# biconnected_components for current graph: 28
# cut_vertices for current graph: 23
# conected_component for current graph: 11
# biconnected_components for current graph: 11
# cut_vertices for current graph: 10
# conected_component for current graph: 28
# biconnected_components for current graph: 19
# cut_vertices for current graph: 16
# conected_component for current graph: 10
# biconnected_components for current graph: 8
# cut_vertices for current graph: 5
# conected_component for current graph: 17
# biconnected_components for current graph: 8
# cut_vertices for current graph: 7
# conected_component for current graph: 11
# biconnected_components for current graph: 6
# cut_vertices for current graph: 5
# conected_component for current graph: 3
# biconnected_components for current graph: 3
# cut_vertices for current graph: 2
# conected_component for current graph: 4
# biconnected_components for current graph: 5
# cut_vertices for current graph: 4
# conected_component for current graph: 10
# biconnected_components for current graph: 11
# cut_vertices for current graph: 9
# conected_component for current graph: 6
# biconnected_components for current graph: 9
# cut_vertices for current graph: 7
# conected_component for current graph: 8
# biconnected_components for current graph: 14
# cut_vertices for current graph: 12
# conected_component for current graph: 2
# biconnected_components for current graph: 1
# cut_vertices for current graph: 0
# conected_component for current graph: 18
# biconnected_components for current graph: 18
# cut_vertices for current graph: 16
# conected_component for current graph: 16
# biconnected_components for current graph: 9
# cut_vertices for current graph: 7
# conected_component for current graph: 12
# biconnected_components for current graph: 21
# cut_vertices for current graph: 18
# conected_component for current graph: 10
# biconnected_components for current graph: 4
# cut_vertices for current graph: 3
# conected_component for current graph: 2
# biconnected_components for current graph: 6
# cut_vertices for current graph: 5
# conected_component for current graph: 3
# biconnected_components for current graph: 4
# cut_vertices for current graph: 3
# conected_component for current graph: 11
# biconnected_components for current graph: 12
# cut_vertices for current graph: 10
# conected_component for current graph: 11
# biconnected_components for current graph: 8
# cut_vertices for current graph: 6
# conected_component for current graph: 33
# biconnected_components for current graph: 20
# cut_vertices for current graph: 17
# conected_component for current graph: 11
# biconnected_components for current graph: 15
# cut_vertices for current graph: 12
# conected_component for current graph: 19
# biconnected_components for current graph: 19
# cut_vertices for current graph: 15
# conected_component for current graph: 12
# biconnected_components for current graph: 10
# cut_vertices for current graph: 8
# conected_component for current graph: 12
# biconnected_components for current graph: 10
# cut_vertices for current graph: 9
